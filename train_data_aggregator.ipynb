# %%
#MERGE THE DATA
import os
import pandas as pd
from fuzzywuzzy import fuzz
from fuzzywuzzy import process

# Step 1: Create the merged_data folder structure
merged_data_dir = 'merged_data'
seasons = ['2021-22', '2022-23', '2023-24']
positions = ['FWD', 'MID', 'DEF', 'GK']

# Create the merged_data directory with subdirectories for each season and position
for season in seasons:
    season_dir = os.path.join(merged_data_dir, season)
    os.makedirs(season_dir, exist_ok=True)
    
    for position in positions:
        position_dir = os.path.join(season_dir, position)
        os.makedirs(position_dir, exist_ok=True)

# Step 2: Define paths to fpl_gw_data and understat_data directories
fpl_gw_data_dir = 'fpl_gw_data'
understat_data_dir = 'understat_data'

# Function to find the best match using fuzzy matching
def find_best_match(player_name, understat_files):
    best_match = process.extractOne(player_name, understat_files, scorer=fuzz.partial_ratio)
    if best_match and best_match[1] >= 65:  # Adjust the threshold as needed
        return best_match[0]
    return None

# Step 3: Process each CSV file in fpl_gw_data
for season in seasons:
    fpl_season_dir = os.path.join(fpl_gw_data_dir, season)
    understat_season_dir = os.path.join(understat_data_dir, season)
    
    if os.path.isdir(fpl_season_dir) and os.path.isdir(understat_season_dir):
        for fpl_csv in os.listdir(fpl_season_dir):
            if fpl_csv.endswith('.csv'):
                fpl_csv_path = os.path.join(fpl_season_dir, fpl_csv)
                
                # Read the fpl_gw_data CSV
                fpl_df = pd.read_csv(fpl_csv_path)
                
                # Get player name and position
                player_name = fpl_df['name'].iloc[0]  
                player_position = fpl_df['position'].iloc[0]
                
                # Capitalize first and last name for fuzzy matching
                player_name_capitalized = '_'.join([name.capitalize() for name in player_name.split()])
                
                # List of all Understat files in the corresponding season directory
                understat_files = os.listdir(understat_season_dir)
                
                # Use fuzzy matching to find the best match for the player
                best_match_file = find_best_match(player_name_capitalized, understat_files)
                
                if best_match_file:
                    understat_csv_path = os.path.join(understat_season_dir, best_match_file)
                    
                    # Read the understat CSV
                    understat_df = pd.read_csv(understat_csv_path)
                    
                    # Merge fpl_gw_data with understat_data based on matching kickoff_time and date
                    fpl_df['kickoff_time'] = pd.to_datetime(fpl_df['kickoff_time']).dt.date
                    understat_df['date'] = pd.to_datetime(understat_df['date']).dt.date
                    
                    # Perform a left join to keep all rows from fpl_df and fill missing data with NaN
                    merged_df = pd.merge(fpl_df, understat_df, left_on='kickoff_time', right_on='date', how='left')
                    
                    # Save the merged file in the correct position folder in merged_data
                    merged_output_dir = os.path.join(merged_data_dir, season, player_position)
                    merged_output_path = os.path.join(merged_output_dir, fpl_csv)
                    
                    merged_df.to_csv(merged_output_path, index=False)
                    print(f"Merged and saved {fpl_csv} to {merged_output_dir}")
                else:
                    print(f"No matching Understat file found for {player_name}. Skipping {fpl_csv}.")
    else:
        print(f"Season folder {season} does not exist in both fpl_gw_data and understat_data.")
# Out:
# Merged and saved Miguel_Almirón.csv to merged_data/2021-22/MID
# No matching Understat file found for Isaac Success Ajayi. Skipping Isaac_Success_Ajayi.csv.
# Merged and saved Joseph_Hungbo.csv to merged_data/2021-22/MID
# Merged and saved Patrik_Gunnarsson.csv to merged_data/2021-22/GK
# Merged and saved Nathan_Aké.csv to merged_data/2021-22/DEF
# Merged and saved Jamie_Vardy.csv to merged_data/2021-22/FWD
# Merged and saved Lukas_Rupp.csv to merged_data/2021-22/MID
# Merged and saved Edo_Kayembe.csv to merged_data/2021-22/MID
# Merged and saved Vitaly_Janelt.csv to merged_data/2021-22/MID
# Merged and saved Andreas_Christensen.csv to merged_data/2021-22/DEF
# Merged and saved Morgan_Gibbs-White.csv to merged_data/2021-22/MID
# Merged and saved Jonjo_Shelvey.csv to merged_data/2021-22/MID
# No matching Understat file found for Dara Costelloe. Skipping Dara_Costelloe.csv.
# Merged and saved Josh_Benson.csv to merged_data/2021-22/MID
# Merged and saved Bryan_Gil_Salvatierra.csv to merged_data/2021-22/MID
# Merged and saved Pablo_Marí.csv to merged_data/2021-22/DEF
# Merged and saved Gylfi_Sigurdsson.csv to merged_data/2021-22/MID
# Merged and saved Freddie_Woodman.csv to merged_data/2021-22/GK
# Merged and saved Tariq_Lamptey.csv to merged_data/2021-22/DEF
# Merged and saved Martin_Dubravka.csv to merged_data/2021-22/GK
# Merged and saved Tony_Springett.csv to merged_data/2021-22/MID
# No matching Understat file found for Samir Caetano de Souza Santos. Skipping Samir_Caetano_de_Souza_Santos.csv.
# Merged and saved Adam_Webster.csv to merged_data/2021-22/DEF
# Merged and saved Juraj_Kucka.csv to merged_data/2021-22/MID
# No matching Understat file found for Marcelo Flores. Skipping Marcelo_Flores.csv.
# No matching Understat file found for N'Golo Kanté. Skipping N'Golo_Kanté.csv.
# Merged and saved Donny_van_de_Beek.csv to merged_data/2021-22/MID
# Merged and saved Shandon_Baptiste.csv to merged_data/2021-22/MID
# No matching Understat file found for Zach Awe. Skipping Zach_Awe.csv.
# Merged and saved Hamza_Choudhury.csv to merged_data/2021-22/MID
# Merged and saved Curtis_Jones.csv to merged_data/2021-22/MID
# Merged and saved Alexis_Mac_Allister.csv to merged_data/2021-22/MID
# Merged and saved Nathaniel_Phillips.csv to merged_data/2021-22/DEF
# Merged and saved Jarrad_Branthwaite.csv to merged_data/2021-22/DEF
# Merged and saved Tom_Davies.csv to merged_data/2021-22/MID
# Merged and saved Mohamed_Elyounoussi.csv to merged_data/2021-22/MID
# Merged and saved Ben_Nelson.csv to merged_data/2021-22/DEF
# Merged and saved Joe_Rodon.csv to merged_data/2021-22/DEF
# Merged and saved Jordan_Ayew.csv to merged_data/2021-22/FWD
# Merged and saved Bruno_Guimarães_Rodriguez_Moura.csv to merged_data/2021-22/MID
# Merged and saved Oriol_Romeu_Vidal.csv to merged_data/2021-22/MID
# Merged and saved Harrison_Ashby.csv to merged_data/2021-22/DEF
# Merged and saved Joshua_King.csv to merged_data/2021-22/FWD
# Merged and saved Lewis_Hall.csv to merged_data/2021-22/MID
# Merged and saved Yoane_Wissa.csv to merged_data/2021-22/MID
# Merged and saved Issa_Diop.csv to merged_data/2021-22/DEF
# Merged and saved Jonjoe_Kenny.csv to merged_data/2021-22/DEF
# Merged and saved Ian_Carlo_Poveda-Ocampo.csv to merged_data/2021-22/MID
# Merged and saved Odsonne_Edouard.csv to merged_data/2021-22/FWD
# Merged and saved James_Maddison.csv to merged_data/2021-22/MID
# Merged and saved Zak_Swanson.csv to merged_data/2021-22/DEF
# Merged and saved Emiliano_Buendía_Stati.csv to merged_data/2021-22/MID
# No matching Understat file found for Ayotomiwa Dele-Bashiru. Skipping Ayotomiwa_Dele-Bashiru.csv.
# Merged and saved Tino_Livramento.csv to merged_data/2021-22/DEF
# Merged and saved Hugo_Lloris.csv to merged_data/2021-22/GK
# Merged and saved Harvey_Barnes.csv to merged_data/2021-22/MID
# Merged and saved Pierre-Emerick_Aubameyang.csv to merged_data/2021-22/FWD
# Merged and saved Benjamin_Chilwell.csv to merged_data/2021-22/DEF
# No matching Understat file found for Jarell Quansah. Skipping Jarell_Quansah.csv.
# Merged and saved James_Storer.csv to merged_data/2021-22/GK
# Merged and saved Jamie_Bowden.csv to merged_data/2021-22/MID
# Merged and saved Ross_Barkley.csv to merged_data/2021-22/MID
# No matching Understat file found for Frederico Rodrigues de Paula Santos. Skipping Frederico_Rodrigues_de_Paula_Santos.csv.
# Merged and saved Jesurun_Rak-Sakyi.csv to merged_data/2021-22/MID
# Merged and saved Michael_Keane.csv to merged_data/2021-22/DEF
# Merged and saved Cole_Palmer.csv to merged_data/2021-22/MID
# No matching Understat file found for Maxwell Haygarth. Skipping Maxwell_Haygarth.csv.
# Merged and saved Pablo_Fornals.csv to merged_data/2021-22/MID
# Merged and saved Reece_Hannam.csv to merged_data/2021-22/DEF
# Merged and saved Harry_Lewis.csv to merged_data/2021-22/GK
# No matching Understat file found for Emerson Palmieri dos Santos. Skipping Emerson_Palmieri_dos_Santos.csv.
# No matching Understat file found for Viljami Sinisalo. Skipping Viljami_Sinisalo.csv.
# No matching Understat file found for Tyler Dibling. Skipping Tyler_Dibling.csv.
# Merged and saved Juan_Camilo_Hernández_Suárez.csv to merged_data/2021-22/FWD
# Merged and saved Javier_Manquillo.csv to merged_data/2021-22/DEF
# Merged and saved Timothy_Castagne.csv to merged_data/2021-22/DEF
# Merged and saved Joel_Ward.csv to merged_data/2021-22/DEF
# Merged and saved William_Smallbone.csv to merged_data/2021-22/MID
# Merged and saved Wesley_Fofana.csv to merged_data/2021-22/DEF
# Merged and saved Harry_Kane.csv to merged_data/2021-22/FWD
# Merged and saved Carney_Chukwuemeka.csv to merged_data/2021-22/MID
# Merged and saved Arthur_Masuaku.csv to merged_data/2021-22/DEF
# Merged and saved Anwar_El_Ghazi.csv to merged_data/2021-22/MID
# Merged and saved Stuart_Dallas.csv to merged_data/2021-22/MID
# No matching Understat file found for Mahmoud Ahmed Ibrahim Hassan. Skipping Mahmoud_Ahmed_Ibrahim_Hassan.csv.
# Merged and saved Mason_Mount.csv to merged_data/2021-22/MID
# Merged and saved Lucas_Digne.csv to merged_data/2021-22/DEF
# Merged and saved Conrad_Egan-Riley.csv to merged_data/2021-22/DEF
# Merged and saved Cameron_Archer.csv to merged_data/2021-22/FWD
# No matching Understat file found for Vontae Daley-Campbell. Skipping Vontae_Daley-Campbell.csv.
# Merged and saved Kenny_McLean.csv to merged_data/2021-22/MID
# Merged and saved Adam_Masina.csv to merged_data/2021-22/DEF
# Merged and saved Ibrahima_Konaté.csv to merged_data/2021-22/DEF
# Merged and saved Kaide_Gordon.csv to merged_data/2021-22/MID
# Merged and saved Kurt_Zouma.csv to merged_data/2021-22/DEF
# Merged and saved Luis_Díaz.csv to merged_data/2021-22/MID
# Merged and saved Michael_Obafemi.csv to merged_data/2021-22/FWD
# Merged and saved Shola_Shoretire.csv to merged_data/2021-22/MID
# No matching Understat file found for Daniel Castelo Podence. Skipping Daniel_Castelo_Podence.csv.
# Merged and saved Matt_Targett.csv to merged_data/2021-22/DEF
# Merged and saved Cody_Drameh.csv to merged_data/2021-22/DEF
# Merged and saved Angelo_Ogbonna.csv to merged_data/2021-22/DEF
# Merged and saved Gabriel_Magalhães.csv to merged_data/2021-22/DEF
# Merged and saved Dale_Stephens.csv to merged_data/2021-22/MID
# Merged and saved Angus_Gunn.csv to merged_data/2021-22/GK
# Merged and saved Joel_Matip.csv to merged_data/2021-22/DEF
# Merged and saved Sergio_Reguilón.csv to merged_data/2021-22/DEF
# Merged and saved Lewis_Richardson.csv to merged_data/2021-22/FWD
# Merged and saved Jack_Grieves.csv to merged_data/2021-22/FWD
# Merged and saved Michail_Antonio.csv to merged_data/2021-22/FWD
# Merged and saved Cédric_Soares.csv to merged_data/2021-22/DEF
# Merged and saved Saman_Ghoddos.csv to merged_data/2021-22/MID
# Merged and saved Owen_Dodgson.csv to merged_data/2021-22/DEF
# Merged and saved Andrew_Omobamidele.csv to merged_data/2021-22/DEF
# Merged and saved Jacob_Ramsey.csv to merged_data/2021-22/MID
# Merged and saved Keinan_Davis.csv to merged_data/2021-22/FWD
# Merged and saved Pierre_Ekwah.csv to merged_data/2021-22/DEF
# Merged and saved Thomas_Partey.csv to merged_data/2021-22/MID
# No matching Understat file found for Brandon Austin. Skipping Brandon_Austin.csv.
# Merged and saved Ethan_Ampadu.csv to merged_data/2021-22/DEF
# Merged and saved Francisco_Sierralta.csv to merged_data/2021-22/DEF
# Merged and saved Nathan_Ferguson.csv to merged_data/2021-22/DEF
# Merged and saved Conor_Hourihane.csv to merged_data/2021-22/MID
# Merged and saved Dejan_Kulusevski.csv to merged_data/2021-22/MID
# Merged and saved Christian_Kabasele.csv to merged_data/2021-22/DEF
# Merged and saved Nampalys_Mendy.csv to merged_data/2021-22/MID
# Merged and saved Illan_Meslier.csv to merged_data/2021-22/GK
# No matching Understat file found for Jonathan Tomkinson. Skipping Jonathan_Tomkinson.csv.
# Merged and saved Kevin_De_Bruyne.csv to merged_data/2021-22/MID
# Merged and saved Alex_Iwobi.csv to merged_data/2021-22/MID
# Merged and saved Lukasz_Fabianski.csv to merged_data/2021-22/GK
# Merged and saved Lewis_Dobbin.csv to merged_data/2021-22/FWD
# No matching Understat file found for Vincent Angelini. Skipping Vincent_Angelini.csv.
# Merged and saved Ben_Davies.csv to merged_data/2021-22/DEF
# No matching Understat file found for Jordan Hugill. Skipping Jordan_Hugill.csv.
# Merged and saved Nikola_Vlasic.csv to merged_data/2021-22/MID
# Merged and saved James_Ward-Prowse.csv to merged_data/2021-22/MID
# Merged and saved Conor_Coady.csv to merged_data/2021-22/DEF
# Merged and saved Willy_Caballero.csv to merged_data/2021-22/GK
# Merged and saved Liam_Delap.csv to merged_data/2021-22/FWD
# Merged and saved Luke_Shaw.csv to merged_data/2021-22/DEF
# Merged and saved Mathias_Jorgensen.csv to merged_data/2021-22/DEF
# Merged and saved Chris_Wood.csv to merged_data/2021-22/FWD
# Merged and saved Abdoulaye_Doucouré.csv to merged_data/2021-22/MID
# Merged and saved Crysencio_Summerville.csv to merged_data/2021-22/MID
# Merged and saved Jack_Grealish.csv to merged_data/2021-22/MID
# No matching Understat file found for Reece Welch. Skipping Reece_Welch.csv.
# Merged and saved Eberechi_Eze.csv to merged_data/2021-22/MID
# Merged and saved Ben_Wilmot.csv to merged_data/2021-22/DEF
# Merged and saved Héctor_Junior_Firpo_Adames.csv to merged_data/2021-22/DEF
# Merged and saved Romain_Perraud.csv to merged_data/2021-22/DEF
# Merged and saved Sadio_Mané.csv to merged_data/2021-22/MID
# Merged and saved Tyrone_Mings.csv to merged_data/2021-22/DEF
# Merged and saved Karl_Hein.csv to merged_data/2021-22/GK
# Merged and saved Mason_Holgate.csv to merged_data/2021-22/DEF
# Merged and saved Nathan_Young-Coombes.csv to merged_data/2021-22/FWD
# Merged and saved Asmir_Begović.csv to merged_data/2021-22/GK
# Merged and saved Matthew_Craig.csv to merged_data/2021-22/MID
# Merged and saved Benjamin_Mendy.csv to merged_data/2021-22/DEF
# Merged and saved Ryan_Fraser.csv to merged_data/2021-22/MID
# Merged and saved Jeff_Hendrick.csv to merged_data/2021-22/MID
# Merged and saved Craig_Cathcart.csv to merged_data/2021-22/DEF
# No matching Understat file found for Adedapo Awokoya-Mebude. Skipping Adedapo_Awokoya-Mebude.csv.
# Merged and saved Jarrod_Bowen.csv to merged_data/2021-22/MID
# Merged and saved Divock_Origi.csv to merged_data/2021-22/FWD
# Merged and saved Tyrick_Mitchell.csv to merged_data/2021-22/DEF
# Merged and saved Xherdan_Shaqiri.csv to merged_data/2021-22/MID
# Merged and saved Haydon_Roberts.csv to merged_data/2021-22/DEF
# Merged and saved Martin_Kelly.csv to merged_data/2021-22/DEF
# Merged and saved Kieran_Trippier.csv to merged_data/2021-22/DEF
# Merged and saved Adam_Idah.csv to merged_data/2021-22/FWD
# Merged and saved João_Pedro_Cavaco_Cancelo.csv to merged_data/2021-22/DEF
# Merged and saved Ismaila_Sarr.csv to merged_data/2021-22/MID
# No matching Understat file found for Nohan Kenneh. Skipping Nohan_Kenneh.csv.
# Merged and saved Fabian_Delph.csv to merged_data/2021-22/MID
# Merged and saved Solomon_March.csv to merged_data/2021-22/MID
# No matching Understat file found for Kayky da Silva Chagas. Skipping Kayky_da_Silva_Chagas.csv.
# No matching Understat file found for Robert Kenedy Nunes do Nascimento. Skipping Robert_Kenedy_Nunes_do_Nascimento.csv.
# No matching Understat file found for Paris Maghoma. Skipping Paris_Maghoma.csv.
# Merged and saved Jeremy_Ngakia.csv to merged_data/2021-22/DEF
# Merged and saved Mads_Bech_Sørensen.csv to merged_data/2021-22/DEF
# No matching Understat file found for Cieran Slicker. Skipping Cieran_Slicker.csv.
# Merged and saved Emile_Smith_Rowe.csv to merged_data/2021-22/MID
# Merged and saved Alex_Kral.csv to merged_data/2021-22/MID
# Merged and saved Marcos_Alonso.csv to merged_data/2021-22/DEF
# Merged and saved Kalvin_Phillips.csv to merged_data/2021-22/MID
# Merged and saved Callum_Wilson.csv to merged_data/2021-22/FWD
# Merged and saved Harvey_Elliott.csv to merged_data/2021-22/MID
# Merged and saved Mathew_Ryan.csv to merged_data/2021-22/GK
# No matching Understat file found for Marco Stiepermann. Skipping Marco_Stiepermann.csv.
# No matching Understat file found for Fernando Luiz Rosa. Skipping Fernando_Luiz_Rosa.csv.
# Merged and saved Ethan_Pinnock.csv to merged_data/2021-22/DEF
# Merged and saved Ben_Godfrey.csv to merged_data/2021-22/DEF
# Merged and saved Elliot_Anderson.csv to merged_data/2021-22/MID
# Merged and saved Hee-Chan_Hwang.csv to merged_data/2021-22/FWD
# Merged and saved Andros_Townsend.csv to merged_data/2021-22/MID
# Merged and saved Pablo_Hernández_Domínguez.csv to merged_data/2021-22/MID
# Merged and saved Diogo_Jota.csv to merged_data/2021-22/MID
# No matching Understat file found for Emerson Aparecido Leite de Souza Junior. Skipping Emerson_Aparecido_Leite_de_Souza_Junior.csv.
# No matching Understat file found for Jonathan Castro Otto. Skipping Jonathan_Castro_Otto.csv.
# Merged and saved Matthew_Cash.csv to merged_data/2021-22/DEF
# Merged and saved Dimitris_Giannoulis.csv to merged_data/2021-22/DEF
# Merged and saved Edinson_Cavani.csv to merged_data/2021-22/FWD
# Merged and saved Naby_Keita.csv to merged_data/2021-22/MID
# No matching Understat file found for José Malheiro de Sá. Skipping José_Malheiro_de_Sá.csv.
# No matching Understat file found for Marcus Bettinelli. Skipping Marcus_Bettinelli.csv.
# Merged and saved Takumi_Minamino.csv to merged_data/2021-22/MID
# Merged and saved Raheem_Sterling.csv to merged_data/2021-22/MID
# Merged and saved Mateo_Kovacic.csv to merged_data/2021-22/MID
# Merged and saved Ainsley_Maitland-Niles.csv to merged_data/2021-22/MID
# Merged and saved Danny_Rose.csv to merged_data/2021-22/DEF
# Merged and saved Pierre_Lees-Melou.csv to merged_data/2021-22/MID
# Merged and saved Leandro_Trossard.csv to merged_data/2021-22/MID
# Merged and saved James_Morris.csv to merged_data/2021-22/DEF
# Merged and saved John_Stones.csv to merged_data/2021-22/DEF
# No matching Understat file found for Filip Marschall. Skipping Filip_Marschall.csv.
# Merged and saved Darren_Randolph.csv to merged_data/2021-22/GK
# Merged and saved Daniel_James.csv to merged_data/2021-22/MID
# No matching Understat file found for Mohamed Naser El Sayed Elneny. Skipping Mohamed_Naser_El_Sayed_Elneny.csv.
# Merged and saved Jack_Jenkins.csv to merged_data/2021-22/MID
# Merged and saved Aymeric_Laporte.csv to merged_data/2021-22/DEF
# Merged and saved Cheikhou_Kouyaté.csv to merged_data/2021-22/DEF
# Merged and saved Steven_Bergwijn.csv to merged_data/2021-22/MID
# Merged and saved Aaron_Lennon.csv to merged_data/2021-22/MID
# No matching Understat file found for Myles Peart-Harris. Skipping Myles_Peart-Harris.csv.
# Merged and saved Alex_Kirk.csv to merged_data/2021-22/DEF
# Merged and saved Joe_Gelhardt.csv to merged_data/2021-22/FWD
# Merged and saved Adam_Armstrong.csv to merged_data/2021-22/FWD
# Merged and saved Konstantinos_Tsimikas.csv to merged_data/2021-22/DEF
# Merged and saved Luka_Milivojevic.csv to merged_data/2021-22/MID
# Merged and saved Jordan_Henderson.csv to merged_data/2021-22/MID
# Merged and saved Wesley_Moraes.csv to merged_data/2021-22/FWD
# Merged and saved Jack_Stephens.csv to merged_data/2021-22/DEF
# Merged and saved Armando_Broja.csv to merged_data/2021-22/FWD
# Merged and saved Moussa_Sissoko.csv to merged_data/2021-22/MID
# Merged and saved Harry_Winks.csv to merged_data/2021-22/MID
# Merged and saved Josh_Martin.csv to merged_data/2021-22/MID
# Merged and saved Patson_Daka.csv to merged_data/2021-22/FWD
# Merged and saved Hannibal_Mejbri.csv to merged_data/2021-22/MID
# Merged and saved Martin_Ødegaard.csv to merged_data/2021-22/MID
# Merged and saved Billy_Gilmour.csv to merged_data/2021-22/MID
# Merged and saved Morgan_Sanson.csv to merged_data/2021-22/MID
# Merged and saved Marc_Albrighton.csv to merged_data/2021-22/MID
# Merged and saved Marcel_Lavinier.csv to merged_data/2021-22/DEF
# Merged and saved Pascal_Groß.csv to merged_data/2021-22/MID
# Merged and saved Paul_Pogba.csv to merged_data/2021-22/MID
# Merged and saved Neal_Maupay.csv to merged_data/2021-22/FWD
# Merged and saved Mathias_Jensen.csv to merged_data/2021-22/MID
# Merged and saved Reiss_Nelson.csv to merged_data/2021-22/MID
# Merged and saved Tyler_Onyango.csv to merged_data/2021-22/MID
# Merged and saved Jay_Rodriguez.csv to merged_data/2021-22/FWD
# Merged and saved Kieran_Dowell.csv to merged_data/2021-22/MID
# Merged and saved William_Troost-Ekong.csv to merged_data/2021-22/DEF
# Merged and saved Liam_Cooper.csv to merged_data/2021-22/DEF
# Merged and saved Daniel_N'Lundulu.csv to merged_data/2021-22/FWD
# Merged and saved Ellis_Simms.csv to merged_data/2021-22/FWD
# No matching Understat file found for Jon McCracken. Skipping Jon_McCracken.csv.
# Merged and saved Mark_Noble.csv to merged_data/2021-22/MID
# No matching Understat file found for Bernardo Mota Veiga de Carvalho e Silva. Skipping Bernardo_Mota_Veiga_de_Carvalho_e_Silva.csv.
# Merged and saved Saúl_Ñíguez.csv to merged_data/2021-22/MID
# Merged and saved Nemanja_Matic.csv to merged_data/2021-22/MID
# Merged and saved Kyle_Walker.csv to merged_data/2021-22/DEF
# Merged and saved Dwight_Gayle.csv to merged_data/2021-22/FWD
# Merged and saved Fernando_Marçal.csv to merged_data/2021-22/DEF
# Merged and saved Jonny_Evans.csv to merged_data/2021-22/DEF
# No matching Understat file found for Lucas Rodrigues Moura da Silva. Skipping Lucas_Rodrigues_Moura_da_Silva.csv.
# Merged and saved Ryan_Giles.csv to merged_data/2021-22/MID
# Merged and saved Tobi_Omole.csv to merged_data/2021-22/DEF
# No matching Understat file found for Philip Zinckernagel. Skipping Philip_Zinckernagel.csv.
# Merged and saved Adama_Traoré.csv to merged_data/2021-22/MID
# Merged and saved Dane_Scarlett.csv to merged_data/2021-22/FWD
# Merged and saved Andreas_Pereira.csv to merged_data/2021-22/MID
# Merged and saved Matt_Ritchie.csv to merged_data/2021-22/DEF
# Merged and saved Michy_Batshuayi.csv to merged_data/2021-22/FWD
# No matching Understat file found for Gabriel Fernando de Jesus. Skipping Gabriel_Fernando_de_Jesus.csv.
# Merged and saved Virgil_van_Dijk.csv to merged_data/2021-22/DEF
# Merged and saved Pascal_Struijk.csv to merged_data/2021-22/DEF
# Merged and saved Anthony_Gordon.csv to merged_data/2021-22/MID
# Merged and saved Ollie_Watkins.csv to merged_data/2021-22/FWD
# No matching Understat file found for Francisco Femenía Far. Skipping Francisco_Femenía_Far.csv.
# Merged and saved Aaron_Wan-Bissaka.csv to merged_data/2021-22/DEF
# Merged and saved Finley_Stevens.csv to merged_data/2021-22/DEF
# Merged and saved Nathan_Patterson.csv to merged_data/2021-22/DEF
# Merged and saved Fabian_Schär.csv to merged_data/2021-22/DEF
# Merged and saved Axel_Tuanzebe.csv to merged_data/2021-22/DEF
# No matching Understat file found for Francisco Machado Mota de Castro Trincão. Skipping Francisco_Machado_Mota_de_Castro_Trincão.csv.
# Merged and saved Oghenekaro_Peter_Etebo.csv to merged_data/2021-22/MID
# Merged and saved James_McAtee.csv to merged_data/2021-22/MID
# Merged and saved Charlie_Savage.csv to merged_data/2021-22/MID
# Merged and saved Eric_Bailly.csv to merged_data/2021-22/DEF
# Merged and saved Marcus_Forss.csv to merged_data/2021-22/FWD
# Merged and saved Fraser_Forster.csv to merged_data/2021-22/GK
# Merged and saved Jack_Harrison.csv to merged_data/2021-22/MID
# Merged and saved Lewis_Dunk.csv to merged_data/2021-22/DEF
# No matching Understat file found for Halil Dervişoğlu. Skipping Halil_Dervişoğlu.csv.
# Merged and saved Ibrahima_Diallo.csv to merged_data/2021-22/MID
# Merged and saved Francisco_Casilla_Cortés.csv to merged_data/2021-22/GK
# Merged and saved Kristoffer_Ajer.csv to merged_data/2021-22/DEF
# Merged and saved Moisés_Caicedo.csv to merged_data/2021-22/MID
# Merged and saved Benjamin_Chrisene.csv to merged_data/2021-22/MID
# Merged and saved Saïd_Benrahma.csv to merged_data/2021-22/MID
# No matching Understat file found for Ed Turns. Skipping Ed_Turns.csv.
# No matching Understat file found for Frederik Alves. Skipping Frederik_Alves.csv.
# No matching Understat file found for Mark Gillespie. Skipping Mark_Gillespie.csv.
# Merged and saved Niels_Nkounkou.csv to merged_data/2021-22/DEF
# No matching Understat file found for Kgaogelo Chauke. Skipping Kgaogelo_Chauke.csv.
# Merged and saved Christian_Nørgaard.csv to merged_data/2021-22/MID
# Merged and saved Danny_Ward.csv to merged_data/2021-22/GK
# Merged and saved Ryan_Sessegnon.csv to merged_data/2021-22/DEF
# Merged and saved Dominic_Calvert-Lewin.csv to merged_data/2021-22/FWD
# Merged and saved Ben_Woodburn.csv to merged_data/2021-22/MID
# Merged and saved Dion_Sanderson.csv to merged_data/2021-22/DEF
# No matching Understat file found for Tommy Doyle. Skipping Tommy_Doyle.csv.
# Merged and saved Riyad_Mahrez.csv to merged_data/2021-22/MID
# Merged and saved Christos_Tzolis.csv to merged_data/2021-22/MID
# Merged and saved Giovani_Lo_Celso.csv to merged_data/2021-22/MID
# Merged and saved Phil_Jones.csv to merged_data/2021-22/DEF
# Merged and saved Raúl_Jiménez.csv to merged_data/2021-22/FWD
# Merged and saved Rayan_Ait_Nouri.csv to merged_data/2021-22/DEF
# Merged and saved Michael_Olise.csv to merged_data/2021-22/MID
# No matching Understat file found for Romeo Lavia. Skipping Romeo_Lavia.csv.
# Merged and saved Álvaro_Fernández.csv to merged_data/2021-22/GK
# Merged and saved Aaron_Ramsdale.csv to merged_data/2021-22/GK
# Merged and saved Karl_Darlow.csv to merged_data/2021-22/GK
# Merged and saved Albert_Sambi_Lokonga.csv to merged_data/2021-22/MID
# No matching Understat file found for Lyanco Evangelista Silveira Neves Vojnovic. Skipping Lyanco_Evangelista_Silveira_Neves_Vojnovic.csv.
# Merged and saved Roberto_Firmino.csv to merged_data/2021-22/FWD
# Merged and saved Ben_White.csv to merged_data/2021-22/DEF
# Merged and saved Sam_Greenwood.csv to merged_data/2021-22/FWD
# Merged and saved Ben_Gibson.csv to merged_data/2021-22/DEF
# No matching Understat file found for Toti António Gomes. Skipping Toti_António_Gomes.csv.
# Merged and saved Gabriel_Teodoro_Martinelli_Silva.csv to merged_data/2021-22/MID
# Merged and saved Leon_Bailey.csv to merged_data/2021-22/MID
# No matching Understat file found for Remi Matthews. Skipping Remi_Matthews.csv.
# No matching Understat file found for Josh Feeney. Skipping Josh_Feeney.csv.
# Merged and saved Aaron_Ramsey.csv to merged_data/2021-22/MID
# Merged and saved Luke_Thomas.csv to merged_data/2021-22/DEF
# Merged and saved Mateusz_Klich.csv to merged_data/2021-22/MID
# No matching Understat file found for Shaqai Forde. Skipping Shaqai_Forde.csv.
# Merged and saved Nicolas_Pépé.csv to merged_data/2021-22/MID
# Merged and saved Bali_Mumba.csv to merged_data/2021-22/DEF
# Merged and saved Stuart_McKinstry.csv to merged_data/2021-22/MID
# No matching Understat file found for Domingos Quina. Skipping Domingos_Quina.csv.
# Merged and saved Robert_Street.csv to merged_data/2021-22/FWD
# Merged and saved Archie_Gray.csv to merged_data/2021-22/MID
# Merged and saved Marc_Cucurella.csv to merged_data/2021-22/DEF
# Merged and saved Michal_Karbownik.csv to merged_data/2021-22/DEF
# Merged and saved Liam_Gibbs.csv to merged_data/2021-22/MID
# Merged and saved Ademola_Lookman.csv to merged_data/2021-22/MID
# Merged and saved Granit_Xhaka.csv to merged_data/2021-22/MID
# Merged and saved Alex_McCarthy.csv to merged_data/2021-22/GK
# Merged and saved Che_Adams.csv to merged_data/2021-22/FWD
# No matching Understat file found for Rui Pedro dos Santos Patrício. Skipping Rui_Pedro_dos_Santos_Patrício.csv.
# Merged and saved Phil_Bardsley.csv to merged_data/2021-22/DEF
# Merged and saved Abu_Kamara.csv to merged_data/2021-22/FWD
# Merged and saved Hassane_Kamara.csv to merged_data/2021-22/DEF
# Merged and saved Ki-Jana_Hoever.csv to merged_data/2021-22/DEF
# Merged and saved Josh_Brownhill.csv to merged_data/2021-22/MID
# Merged and saved Charlie_Cresswell.csv to merged_data/2021-22/DEF
# No matching Understat file found for Fabio Henrique Tavares. Skipping Fabio_Henrique_Tavares.csv.
# Merged and saved Christian_Marques.csv to merged_data/2021-22/DEF
# Merged and saved Jed_Steer.csv to merged_data/2021-22/GK
# No matching Understat file found for Dynel Simeu. Skipping Dynel_Simeu.csv.
# No matching Understat file found for Julian Jeanvier. Skipping Julian_Jeanvier.csv.
# Merged and saved Charlie_Patino.csv to merged_data/2021-22/MID
# Merged and saved Jairo_Riedewald.csv to merged_data/2021-22/MID
# Merged and saved Kasey_McAteer.csv to merged_data/2021-22/MID
# Merged and saved James_Tomkins.csv to merged_data/2021-22/DEF
# Merged and saved Joe_Hart.csv to merged_data/2021-22/GK
# Merged and saved Conor_Gallagher.csv to merged_data/2021-22/MID
# Merged and saved Will_Hughes.csv to merged_data/2021-22/MID
# Merged and saved Ozan_Tufan.csv to merged_data/2021-22/MID
# Merged and saved Aaron_Cresswell.csv to merged_data/2021-22/DEF
# Merged and saved Nathan_Broadhead.csv to merged_data/2021-22/FWD
# Merged and saved Mads_Roerslev_Rasmussen.csv to merged_data/2021-22/DEF
# Merged and saved Sean_Longstaff.csv to merged_data/2021-22/MID
# Merged and saved Jacob_Murphy.csv to merged_data/2021-22/MID
# No matching Understat file found for Mika Biereth. Skipping Mika_Biereth.csv.
# Merged and saved Mohammed_Salisu.csv to merged_data/2021-22/DEF
# No matching Understat file found for Thierry Small. Skipping Thierry_Small.csv.
# Merged and saved Christian_Eriksen.csv to merged_data/2021-22/MID
# Merged and saved Ken_Sema.csv to merged_data/2021-22/MID
# Merged and saved Robin_Koch.csv to merged_data/2021-22/DEF
# Merged and saved Yves_Bissouma.csv to merged_data/2021-22/MID
# Merged and saved Romelu_Lukaku.csv to merged_data/2021-22/FWD
# Merged and saved Danny_Ings.csv to merged_data/2021-22/FWD
# No matching Understat file found for Hélder Wander Sousa de Azevedo e Costa. Skipping Hélder_Wander_Sousa_de_Azevedo_e_Costa.csv.
# Merged and saved Grant_Hanley.csv to merged_data/2021-22/DEF
# Merged and saved Harvey_Vale.csv to merged_data/2021-22/MID
# Merged and saved Joseph_Gomez.csv to merged_data/2021-22/DEF
# No matching Understat file found for Lucas De Bolle. Skipping Lucas_De_Bolle.csv.
# Merged and saved Joachim_Andersen.csv to merged_data/2021-22/DEF
# Merged and saved Jaden_Philogene-Bidace.csv to merged_data/2021-22/MID
# Merged and saved Hakim_Ziyech.csv to merged_data/2021-22/MID
# No matching Understat file found for Mattéo Guendouzi. Skipping Mattéo_Guendouzi.csv.
# Merged and saved Heung-Min_Son.csv to merged_data/2021-22/MID
# Merged and saved Cenk_Tosun.csv to merged_data/2021-22/FWD
# Merged and saved Will_Norris.csv to merged_data/2021-22/GK
# Merged and saved Anthony_Martial.csv to merged_data/2021-22/FWD
# No matching Understat file found for Conor Coventry. Skipping Conor_Coventry.csv.
# Merged and saved Daniel_Amartey.csv to merged_data/2021-22/DEF
# Merged and saved Takehiro_Tomiyasu.csv to merged_data/2021-22/DEF
# Merged and saved Phil_Foden.csv to merged_data/2021-22/MID
# Merged and saved Kasper_Schmeichel.csv to merged_data/2021-22/GK
# Merged and saved Christian_Benteke.csv to merged_data/2021-22/FWD
# Merged and saved Dominic_Thompson.csv to merged_data/2021-22/DEF
# No matching Understat file found for Ajibola Alese. Skipping Ajibola_Alese.csv.
# Merged and saved James_Tarkowski.csv to merged_data/2021-22/DEF
# No matching Understat file found for Odeluga Offiah. Skipping Odeluga_Offiah.csv.
# Merged and saved Adrian_Blake.csv to merged_data/2021-22/MID
# Merged and saved Jan_Zamburek.csv to merged_data/2021-22/MID
# Merged and saved Philippe_Coutinho_Correia.csv to merged_data/2021-22/MID
# Merged and saved Jadon_Sancho.csv to merged_data/2021-22/MID
# Merged and saved Jamal_Baptiste.csv to merged_data/2021-22/DEF
# Merged and saved Reece_James.csv to merged_data/2021-22/DEF
# Merged and saved John_Ruddy.csv to merged_data/2021-22/GK
# Merged and saved Robin_Olsen.csv to merged_data/2021-22/GK
# Merged and saved Owen_Beck.csv to merged_data/2021-22/DEF
# Merged and saved Pontus_Jansson.csv to merged_data/2021-22/DEF
# Merged and saved Johann_Berg_Gudmundsson.csv to merged_data/2021-22/MID
# Merged and saved Michael_McGovern.csv to merged_data/2021-22/GK
# No matching Understat file found for Nuno Varela Tavares. Skipping Nuno_Varela_Tavares.csv.
# Merged and saved Joe_White.csv to merged_data/2021-22/MID
# Merged and saved Yerry_Mina.csv to merged_data/2021-22/DEF
# No matching Understat file found for Luke Mbete. Skipping Luke_Mbete.csv.
# Merged and saved Jakub_Moder.csv to merged_data/2021-22/MID
# Merged and saved Olivier_Giroud.csv to merged_data/2021-22/FWD
# Merged and saved Manuel_Lanzini.csv to merged_data/2021-22/MID
# No matching Understat file found for Kamil Conteh. Skipping Kamil_Conteh.csv.
# Merged and saved Jeremy_Sarmiento.csv to merged_data/2021-22/MID
# No matching Understat file found for Pelenda Joshua Dasilva. Skipping Pelenda_Joshua_Dasilva.csv.
# Merged and saved Troy_Deeney.csv to merged_data/2021-22/FWD
# Merged and saved Alphonse_Areola.csv to merged_data/2021-22/GK
# Merged and saved Matthew_Cox.csv to merged_data/2021-22/GK
# Merged and saved Adam_Forshaw.csv to merged_data/2021-22/MID
# Merged and saved Stuart_Armstrong.csv to merged_data/2021-22/MID
# Merged and saved Daniel_Chesters.csv to merged_data/2021-22/MID
# Merged and saved Bailey_Peacock-Farrell.csv to merged_data/2021-22/GK
# No matching Understat file found for João Filipe Iria Santos Moutinho. Skipping João_Filipe_Iria_Santos_Moutinho.csv.
# No matching Understat file found for Pierluigi Gollini. Skipping Pierluigi_Gollini.csv.
# Merged and saved Willy_Boly.csv to merged_data/2021-22/DEF
# Merged and saved Imrân_Louza.csv to merged_data/2021-22/MID
# Merged and saved Davinson_Sánchez.csv to merged_data/2021-22/DEF
# Merged and saved Ferran_Torres.csv to merged_data/2021-22/MID
# Merged and saved Seamus_Coleman.csv to merged_data/2021-22/DEF
# Merged and saved Timo_Werner.csv to merged_data/2021-22/FWD
# Merged and saved Diego_Llorente.csv to merged_data/2021-22/DEF
# Merged and saved Przemyslaw_Placheta.csv to merged_data/2021-22/MID
# Merged and saved Nathaniel_Clyne.csv to merged_data/2021-22/DEF
# Merged and saved Rodrigo_Moreno.csv to merged_data/2021-22/FWD
# No matching Understat file found for André Filipe Tavares Gomes. Skipping André_Filipe_Tavares_Gomes.csv.
# Merged and saved Daniel_Bachmann.csv to merged_data/2021-22/GK
# No matching Understat file found for Bruno Miguel Borges Fernandes. Skipping Bruno_Miguel_Borges_Fernandes.csv.
# Merged and saved Jack_Cork.csv to merged_data/2021-22/MID
# Merged and saved Todd_Cantwell.csv to merged_data/2021-22/MID
# Merged and saved Kai_Havertz.csv to merged_data/2021-22/MID
# Merged and saved Marvelous_Nakamba.csv to merged_data/2021-22/MID
# Merged and saved Ryan_Bertrand.csv to merged_data/2021-22/DEF
# Merged and saved Nathan_Tella.csv to merged_data/2021-22/MID
# Merged and saved Cristian_Romero.csv to merged_data/2021-22/DEF
# Merged and saved Kiernan_Dewsbury-Hall.csv to merged_data/2021-22/MID
# Merged and saved Douglas_Luiz_Soares_de_Paulo.csv to merged_data/2021-22/MID
# Merged and saved Bernardo_Fernandes_Da_Silva_Junior.csv to merged_data/2021-22/DEF
# No matching Understat file found for João Pedro Junqueira de Jesus. Skipping João_Pedro_Junqueira_de_Jesus.csv.
# No matching Understat file found for Joseph McGlynn. Skipping Joseph_McGlynn.csv.
# Merged and saved Ciaran_Clark.csv to merged_data/2021-22/DEF
# Merged and saved Jan_Bednarek.csv to merged_data/2021-22/DEF
# Merged and saved Erik_Lamela.csv to merged_data/2021-22/MID
# Merged and saved Dan_Gosling.csv to merged_data/2021-22/MID
# Merged and saved Dan_Burn.csv to merged_data/2021-22/DEF
# Merged and saved Isaac_Price.csv to merged_data/2021-22/MID
# Merged and saved Jean-Philippe_Mateta.csv to merged_data/2021-22/FWD
# No matching Understat file found for Rúben Santos Gato Alves Dias. Skipping Rúben_Santos_Gato_Alves_Dias.csv.
# No matching Understat file found for Tom Heaton. Skipping Tom_Heaton.csv.
# Merged and saved Allan_Saint-Maximin.csv to merged_data/2021-22/FWD
# Merged and saved Trent_Alexander-Arnold.csv to merged_data/2021-22/DEF
# Merged and saved Craig_Dawson.csv to merged_data/2021-22/DEF
# Merged and saved Ashley_Young.csv to merged_data/2021-22/DEF
# Merged and saved Emil_Krafth.csv to merged_data/2021-22/DEF
# Merged and saved Oleksandr_Zinchenko.csv to merged_data/2021-22/DEF
# Merged and saved Alireza_Jahanbakhsh.csv to merged_data/2021-22/MID
# No matching Understat file found for Kwadwo Baah. Skipping Kwadwo_Baah.csv.
# Merged and saved Jamaal_Lascelles.csv to merged_data/2021-22/DEF
# Merged and saved Joël_Veltman.csv to merged_data/2021-22/DEF
# Merged and saved Leander_Dendoncker.csv to merged_data/2021-22/MID
# Merged and saved Rob_Holding.csv to merged_data/2021-22/DEF
# Merged and saved Youri_Tielemans.csv to merged_data/2021-22/MID
# Merged and saved Pierre-Emile_Højbjerg.csv to merged_data/2021-22/MID
# Merged and saved Scott_Banks.csv to merged_data/2021-22/MID
# Merged and saved Jonas_Lössl.csv to merged_data/2021-22/GK
# Merged and saved Andre_Gray.csv to merged_data/2021-22/FWD
# Merged and saved Brandon_Williams.csv to merged_data/2021-22/DEF
# No matching Understat file found for Arthur Okonkwo. Skipping Arthur_Okonkwo.csv.
# Merged and saved Matthew_Lowton.csv to merged_data/2021-22/DEF
# No matching Understat file found for Louie Moulden. Skipping Louie_Moulden.csv.
# Merged and saved Japhet_Tanganga.csv to merged_data/2021-22/DEF
# Merged and saved Kristoffer_Klaesson.csv to merged_data/2021-22/GK
# Merged and saved Wayne_Hennessey.csv to merged_data/2021-22/GK
# Merged and saved Ruben_Loftus-Cheek.csv to merged_data/2021-22/MID
# Merged and saved John_McGinn.csv to merged_data/2021-22/MID
# No matching Understat file found for Omari Hutchinson. Skipping Omari_Hutchinson.csv.
# Merged and saved Kelechi_Iheanacho.csv to merged_data/2021-22/FWD
# Merged and saved Ashley_Fletcher.csv to merged_data/2021-22/FWD
# Merged and saved Shane_Duffy.csv to merged_data/2021-22/DEF
# No matching Understat file found for José Diogo Dalot Teixeira. Skipping José_Diogo_Dalot_Teixeira.csv.
# Merged and saved Rúnar_Alex_Rúnarsson.csv to merged_data/2021-22/GK
# Merged and saved Lewis_Bate.csv to merged_data/2021-22/MID
# No matching Understat file found for Bobby Thomas. Skipping Bobby_Thomas.csv.
# Merged and saved Jason_Steele.csv to merged_data/2021-22/GK
# Merged and saved Charlie_Taylor.csv to merged_data/2021-22/DEF
# No matching Understat file found for Ellery Balcombe. Skipping Ellery_Balcombe.csv.
# No matching Understat file found for Bernard Anício Caldeira Duarte. Skipping Bernard_Anício_Caldeira_Duarte.csv.
# No matching Understat file found for Hugo Bueno. Skipping Hugo_Bueno.csv.
# Merged and saved Jonathan_Rowe.csv to merged_data/2021-22/MID
# Merged and saved Demarai_Gray.csv to merged_data/2021-22/MID
# Merged and saved Matthew_Pollock.csv to merged_data/2021-22/DEF
# Merged and saved Amad_Diallo.csv to merged_data/2021-22/MID
# Merged and saved Vladimir_Coufal.csv to merged_data/2021-22/DEF
# Merged and saved Christoph_Zimmermann.csv to merged_data/2021-22/DEF
# Merged and saved Joelinton_Cássio_Apolinário_de_Lira.csv to merged_data/2021-22/FWD
# No matching Understat file found for Bruno André Cavaco Jordão. Skipping Bruno_André_Cavaco_Jordão.csv.
# Merged and saved Max_Kilman.csv to merged_data/2021-22/DEF
# Merged and saved Trevoh_Chalobah.csv to merged_data/2021-22/DEF
# No matching Understat file found for Dilan Markanday. Skipping Dilan_Markanday.csv.
# Merged and saved Tim_Iroegbunam.csv to merged_data/2021-22/MID
# Merged and saved Salomón_Rondón.csv to merged_data/2021-22/FWD
# Merged and saved Onel_Hernández.csv to merged_data/2021-22/MID
# Merged and saved Rico_Henry.csv to merged_data/2021-22/DEF
# Merged and saved Harvey_White.csv to merged_data/2021-22/MID
# Merged and saved Kaine_Hayden.csv to merged_data/2021-22/DEF
# Merged and saved Tyler_Morton.csv to merged_data/2021-22/MID
# No matching Understat file found for Adrián San Miguel del Castillo. Skipping Adrián_San_Miguel_del_Castillo.csv.
# Merged and saved Rhys_Williams.csv to merged_data/2021-22/DEF
# Merged and saved Jesse_Lingard.csv to merged_data/2021-22/MID
# Merged and saved Jannik_Vestergaard.csv to merged_data/2021-22/DEF
# Merged and saved Wout_Weghorst.csv to merged_data/2021-22/FWD
# Merged and saved Scott_McTominay.csv to merged_data/2021-22/MID
# Merged and saved Tyler_Roberts.csv to merged_data/2021-22/MID
# Merged and saved Zack_Steffen.csv to merged_data/2021-22/GK
# Merged and saved Taylor_Richards.csv to merged_data/2021-22/MID
# Merged and saved Ben_Johnson.csv to merged_data/2021-22/DEF
# No matching Understat file found for Salah-Eddine Oulad M'hand. Skipping Salah-Eddine_Oulad_M'hand.csv.
# Merged and saved Matt_Doherty.csv to merged_data/2021-22/DEF
# No matching Understat file found for Lucas Torreira. Skipping Lucas_Torreira.csv.
# No matching Understat file found for Alex Nicolao Telles. Skipping Alex_Nicolao_Telles.csv.
# Merged and saved Toby_Alderweireld.csv to merged_data/2021-22/DEF
# Merged and saved Kevin_Long.csv to merged_data/2021-22/DEF
# Merged and saved João_Virgínia.csv to merged_data/2021-22/GK
# Merged and saved Charlie_Whitaker.csv to merged_data/2021-22/MID
# Merged and saved David_Raya_Martin.csv to merged_data/2021-22/GK
# Merged and saved Anthony_Elanga.csv to merged_data/2021-22/MID
# Merged and saved Alex_Oxlade-Chamberlain.csv to merged_data/2021-22/MID
# Merged and saved Neco_Williams.csv to merged_data/2021-22/DEF
# Merged and saved Aaron_Connolly.csv to merged_data/2021-22/FWD
# No matching Understat file found for Jorge Luiz Frello Filho. Skipping Jorge_Luiz_Frello_Filho.csv.
# Merged and saved Ozan_Kabak.csv to merged_data/2021-22/DEF
# Merged and saved Miguel_Azeez.csv to merged_data/2021-22/MID
# Merged and saved Ben_Mee.csv to merged_data/2021-22/DEF
# Merged and saved Çaglar_Söyüncü.csv to merged_data/2021-22/DEF
# No matching Understat file found for Francisco Jorge Tomás Oliveira. Skipping Francisco_Jorge_Tomás_Oliveira.csv.
# Merged and saved Mathias_Normann.csv to merged_data/2021-22/MID
# Merged and saved Alexandre_Lacazette.csv to merged_data/2021-22/FWD
# Merged and saved Patrick_Cutrone.csv to merged_data/2021-22/FWD
# Merged and saved Shane_Long.csv to merged_data/2021-22/FWD
# No matching Understat file found for Samuel Edozie. Skipping Samuel_Edozie.csv.
# Merged and saved Chem_Campbell.csv to merged_data/2021-22/MID
# No matching Understat file found for Rúben Diogo da Silva Neves. Skipping Rúben_Diogo_da_Silva_Neves.csv.
# Merged and saved Rodrigo_Bentancur.csv to merged_data/2021-22/MID
# Merged and saved Marcus_Rashford.csv to merged_data/2021-22/MID
# Merged and saved Federico_Fernández.csv to merged_data/2021-22/DEF
# Merged and saved Robert_Sánchez.csv to merged_data/2021-22/GK
# Merged and saved Marc_Leonard.csv to merged_data/2021-22/MID
# Merged and saved Wilfried_Zaha.csv to merged_data/2021-22/MID
# Merged and saved Nicolas_Nkoulou.csv to merged_data/2021-22/DEF
# No matching Understat file found for Florin Andone. Skipping Florin_Andone.csv.
# Merged and saved Antonio_Rüdiger.csv to merged_data/2021-22/DEF
# Merged and saved Steven_Alzate.csv to merged_data/2021-22/MID
# Merged and saved Frank_Onyeka.csv to merged_data/2021-22/MID
# No matching Understat file found for Marc Navarro. Skipping Marc_Navarro.csv.
# No matching Understat file found for Mazeed Ogungbo. Skipping Mazeed_Ogungbo.csv.
# No matching Understat file found for Tommi O'Reilly. Skipping Tommi_O'Reilly.csv.
# No matching Understat file found for Marcelo de Araújo Pitaluga Filho. Skipping Marcelo_de_Araújo_Pitaluga_Filho.csv.
# Merged and saved Juan_Mata.csv to merged_data/2021-22/MID
# Merged and saved Romain_Saïss.csv to merged_data/2021-22/DEF
# Merged and saved Thiago_Alcántara_do_Nascimento.csv to merged_data/2021-22/MID
# Merged and saved James_McArthur.csv to merged_data/2021-22/MID
# No matching Understat file found for Raphael Dias Belloli. Skipping Raphael_Dias_Belloli.csv.
# Merged and saved Ben_Foster.csv to merged_data/2021-22/GK
# Merged and saved Leo_Fuhr_Hjelde.csv to merged_data/2021-22/DEF
# Merged and saved Christian_Pulisic.csv to merged_data/2021-22/MID
# No matching Understat file found for Andreas Söndergaard. Skipping Andreas_Söndergaard.csv.
# No matching Understat file found for Pedro Lomba Neto. Skipping Pedro_Lomba_Neto.csv.
# Merged and saved Calum_Chambers.csv to merged_data/2021-22/DEF
# No matching Understat file found for Allan Marques Loureiro. Skipping Allan_Marques_Loureiro.csv.
# Merged and saved Mohamed_Salah.csv to merged_data/2021-22/MID
# Merged and saved Jean-Philippe_Gbamin.csv to merged_data/2021-22/MID
# Merged and saved Vitalii_Mykolenko.csv to merged_data/2021-22/DEF
# Merged and saved Paul_Dummett.csv to merged_data/2021-22/DEF
# Merged and saved Lewis_Brunt.csv to merged_data/2021-22/MID
# Merged and saved Ryan_Alebiosu.csv to merged_data/2021-22/DEF
# Merged and saved Jamal_Lewis.csv to merged_data/2021-22/DEF
# Merged and saved Malang_Sarr.csv to merged_data/2021-22/DEF
# Merged and saved Maxwel_Cornet.csv to merged_data/2021-22/MID
# No matching Understat file found for Björn Engels. Skipping Björn_Engels.csv.
# Merged and saved Mason_Greenwood.csv to merged_data/2021-22/MID
# No matching Understat file found for Richarlison de Andrade. Skipping Richarlison_de_Andrade.csv.
# No matching Understat file found for Kepa Arrizabalaga. Skipping Kepa_Arrizabalaga.csv.
# No matching Understat file found for Thomas McGill. Skipping Thomas_McGill.csv.
# Merged and saved William_Saliba.csv to merged_data/2021-22/DEF
# Merged and saved David_de_Gea.csv to merged_data/2021-22/GK
# Merged and saved Ezri_Konsa_Ngoyo.csv to merged_data/2021-22/DEF
# No matching Understat file found for Tayo Adaramola. Skipping Tayo_Adaramola.csv.
# Merged and saved Kyle_Walker-Peters.csv to merged_data/2021-22/DEF
# Merged and saved James_Milner.csv to merged_data/2021-22/MID
# Merged and saved Andi_Zeqiri.csv to merged_data/2021-22/FWD
# Merged and saved Moussa_Djenepo.csv to merged_data/2021-22/MID
# Merged and saved Edward_Nketiah.csv to merged_data/2021-22/FWD
# No matching Understat file found for Mbwana Ally Samatta. Skipping Mbwana_Ally_Samatta.csv.
# Merged and saved Danny_Welbeck.csv to merged_data/2021-22/FWD
# Merged and saved Robert_Elliot.csv to merged_data/2021-22/GK
# Merged and saved Jeffrey_Schlupp.csv to merged_data/2021-22/MID
# Merged and saved Ayoze_Pérez.csv to merged_data/2021-22/MID
# Merged and saved Tariqe_Fosu-Henry.csv to merged_data/2021-22/MID
# Merged and saved Héctor_Bellerín.csv to merged_data/2021-22/DEF
# No matching Understat file found for Thomas Dickson-Peters. Skipping Thomas_Dickson-Peters.csv.
# No matching Understat file found for Thiago Emiliano da Silva. Skipping Thiago_Emiliano_da_Silva.csv.
# Merged and saved Joshua_Sargent.csv to merged_data/2021-22/FWD
# Merged and saved Nathan_Collins.csv to merged_data/2021-22/DEF
# Merged and saved Dennis_Praet.csv to merged_data/2021-22/MID
# No matching Understat file found for Harry Tyrer. Skipping Harry_Tyrer.csv.
# Merged and saved Conor_Bradley.csv to merged_data/2021-22/DEF
# Merged and saved Bryan_Mbeumo.csv to merged_data/2021-22/MID
# Merged and saved Kieran_Tierney.csv to merged_data/2021-22/DEF
# Merged and saved Callum_Hudson-Odoi.csv to merged_data/2021-22/MID
# Merged and saved Jacob_Sørensen.csv to merged_data/2021-22/DEF
# Merged and saved Teemu_Pukki.csv to merged_data/2021-22/FWD
# Merged and saved Sonny_Perkins.csv to merged_data/2021-22/MID
# Merged and saved César_Azpilicueta.csv to merged_data/2021-22/DEF
# Merged and saved Emmanuel_Dennis.csv to merged_data/2021-22/FWD
# Merged and saved Sam_Byram.csv to merged_data/2021-22/DEF
# No matching Understat file found for Armstrong Oko-Flex. Skipping Armstrong_Oko-Flex.csv.
# Merged and saved Liam_McCarron.csv to merged_data/2021-22/MID
# Merged and saved James_Rodríguez.csv to merged_data/2021-22/MID
# Merged and saved Dean_Henderson.csv to merged_data/2021-22/GK
# Merged and saved Tim_Krul.csv to merged_data/2021-22/GK
# Merged and saved Luke_Cundle.csv to merged_data/2021-22/MID
# Merged and saved Nick_Pope.csv to merged_data/2021-22/GK
# Merged and saved Tom_Cleverley.csv to merged_data/2021-22/MID
# Merged and saved Tanguy_Ndombele.csv to merged_data/2021-22/MID
# Merged and saved Theo_Walcott.csv to merged_data/2021-22/MID
# Merged and saved Yan_Valery.csv to merged_data/2021-22/DEF
# Merged and saved Folarin_Balogun.csv to merged_data/2021-22/FWD
# No matching Understat file found for Ederson Santana de Moraes. Skipping Ederson_Santana_de_Moraes.csv.
# Merged and saved Jürgen_Locadia.csv to merged_data/2021-22/FWD
# Merged and saved Adam_Lallana.csv to merged_data/2021-22/MID
# Merged and saved Wilfred_Ndidi.csv to merged_data/2021-22/MID
# No matching Understat file found for Lamare Bogarde. Skipping Lamare_Bogarde.csv.
# Merged and saved Victor_Lindelöf.csv to merged_data/2021-22/DEF
# Merged and saved Rodrigo_Hernandez.csv to merged_data/2021-22/MID
# Merged and saved Joseph_Willock.csv to merged_data/2021-22/MID
# Merged and saved Tammy_Abraham.csv to merged_data/2021-22/FWD
# No matching Understat file found for Yerson Mosquera Valdelamar. Skipping Yerson_Mosquera_Valdelamar.csv.
# No matching Understat file found for Eldin Jakupovic. Skipping Eldin_Jakupovic.csv.
# Merged and saved Tomas_Soucek.csv to merged_data/2021-22/MID
# Merged and saved Cristiano_Ronaldo_dos_Santos_Aveiro.csv to merged_data/2021-22/FWD
# Merged and saved Ivan_Toney.csv to merged_data/2021-22/FWD
# Merged and saved Matej_Vydra.csv to merged_data/2021-22/FWD
# No matching Understat file found for Jarosław Jach. Skipping Jarosław_Jach.csv.
# Merged and saved Declan_Rice.csv to merged_data/2021-22/MID
# Merged and saved Anthony_Mancini.csv to merged_data/2021-22/MID
# Merged and saved Oliver_Skipp.csv to merged_data/2021-22/MID
# Merged and saved Bertrand_Traoré.csv to merged_data/2021-22/MID
# Merged and saved Boubakary_Soumaré.csv to merged_data/2021-22/MID
# Merged and saved Connor_Roberts.csv to merged_data/2021-22/DEF
# Merged and saved Nélson_Cabral_Semedo.csv to merged_data/2021-22/DEF
# No matching Understat file found for Tiago Çukur. Skipping Tiago_Çukur.csv.
# Merged and saved Moise_Kean.csv to merged_data/2021-22/FWD
# Merged and saved Marc_Guéhi.csv to merged_data/2021-22/DEF
# Merged and saved Matthew_Longstaff.csv to merged_data/2021-22/MID
# Merged and saved Jamie_Shackleton.csv to merged_data/2021-22/MID
# Merged and saved Alejandro_Garnacho_Ferreyra.csv to merged_data/2021-22/MID
# Merged and saved Scott_Carson.csv to merged_data/2021-22/GK
# No matching Understat file found for Frédéric Guilbert. Skipping Frédéric_Guilbert.csv.
# No matching Understat file found for Willian Borges Da Silva. Skipping Willian_Borges_Da_Silva.csv.
# Merged and saved Eric_Dier.csv to merged_data/2021-22/DEF
# Merged and saved Raphaël_Varane.csv to merged_data/2021-22/DEF
# No matching Understat file found for Kjell Scherpen. Skipping Kjell_Scherpen.csv.
# Merged and saved Kortney_Hause.csv to merged_data/2021-22/DEF
# Merged and saved Charlie_Goode.csv to merged_data/2021-22/DEF
# No matching Understat file found for Ricardo Domingos Barbosa Pereira. Skipping Ricardo_Domingos_Barbosa_Pereira.csv.
# Merged and saved Dwight_McNeil.csv to merged_data/2021-22/MID
# Merged and saved Vicente_Guaita.csv to merged_data/2021-22/GK
# Merged and saved Sergi_Canós.csv to merged_data/2021-22/MID
# Merged and saved Harry_Maguire.csv to merged_data/2021-22/DEF
# No matching Understat file found for Andy Lonergan. Skipping Andy_Lonergan.csv.
# Merged and saved Konstantinos_Mavropanos.csv to merged_data/2021-22/DEF
# Merged and saved Davy_Pröpper.csv to merged_data/2021-22/MID
# Merged and saved Isaac_Hayden.csv to merged_data/2021-22/MID
# No matching Understat file found for Alfie Devine. Skipping Alfie_Devine.csv.
# Merged and saved Max_Aarons.csv to merged_data/2021-22/DEF
# Merged and saved Emiliano_Martínez.csv to merged_data/2021-22/GK
# Merged and saved James_Justin.csv to merged_data/2021-22/DEF
# Merged and saved Luke_Ayling.csv to merged_data/2021-22/DEF
# ...
# Merged and saved Kenny_Tete.csv to merged_data/2023-24/DEF
# No matching Understat file found for Diogo Teixeira da Silva. Skipping Diogo_Teixeira_da_Silva.csv.
# No matching Understat file found for Emerson Leite de Souza Junior. Skipping Emerson_Leite_de_Souza_Junior.csv.
# Merged and saved Alex_Scott.csv to merged_data/2023-24/MID
# Merged and saved Tom_King.csv to merged_data/2023-24/GK
# Merged and saved Dan_Potts.csv to merged_data/2023-24/DEF
# Merged and saved Chris_Basham.csv to merged_data/2023-24/DEF
# Merged and saved Hannes_Delcroix.csv to merged_data/2023-24/DEF
# Merged and saved David_Raya_Martin.csv to merged_data/2023-24/GK
# Merged and saved Anthony_Elanga.csv to merged_data/2023-24/MID
# No matching Understat file found for Noël Atom. Skipping Noël_Atom.csv.
# Merged and saved Valintino_Adedokun.csv to merged_data/2023-24/DEF
# Merged and saved Neco_Williams.csv to merged_data/2023-24/DEF
# Merged and saved Youssef_Ramalho_Chermiti.csv to merged_data/2023-24/FWD
# No matching Understat file found for Aaron Connolly. Skipping Aaron_Connolly.csv.
# No matching Understat file found for Jorge Luiz Frello Filho. Skipping Jorge_Luiz_Frello_Filho.csv.
# Merged and saved Ben_Mee.csv to merged_data/2023-24/DEF
# No matching Understat file found for Jonathan Panzo. Skipping Jonathan_Panzo.csv.
# Merged and saved Mark_Flekken.csv to merged_data/2023-24/GK
# No matching Understat file found for Francisco Jorge Tomás Oliveira. Skipping Francisco_Jorge_Tomás_Oliveira.csv.
# Merged and saved Naouirou_Ahamada.csv to merged_data/2023-24/MID
# Merged and saved Mason_Burstow.csv to merged_data/2023-24/FWD
# No matching Understat file found for Wesley Moraes Ferreira da Silva. Skipping Wesley_Moraes_Ferreira_da_Silva.csv.
# No matching Understat file found for Darko Churlinov. Skipping Darko_Churlinov.csv.
# No matching Understat file found for Luc De Fougerolles. Skipping Luc_De_Fougerolles.csv.
# Merged and saved Lewis_Warrington.csv to merged_data/2023-24/MID
# Merged and saved Justin_Hubner.csv to merged_data/2023-24/DEF
# No matching Understat file found for Luke McNally. Skipping Luke_McNally.csv.
# Merged and saved Oscar_Bobb.csv to merged_data/2023-24/MID
# Merged and saved Aaron_Hickey.csv to merged_data/2023-24/DEF
# Merged and saved Rodrigo_Bentancur.csv to merged_data/2023-24/MID
# No matching Understat file found for Andreas Hoelgebaum Pereira. Skipping Andreas_Hoelgebaum_Pereira.csv.
# Merged and saved Ben_Parkinson.csv to merged_data/2023-24/FWD
# Merged and saved Marcus_Rashford.csv to merged_data/2023-24/MID
# Merged and saved Jeremy_Sarmiento_Morante.csv to merged_data/2023-24/MID
# Merged and saved Antonee_Robinson.csv to merged_data/2023-24/DEF
# Merged and saved Robert_Sánchez.csv to merged_data/2023-24/GK
# No matching Understat file found for Aidan Francis-Clarke. Skipping Aidan_Francis-Clarke.csv.
# Merged and saved Nicolás_Domínguez.csv to merged_data/2023-24/MID
# Merged and saved Javier_Manquillo_Gaitán.csv to merged_data/2023-24/DEF
# Merged and saved Alex_Murphy.csv to merged_data/2023-24/DEF
# No matching Understat file found for Steven Alzate. Skipping Steven_Alzate.csv.
# Merged and saved Valentín_Barco.csv to merged_data/2023-24/DEF
# Merged and saved Frank_Onyeka.csv to merged_data/2023-24/MID
# No matching Understat file found for Mahamadou Susoho. Skipping Mahamadou_Susoho.csv.
# No matching Understat file found for Tommi O'Reilly. Skipping Tommi_O'Reilly.csv.
# No matching Understat file found for Marcelo de Araújo Pitaluga Filho. Skipping Marcelo_de_Araújo_Pitaluga_Filho.csv.
# Merged and saved João_Palhinha_Gonçalves.csv to merged_data/2023-24/MID
# Merged and saved Thiago_Alcántara_do_Nascimento.csv to merged_data/2023-24/MID
# Merged and saved Hjalmar_Ekdal.csv to merged_data/2023-24/DEF
# Merged and saved Enes_Ünal.csv to merged_data/2023-24/FWD
# Merged and saved Christian_Pulisic.csv to merged_data/2023-24/MID
# Merged and saved Joe_Gomez.csv to merged_data/2023-24/DEF
# Merged and saved Devan_Tanton.csv to merged_data/2023-24/DEF
# Merged and saved Simon_Adingra.csv to merged_data/2023-24/MID
# Merged and saved Morgan_Rogers.csv to merged_data/2023-24/MID
# No matching Understat file found for Pedro Lomba Neto. Skipping Pedro_Lomba_Neto.csv.
# Merged and saved Destiny_Udogie.csv to merged_data/2023-24/DEF
# Merged and saved Calum_Chambers.csv to merged_data/2023-24/DEF
# Merged and saved Mohamed_Salah.csv to merged_data/2023-24/MID
# No matching Understat file found for Kell Watts. Skipping Kell_Watts.csv.
# Merged and saved Jean-Philippe_Gbamin.csv to merged_data/2023-24/MID
# No matching Understat file found for Admiral Muskwe. Skipping Admiral_Muskwe.csv.
# Merged and saved Vitalii_Mykolenko.csv to merged_data/2023-24/DEF
# Merged and saved Gabriel_Martinelli_Silva.csv to merged_data/2023-24/MID
# Merged and saved Paul_Dummett.csv to merged_data/2023-24/DEF
# Merged and saved Tom_Cairney.csv to merged_data/2023-24/MID
# Merged and saved Jacob_Brown.csv to merged_data/2023-24/FWD
# Merged and saved Harrison_Reed.csv to merged_data/2023-24/MID
# Merged and saved Jamal_Lewis.csv to merged_data/2023-24/DEF
# No matching Understat file found for Malang Sarr. Skipping Malang_Sarr.csv.
# Merged and saved Maxwel_Cornet.csv to merged_data/2023-24/MID
# Merged and saved Joe_Whitworth.csv to merged_data/2023-24/GK
# No matching Understat file found for Richarlison de Andrade. Skipping Richarlison_de_Andrade.csv.
# No matching Understat file found for Enock Agyei. Skipping Enock_Agyei.csv.
# Merged and saved Joe_Hugill.csv to merged_data/2023-24/FWD
# No matching Understat file found for Kepa Arrizabalaga. Skipping Kepa_Arrizabalaga.csv.
# Merged and saved William_Saliba.csv to merged_data/2023-24/DEF
# Merged and saved Calvin_Bassey.csv to merged_data/2023-24/DEF
# Merged and saved Ezri_Konsa_Ngoyo.csv to merged_data/2023-24/DEF
# No matching Understat file found for Tayo Adaramola. Skipping Tayo_Adaramola.csv.
# Merged and saved James_Milner.csv to merged_data/2023-24/MID
# Merged and saved Mark_O’Mahony.csv to merged_data/2023-24/FWD
# Merged and saved Joseph_Johnson.csv to merged_data/2023-24/DEF
# No matching Understat file found for Andi Zeqiri. Skipping Andi_Zeqiri.csv.
# No matching Understat file found for Pape Matar Sarr. Skipping Pape_Matar_Sarr.csv.
# Merged and saved Marek_Rodák.csv to merged_data/2023-24/GK
# Merged and saved Ivan_Perišić.csv to merged_data/2023-24/DEF
# Merged and saved James_Wright.csv to merged_data/2023-24/GK
# Merged and saved Ethan_Nwaneri.csv to merged_data/2023-24/MID
# Merged and saved Kevin_Mbabu.csv to merged_data/2023-24/DEF
# No matching Understat file found for Ademola Ola-Adebomi. Skipping Ademola_Ola-Adebomi.csv.
# Merged and saved Danny_Welbeck.csv to merged_data/2023-24/FWD
# Merged and saved André_Onana.csv to merged_data/2023-24/GK
# Merged and saved Joe_Gauci.csv to merged_data/2023-24/GK
# Merged and saved Lewis_Orford.csv to merged_data/2023-24/MID
# Merged and saved Jeffrey_Schlupp.csv to merged_data/2023-24/MID
# No matching Understat file found for Diego Manuel Jadon da Silva Moreira. Skipping Diego_Manuel_Jadon_da_Silva_Moreira.csv.
# No matching Understat file found for Lawrence Vigouroux. Skipping Lawrence_Vigouroux.csv.
# Merged and saved Benoît_Badiashile.csv to merged_data/2023-24/DEF
# Merged and saved Luca_Koleosho.csv to merged_data/2023-24/MID
# No matching Understat file found for Josh Powell. Skipping Josh_Powell.csv.
# Merged and saved Kiano_Dyer.csv to merged_data/2023-24/MID
# No matching Understat file found for Thiago Emiliano da Silva. Skipping Thiago_Emiliano_da_Silva.csv.
# Merged and saved Nathan_Collins.csv to merged_data/2023-24/DEF
# Merged and saved Auston_Trusty.csv to merged_data/2023-24/DEF
# Merged and saved Mykhailo_Mudryk.csv to merged_data/2023-24/MID
# No matching Understat file found for Terence Kongolo. Skipping Terence_Kongolo.csv.
# No matching Understat file found for Kaine Kesler-Hayden. Skipping Kaine_Kesler-Hayden.csv.
# Merged and saved Conor_Bradley.csv to merged_data/2023-24/DEF
# No matching Understat file found for Murillo Santiago Costa dos Santos. Skipping Murillo_Santiago_Costa_dos_Santos.csv.
# Merged and saved Bryan_Mbeumo.csv to merged_data/2023-24/MID
# Merged and saved Kieran_Tierney.csv to merged_data/2023-24/DEF
# Merged and saved Callum_Hudson-Odoi.csv to merged_data/2023-24/MID
# No matching Understat file found for Matheus Santos Carneiro Da Cunha. Skipping Matheus_Santos_Carneiro_Da_Cunha.csv.
# No matching Understat file found for Garang Kuol. Skipping Garang_Kuol.csv.
# Merged and saved Ty_Barnett.csv to merged_data/2023-24/MID
# Merged and saved Moisés_Caicedo_Corozo.csv to merged_data/2023-24/MID
# Merged and saved Enso_González.csv to merged_data/2023-24/MID
# No matching Understat file found for Travis Hernes. Skipping Travis_Hernes.csv.
# Merged and saved Leon_Chiwome.csv to merged_data/2023-24/FWD
# Merged and saved César_Azpilicueta.csv to merged_data/2023-24/DEF
# No matching Understat file found for Allan Campbell. Skipping Allan_Campbell.csv.
# Merged and saved Emmanuel_Dennis.csv to merged_data/2023-24/FWD
# Merged and saved Dean_Henderson.csv to merged_data/2023-24/GK
# Merged and saved Emiliano_Marcondes.csv to merged_data/2023-24/MID
# Merged and saved Axel_Disasi.csv to merged_data/2023-24/DEF
# Merged and saved Sander_Berge.csv to merged_data/2023-24/MID
# No matching Understat file found for Tim Krul. Skipping Tim_Krul.csv.
# No matching Understat file found for Luke Cundle. Skipping Luke_Cundle.csv.
# Merged and saved Nick_Pope.csv to merged_data/2023-24/GK
# No matching Understat file found for Braian Ojeda Rodríguez. Skipping Braian_Ojeda_Rodríguez.csv.
# Merged and saved Alfie_Doughty.csv to merged_data/2023-24/DEF
# No matching Understat file found for Folarin Balogun. Skipping Folarin_Balogun.csv.
# No matching Understat file found for Ederson Santana de Moraes. Skipping Ederson_Santana_de_Moraes.csv.
# Merged and saved Diego_Carlos_Santos_Silva.csv to merged_data/2023-24/DEF
# Merged and saved Adam_Lallana.csv to merged_data/2023-24/MID
# Merged and saved David_Brooks.csv to merged_data/2023-24/MID
# Merged and saved Joe_Hodge.csv to merged_data/2023-24/MID
# Merged and saved Ethan_Wheatley.csv to merged_data/2023-24/FWD
# Merged and saved Rasmus_Højlund.csv to merged_data/2023-24/FWD
# Merged and saved Harry_Amass.csv to merged_data/2023-24/DEF
# Merged and saved Victor_Lindelöf.csv to merged_data/2023-24/DEF
# Merged and saved Arnaut_Danjuma_Groeneveld.csv to merged_data/2023-24/MID
# Merged and saved Rodrigo_Hernandez.csv to merged_data/2023-24/MID
# No matching Understat file found for André Tavares Gomes. Skipping André_Tavares_Gomes.csv.
# Merged and saved Sam_Curtis.csv to merged_data/2023-24/DEF
# Merged and saved Taiwo_Awoniyi.csv to merged_data/2023-24/FWD
# No matching Understat file found for Carlos Henrique Casimiro. Skipping Carlos_Henrique_Casimiro.csv.
# Merged and saved Noha_Lemina.csv to merged_data/2023-24/MID
# Merged and saved Pau_Torres.csv to merged_data/2023-24/DEF
# Merged and saved Djed_Spence.csv to merged_data/2023-24/DEF
# Merged and saved Louie_Watson.csv to merged_data/2023-24/MID
# Merged and saved Ivan_Toney.csv to merged_data/2023-24/FWD
# Merged and saved Joe_Worrall.csv to merged_data/2023-24/DEF
# Merged and saved Declan_Rice.csv to merged_data/2023-24/MID
# Merged and saved Carlos_Baleba.csv to merged_data/2023-24/MID
# Merged and saved Oliver_Skipp.csv to merged_data/2023-24/MID
# Merged and saved Bertrand_Traoré.csv to merged_data/2023-24/MID
# Merged and saved Pablo_Fornals_Malla.csv to merged_data/2023-24/MID
# Merged and saved Facundo_Pellistri_Rebollo.csv to merged_data/2023-24/MID
# No matching Understat file found for Fodé Ballo-Touré. Skipping Fodé_Ballo-Touré.csv.
# Merged and saved Anis_Slimane.csv to merged_data/2023-24/MID
# Merged and saved Connor_Roberts.csv to merged_data/2023-24/DEF
# Merged and saved Nélson_Cabral_Semedo.csv to merged_data/2023-24/DEF
# Merged and saved Giovanni_Reyna.csv to merged_data/2023-24/MID
# Merged and saved Lyle_Foster.csv to merged_data/2023-24/FWD
# Merged and saved Joseph_Anang.csv to merged_data/2023-24/GK
# Merged and saved Marc_Guéhi.csv to merged_data/2023-24/DEF
# Merged and saved Scott_Carson.csv to merged_data/2023-24/GK
# Merged and saved Antwoine_Hackford.csv to merged_data/2023-24/FWD
# Merged and saved Sasa_Kalajdzic.csv to merged_data/2023-24/FWD
# Merged and saved Guglielmo_Vicario.csv to merged_data/2023-24/GK
# Merged and saved Yasser_Larouci.csv to merged_data/2023-24/DEF
# No matching Understat file found for Willian Borges da Silva. Skipping Willian_Borges_da_Silva.csv.
# Merged and saved Eric_Dier.csv to merged_data/2023-24/DEF
# Merged and saved Raphaël_Varane.csv to merged_data/2023-24/DEF
# No matching Understat file found for Leigh Kavanagh. Skipping Leigh_Kavanagh.csv.
# Merged and saved Jaidon_Anthony.csv to merged_data/2023-24/MID
# No matching Understat file found for Kjell Scherpen. Skipping Kjell_Scherpen.csv.
# No matching Understat file found for Kortney Hause. Skipping Kortney_Hause.csv.
# Merged and saved Charlie_Goode.csv to merged_data/2023-24/DEF
# Merged and saved Micky_van_de_Ven.csv to merged_data/2023-24/DEF
# Merged and saved Dwight_McNeil.csv to merged_data/2023-24/MID
# Merged and saved Vicente_Guaita.csv to merged_data/2023-24/GK
# Merged and saved Brennan_Johnson.csv to merged_data/2023-24/MID
# Merged and saved Yegor_Yarmolyuk.csv to merged_data/2023-24/MID
# Merged and saved Harry_Maguire.csv to merged_data/2023-24/DEF
# No matching Understat file found for Andy Lonergan. Skipping Andy_Lonergan.csv.
# Merged and saved Konstantinos_Mavropanos.csv to merged_data/2023-24/DEF
# No matching Understat file found for Fábio Ferreira Vieira. Skipping Fábio_Ferreira_Vieira.csv.
# Merged and saved Keane_Lewis-Potter.csv to merged_data/2023-24/MID
# Merged and saved Isaac_Hayden.csv to merged_data/2023-24/MID
# Merged and saved Max_Aarons.csv to merged_data/2023-24/DEF
# Merged and saved Jhon_Durán.csv to merged_data/2023-24/FWD
# No matching Understat file found for Lucas Bergström. Skipping Lucas_Bergström.csv.
# Merged and saved Mario_Lemina.csv to merged_data/2023-24/MID
# Merged and saved Boubacar_Kamara.csv to merged_data/2023-24/MID
# Merged and saved Christian_Chigozie.csv to merged_data/2023-24/DEF
# Merged and saved Caoimhin_Kelleher.csv to merged_data/2023-24/GK
# Merged and saved Ryan_Fredericks.csv to merged_data/2023-24/DEF
# Merged and saved Lewis_Cook.csv to merged_data/2023-24/MID
# Merged and saved Bernd_Leno.csv to merged_data/2023-24/GK
# No matching Understat file found for Michał Karbownik. Skipping Michał_Karbownik.csv.
# Merged and saved Matheus_França_de_Oliveira.csv to merged_data/2023-24/MID
# Merged and saved Andrew_Robertson.csv to merged_data/2023-24/DEF
# Merged and saved Solly_March.csv to merged_data/2023-24/MID
# No matching Understat file found for Louie Marsh. Skipping Louie_Marsh.csv.
# Merged and saved Daiki_Hashioka.csv to merged_data/2023-24/DEF
# No matching Understat file found for Tanguy Ndombélé Alvaro. Skipping Tanguy_Ndombélé_Alvaro.csv.
# Merged and saved Mike_Trésor.csv to merged_data/2023-24/MID
# No matching Understat file found for Alisson Ramses Becker. Skipping Alisson_Ramses_Becker.csv.
# Merged and saved Serge_Aurier.csv to merged_data/2023-24/DEF
# No matching Understat file found for João Victor Gomes da Silva. Skipping João_Victor_Gomes_da_Silva.csv.
# Merged and saved Jordan_Pickford.csv to merged_data/2023-24/GK
# Merged and saved Nathan_Redmond.csv to merged_data/2023-24/MID
# No matching Understat file found for Mads Bidstrup. Skipping Mads_Bidstrup.csv.
# Merged and saved Micah_Hamilton.csv to merged_data/2023-24/MID
# Merged and saved Bukayo_Saka.csv to merged_data/2023-24/MID
# Merged and saved Evan_Ferguson.csv to merged_data/2023-24/FWD
# Merged and saved Ben_Jackson.csv to merged_data/2023-24/DEF
# Merged and saved Josh_Acheampong.csv to merged_data/2023-24/DEF
# Merged and saved Wataru_Endo.csv to merged_data/2023-24/MID
# No matching Understat file found for Myles Lewis-Skelly. Skipping Myles_Lewis-Skelly.csv.
# Merged and saved Malo_Gusto.csv to merged_data/2023-24/DEF
# Merged and saved Jacob_Bruun_Larsen.csv to merged_data/2023-24/MID
# No matching Understat file found for Toby Collyer. Skipping Toby_Collyer.csv.

# %%
#RESTRUCTURING THE FWD FOLDER DATA
import os
import pandas as pd

# Define the path to the FWD folder in each season
merged_data_dir = 'merged_data'
seasons = ['2021-22', '2022-23', '2023-24']
fwd_folder = 'FWD'

# Columns to drop
columns_to_drop = ['position_x', 'kickoff_time', 'time']

# Column order as specified, including 'starts' as optional
desired_column_order = [
    'name', 'team', 'opponent_team', 'date', 'was_home', 'position_y', 'minutes', 'goals', 'xG', 'assists', 'xA',
    'total_points', 'shots', 'key_passes', 'ict_index', 'bonus', 'starts'
]

# Loop through each season and process the FWD folder
for season in seasons:
    fwd_dir = os.path.join(merged_data_dir, season, fwd_folder)
    
    if os.path.isdir(fwd_dir):
        for csv_file in os.listdir(fwd_dir):
            if csv_file.endswith('.csv'):
                file_path = os.path.join(fwd_dir, csv_file)
                
                # Read the CSV file
                df = pd.read_csv(file_path)
                
                # Step 1: Drop the unnecessary columns
                df = df.drop(columns=[col for col in columns_to_drop if col in df.columns], errors='ignore')
                
                # Step 2: Convert 'starts' column to boolean (True/False) if it exists
                if 'starts' in df.columns:
                    df['starts'] = df['starts'].apply(lambda x: True if x == 1 else False)
                else:
                    print(f"'starts' column not found in {csv_file}, skipping the conversion.")
                
                # Step 3: Reorder the columns, but first check for missing columns
                existing_columns = [col for col in desired_column_order if col in df.columns]
                df = df[existing_columns]
                
                # Step 4: Rename 'position_y' to 'position' if 'position_y' exists
                if 'position_y' in df.columns:
                    df = df.rename(columns={'position_y': 'position'})
                
                # Save the modified CSV file back
                df.to_csv(file_path, index=False)
                print(f"Processed and saved {csv_file} in {fwd_dir}")
# Out:
# 'starts' column not found in Isaac_Success_Ajayi.csv, skipping the conversion.
# Processed and saved Isaac_Success_Ajayi.csv in merged_data/2021-22/FWD
# 'starts' column not found in Jamie_Vardy.csv, skipping the conversion.
# Processed and saved Jamie_Vardy.csv in merged_data/2021-22/FWD
# 'starts' column not found in Jordan_Ayew.csv, skipping the conversion.
# Processed and saved Jordan_Ayew.csv in merged_data/2021-22/FWD
# 'starts' column not found in Joshua_King.csv, skipping the conversion.
# Processed and saved Joshua_King.csv in merged_data/2021-22/FWD
# 'starts' column not found in Odsonne_Edouard.csv, skipping the conversion.
# Processed and saved Odsonne_Edouard.csv in merged_data/2021-22/FWD
# 'starts' column not found in Pierre-Emerick_Aubameyang.csv, skipping the conversion.
# Processed and saved Pierre-Emerick_Aubameyang.csv in merged_data/2021-22/FWD
# 'starts' column not found in Juan_Camilo_Hernández_Suárez.csv, skipping the conversion.
# Processed and saved Juan_Camilo_Hernández_Suárez.csv in merged_data/2021-22/FWD
# 'starts' column not found in Harry_Kane.csv, skipping the conversion.
# Processed and saved Harry_Kane.csv in merged_data/2021-22/FWD
# 'starts' column not found in Cameron_Archer.csv, skipping the conversion.
# Processed and saved Cameron_Archer.csv in merged_data/2021-22/FWD
# 'starts' column not found in Michael_Obafemi.csv, skipping the conversion.
# Processed and saved Michael_Obafemi.csv in merged_data/2021-22/FWD
# 'starts' column not found in Lewis_Richardson.csv, skipping the conversion.
# Processed and saved Lewis_Richardson.csv in merged_data/2021-22/FWD
# 'starts' column not found in Jack_Grieves.csv, skipping the conversion.
# Processed and saved Jack_Grieves.csv in merged_data/2021-22/FWD
# 'starts' column not found in Michail_Antonio.csv, skipping the conversion.
# Processed and saved Michail_Antonio.csv in merged_data/2021-22/FWD
# 'starts' column not found in Keinan_Davis.csv, skipping the conversion.
# Processed and saved Keinan_Davis.csv in merged_data/2021-22/FWD
# 'starts' column not found in Lewis_Dobbin.csv, skipping the conversion.
# Processed and saved Lewis_Dobbin.csv in merged_data/2021-22/FWD
# 'starts' column not found in Jordan_Hugill.csv, skipping the conversion.
# Processed and saved Jordan_Hugill.csv in merged_data/2021-22/FWD
# 'starts' column not found in Liam_Delap.csv, skipping the conversion.
# Processed and saved Liam_Delap.csv in merged_data/2021-22/FWD
# 'starts' column not found in Chris_Wood.csv, skipping the conversion.
# Processed and saved Chris_Wood.csv in merged_data/2021-22/FWD
# 'starts' column not found in Nathan_Young-Coombes.csv, skipping the conversion.
# Processed and saved Nathan_Young-Coombes.csv in merged_data/2021-22/FWD
# 'starts' column not found in Adedapo_Awokoya-Mebude.csv, skipping the conversion.
# Processed and saved Adedapo_Awokoya-Mebude.csv in merged_data/2021-22/FWD
# 'starts' column not found in Divock_Origi.csv, skipping the conversion.
# Processed and saved Divock_Origi.csv in merged_data/2021-22/FWD
# 'starts' column not found in Adam_Idah.csv, skipping the conversion.
# Processed and saved Adam_Idah.csv in merged_data/2021-22/FWD
# 'starts' column not found in Kayky_da_Silva_Chagas.csv, skipping the conversion.
# Processed and saved Kayky_da_Silva_Chagas.csv in merged_data/2021-22/FWD
# 'starts' column not found in Callum_Wilson.csv, skipping the conversion.
# Processed and saved Callum_Wilson.csv in merged_data/2021-22/FWD
# 'starts' column not found in Hee-Chan_Hwang.csv, skipping the conversion.
# Processed and saved Hee-Chan_Hwang.csv in merged_data/2021-22/FWD
# 'starts' column not found in Edinson_Cavani.csv, skipping the conversion.
# Processed and saved Edinson_Cavani.csv in merged_data/2021-22/FWD
# 'starts' column not found in Joe_Gelhardt.csv, skipping the conversion.
# Processed and saved Joe_Gelhardt.csv in merged_data/2021-22/FWD
# 'starts' column not found in Adam_Armstrong.csv, skipping the conversion.
# Processed and saved Adam_Armstrong.csv in merged_data/2021-22/FWD
# 'starts' column not found in Wesley_Moraes.csv, skipping the conversion.
# Processed and saved Wesley_Moraes.csv in merged_data/2021-22/FWD
# 'starts' column not found in Armando_Broja.csv, skipping the conversion.
# Processed and saved Armando_Broja.csv in merged_data/2021-22/FWD
# 'starts' column not found in Patson_Daka.csv, skipping the conversion.
# Processed and saved Patson_Daka.csv in merged_data/2021-22/FWD
# 'starts' column not found in Neal_Maupay.csv, skipping the conversion.
# Processed and saved Neal_Maupay.csv in merged_data/2021-22/FWD
# 'starts' column not found in Jay_Rodriguez.csv, skipping the conversion.
# Processed and saved Jay_Rodriguez.csv in merged_data/2021-22/FWD
# 'starts' column not found in Daniel_N'Lundulu.csv, skipping the conversion.
# Processed and saved Daniel_N'Lundulu.csv in merged_data/2021-22/FWD
# 'starts' column not found in Ellis_Simms.csv, skipping the conversion.
# Processed and saved Ellis_Simms.csv in merged_data/2021-22/FWD
# 'starts' column not found in Dwight_Gayle.csv, skipping the conversion.
# Processed and saved Dwight_Gayle.csv in merged_data/2021-22/FWD
# 'starts' column not found in Dane_Scarlett.csv, skipping the conversion.
# Processed and saved Dane_Scarlett.csv in merged_data/2021-22/FWD
# 'starts' column not found in Michy_Batshuayi.csv, skipping the conversion.
# Processed and saved Michy_Batshuayi.csv in merged_data/2021-22/FWD
# 'starts' column not found in Gabriel_Fernando_de_Jesus.csv, skipping the conversion.
# Processed and saved Gabriel_Fernando_de_Jesus.csv in merged_data/2021-22/FWD
# 'starts' column not found in Ollie_Watkins.csv, skipping the conversion.
# Processed and saved Ollie_Watkins.csv in merged_data/2021-22/FWD
# 'starts' column not found in Marcus_Forss.csv, skipping the conversion.
# Processed and saved Marcus_Forss.csv in merged_data/2021-22/FWD
# 'starts' column not found in Halil_Dervişoğlu.csv, skipping the conversion.
# Processed and saved Halil_Dervişoğlu.csv in merged_data/2021-22/FWD
# 'starts' column not found in Dominic_Calvert-Lewin.csv, skipping the conversion.
# Processed and saved Dominic_Calvert-Lewin.csv in merged_data/2021-22/FWD
# 'starts' column not found in Raúl_Jiménez.csv, skipping the conversion.
# Processed and saved Raúl_Jiménez.csv in merged_data/2021-22/FWD
# 'starts' column not found in Roberto_Firmino.csv, skipping the conversion.
# Processed and saved Roberto_Firmino.csv in merged_data/2021-22/FWD
# 'starts' column not found in Sam_Greenwood.csv, skipping the conversion.
# Processed and saved Sam_Greenwood.csv in merged_data/2021-22/FWD
# 'starts' column not found in Shaqai_Forde.csv, skipping the conversion.
# Processed and saved Shaqai_Forde.csv in merged_data/2021-22/FWD
# 'starts' column not found in Robert_Street.csv, skipping the conversion.
# Processed and saved Robert_Street.csv in merged_data/2021-22/FWD
# 'starts' column not found in Che_Adams.csv, skipping the conversion.
# Processed and saved Che_Adams.csv in merged_data/2021-22/FWD
# 'starts' column not found in Abu_Kamara.csv, skipping the conversion.
# Processed and saved Abu_Kamara.csv in merged_data/2021-22/FWD
# 'starts' column not found in Nathan_Broadhead.csv, skipping the conversion.
# Processed and saved Nathan_Broadhead.csv in merged_data/2021-22/FWD
# 'starts' column not found in Mika_Biereth.csv, skipping the conversion.
# Processed and saved Mika_Biereth.csv in merged_data/2021-22/FWD
# 'starts' column not found in Romelu_Lukaku.csv, skipping the conversion.
# Processed and saved Romelu_Lukaku.csv in merged_data/2021-22/FWD
# 'starts' column not found in Danny_Ings.csv, skipping the conversion.
# Processed and saved Danny_Ings.csv in merged_data/2021-22/FWD
# 'starts' column not found in Cenk_Tosun.csv, skipping the conversion.
# Processed and saved Cenk_Tosun.csv in merged_data/2021-22/FWD
# 'starts' column not found in Anthony_Martial.csv, skipping the conversion.
# Processed and saved Anthony_Martial.csv in merged_data/2021-22/FWD
# 'starts' column not found in Christian_Benteke.csv, skipping the conversion.
# Processed and saved Christian_Benteke.csv in merged_data/2021-22/FWD
# 'starts' column not found in Olivier_Giroud.csv, skipping the conversion.
# Processed and saved Olivier_Giroud.csv in merged_data/2021-22/FWD
# 'starts' column not found in Troy_Deeney.csv, skipping the conversion.
# Processed and saved Troy_Deeney.csv in merged_data/2021-22/FWD
# 'starts' column not found in Timo_Werner.csv, skipping the conversion.
# Processed and saved Timo_Werner.csv in merged_data/2021-22/FWD
# 'starts' column not found in Rodrigo_Moreno.csv, skipping the conversion.
# Processed and saved Rodrigo_Moreno.csv in merged_data/2021-22/FWD
# 'starts' column not found in João_Pedro_Junqueira_de_Jesus.csv, skipping the conversion.
# Processed and saved João_Pedro_Junqueira_de_Jesus.csv in merged_data/2021-22/FWD
# 'starts' column not found in Joseph_McGlynn.csv, skipping the conversion.
# Processed and saved Joseph_McGlynn.csv in merged_data/2021-22/FWD
# 'starts' column not found in Jean-Philippe_Mateta.csv, skipping the conversion.
# Processed and saved Jean-Philippe_Mateta.csv in merged_data/2021-22/FWD
# 'starts' column not found in Allan_Saint-Maximin.csv, skipping the conversion.
# Processed and saved Allan_Saint-Maximin.csv in merged_data/2021-22/FWD
# 'starts' column not found in Andre_Gray.csv, skipping the conversion.
# Processed and saved Andre_Gray.csv in merged_data/2021-22/FWD
# 'starts' column not found in Kelechi_Iheanacho.csv, skipping the conversion.
# Processed and saved Kelechi_Iheanacho.csv in merged_data/2021-22/FWD
# 'starts' column not found in Ashley_Fletcher.csv, skipping the conversion.
# Processed and saved Ashley_Fletcher.csv in merged_data/2021-22/FWD
# 'starts' column not found in Joelinton_Cássio_Apolinário_de_Lira.csv, skipping the conversion.
# Processed and saved Joelinton_Cássio_Apolinário_de_Lira.csv in merged_data/2021-22/FWD
# 'starts' column not found in Salomón_Rondón.csv, skipping the conversion.
# Processed and saved Salomón_Rondón.csv in merged_data/2021-22/FWD
# 'starts' column not found in Wout_Weghorst.csv, skipping the conversion.
# Processed and saved Wout_Weghorst.csv in merged_data/2021-22/FWD
# 'starts' column not found in Aaron_Connolly.csv, skipping the conversion.
# Processed and saved Aaron_Connolly.csv in merged_data/2021-22/FWD
# 'starts' column not found in Alexandre_Lacazette.csv, skipping the conversion.
# Processed and saved Alexandre_Lacazette.csv in merged_data/2021-22/FWD
# 'starts' column not found in Patrick_Cutrone.csv, skipping the conversion.
# Processed and saved Patrick_Cutrone.csv in merged_data/2021-22/FWD
# 'starts' column not found in Shane_Long.csv, skipping the conversion.
# Processed and saved Shane_Long.csv in merged_data/2021-22/FWD
# 'starts' column not found in Florin_Andone.csv, skipping the conversion.
# Processed and saved Florin_Andone.csv in merged_data/2021-22/FWD
# 'starts' column not found in Richarlison_de_Andrade.csv, skipping the conversion.
# Processed and saved Richarlison_de_Andrade.csv in merged_data/2021-22/FWD
# 'starts' column not found in Andi_Zeqiri.csv, skipping the conversion.
# Processed and saved Andi_Zeqiri.csv in merged_data/2021-22/FWD
# 'starts' column not found in Edward_Nketiah.csv, skipping the conversion.
# Processed and saved Edward_Nketiah.csv in merged_data/2021-22/FWD
# 'starts' column not found in Mbwana_Ally_Samatta.csv, skipping the conversion.
# Processed and saved Mbwana_Ally_Samatta.csv in merged_data/2021-22/FWD
# 'starts' column not found in Danny_Welbeck.csv, skipping the conversion.
# Processed and saved Danny_Welbeck.csv in merged_data/2021-22/FWD
# 'starts' column not found in Thomas_Dickson-Peters.csv, skipping the conversion.
# Processed and saved Thomas_Dickson-Peters.csv in merged_data/2021-22/FWD
# 'starts' column not found in Joshua_Sargent.csv, skipping the conversion.
# Processed and saved Joshua_Sargent.csv in merged_data/2021-22/FWD
# 'starts' column not found in Teemu_Pukki.csv, skipping the conversion.
# Processed and saved Teemu_Pukki.csv in merged_data/2021-22/FWD
# 'starts' column not found in Emmanuel_Dennis.csv, skipping the conversion.
# Processed and saved Emmanuel_Dennis.csv in merged_data/2021-22/FWD
# 'starts' column not found in Folarin_Balogun.csv, skipping the conversion.
# Processed and saved Folarin_Balogun.csv in merged_data/2021-22/FWD
# 'starts' column not found in Jürgen_Locadia.csv, skipping the conversion.
# Processed and saved Jürgen_Locadia.csv in merged_data/2021-22/FWD
# 'starts' column not found in Tammy_Abraham.csv, skipping the conversion.
# Processed and saved Tammy_Abraham.csv in merged_data/2021-22/FWD
# 'starts' column not found in Cristiano_Ronaldo_dos_Santos_Aveiro.csv, skipping the conversion.
# Processed and saved Cristiano_Ronaldo_dos_Santos_Aveiro.csv in merged_data/2021-22/FWD
# 'starts' column not found in Ivan_Toney.csv, skipping the conversion.
# Processed and saved Ivan_Toney.csv in merged_data/2021-22/FWD
# 'starts' column not found in Matej_Vydra.csv, skipping the conversion.
# Processed and saved Matej_Vydra.csv in merged_data/2021-22/FWD
# 'starts' column not found in Tiago_Çukur.csv, skipping the conversion.
# Processed and saved Tiago_Çukur.csv in merged_data/2021-22/FWD
# 'starts' column not found in Moise_Kean.csv, skipping the conversion.
# Processed and saved Moise_Kean.csv in merged_data/2021-22/FWD
# 'starts' column not found in Fabio_Silva.csv, skipping the conversion.
# Processed and saved Fabio_Silva.csv in merged_data/2021-22/FWD
# 'starts' column not found in Ashley_Barnes.csv, skipping the conversion.
# Processed and saved Ashley_Barnes.csv in merged_data/2021-22/FWD
# 'starts' column not found in Patrick_Bamford.csv, skipping the conversion.
# Processed and saved Patrick_Bamford.csv in merged_data/2021-22/FWD
# 'starts' column not found in Evan_Ferguson.csv, skipping the conversion.
# Processed and saved Evan_Ferguson.csv in merged_data/2021-22/FWD
# 'starts' column not found in Stipe_Perica.csv, skipping the conversion.
# Processed and saved Stipe_Perica.csv in merged_data/2021-22/FWD
# Processed and saved Jamie_Vardy.csv in merged_data/2022-23/FWD
# Processed and saved Terry_Ablade.csv in merged_data/2022-23/FWD
# Processed and saved Odsonne_Edouard.csv in merged_data/2022-23/FWD
# Processed and saved Pierre-Emerick_Aubameyang.csv in merged_data/2022-23/FWD
# Processed and saved Mateo_Joseph_Fernández.csv in merged_data/2022-23/FWD
# Processed and saved Harry_Kane.csv in merged_data/2022-23/FWD
# Processed and saved Thomas_Cannon.csv in merged_data/2022-23/FWD
# Processed and saved Cameron_Archer.csv in merged_data/2022-23/FWD
# Processed and saved Carlos_Vinícius_Alves_Morais.csv in merged_data/2022-23/FWD
# Processed and saved Shola_Shoretire.csv in merged_data/2022-23/FWD
# Processed and saved Michail_Antonio.csv in merged_data/2022-23/FWD
# Processed and saved Sam_Surridge.csv in merged_data/2022-23/FWD
# Processed and saved Daniel_Adu-Adjei.csv in merged_data/2022-23/FWD
# Processed and saved Keinan_Davis.csv in merged_data/2022-23/FWD
# Processed and saved Antoine_Semenyo.csv in merged_data/2022-23/FWD
# Processed and saved Liam_Delap.csv in merged_data/2022-23/FWD
# Processed and saved Chris_Wood.csv in merged_data/2022-23/FWD
# Processed and saved Dominic_Ballard.csv in merged_data/2022-23/FWD
# Processed and saved Darwin_Núñez_Ribeiro.csv in merged_data/2022-23/FWD
# Processed and saved Callum_Wilson.csv in merged_data/2022-23/FWD
# Processed and saved Nathan_Fraser.csv in merged_data/2022-23/FWD
# Processed and saved Diego_Da_Silva_Costa.csv in merged_data/2022-23/FWD
# Processed and saved Kieffer_Moore.csv in merged_data/2022-23/FWD
# Processed and saved John-Kymani_Gordon.csv in merged_data/2022-23/FWD
# Processed and saved Eddie_Nketiah.csv in merged_data/2022-23/FWD
# Processed and saved Joe_Gelhardt.csv in merged_data/2022-23/FWD
# Processed and saved Erling_Haaland.csv in merged_data/2023-24/FWD
# Processed and saved Wout_Weghorst.csv in merged_data/2023-24/FWD
# Processed and saved Youssef_Ramalho_Chermiti.csv in merged_data/2023-24/FWD
# Processed and saved Mason_Burstow.csv in merged_data/2023-24/FWD
# Processed and saved Ben_Parkinson.csv in merged_data/2023-24/FWD
# Processed and saved Enes_Ünal.csv in merged_data/2023-24/FWD
# Processed and saved Jacob_Brown.csv in merged_data/2023-24/FWD
# Processed and saved Joe_Hugill.csv in merged_data/2023-24/FWD
# Processed and saved Mark_O’Mahony.csv in merged_data/2023-24/FWD
# Processed and saved Danny_Welbeck.csv in merged_data/2023-24/FWD
# Processed and saved Leon_Chiwome.csv in merged_data/2023-24/FWD
# Processed and saved Emmanuel_Dennis.csv in merged_data/2023-24/FWD
# Processed and saved Ethan_Wheatley.csv in merged_data/2023-24/FWD
# Processed and saved Rasmus_Højlund.csv in merged_data/2023-24/FWD
# Processed and saved Taiwo_Awoniyi.csv in merged_data/2023-24/FWD
# Processed and saved Ivan_Toney.csv in merged_data/2023-24/FWD
# Processed and saved Lyle_Foster.csv in merged_data/2023-24/FWD
# Processed and saved Antwoine_Hackford.csv in merged_data/2023-24/FWD
# Processed and saved Sasa_Kalajdzic.csv in merged_data/2023-24/FWD
# Processed and saved Jhon_Durán.csv in merged_data/2023-24/FWD
# Processed and saved Evan_Ferguson.csv in merged_data/2023-24/FWD

# %%
#RESTRUCTURING THE MID FOLDER 
import os
import pandas as pd

# Define the path to the MID folder in each season
merged_data_dir = 'merged_data'
seasons = ['2021-22', '2022-23', '2023-24']
mid_folder = 'MID'

# Columns to drop
columns_to_drop = ['position_x', 'kickoff_time', 'time']

# Column order as specified for the MID folder
desired_column_order = [
    'name', 'team', 'opponent_team', 'date', 'was_home', 'position_y', 'minutes', 'goals', 'xG', 'assists', 'xA',
    'total_points', 'shots', 'key_passes', 'ict_index', 'bonus', 'clean_sheets', 'goals_conceded', 'starts'
]

# Loop through each season and process the MID folder
for season in seasons:
    mid_dir = os.path.join(merged_data_dir, season, mid_folder)
    
    if os.path.isdir(mid_dir):
        for csv_file in os.listdir(mid_dir):
            if csv_file.endswith('.csv'):
                file_path = os.path.join(mid_dir, csv_file)
                
                # Read the CSV file
                df = pd.read_csv(file_path)
                
                # Step 1: Drop the unnecessary columns
                df = df.drop(columns=[col for col in columns_to_drop if col in df.columns], errors='ignore')
                
                # Step 2: Convert 'starts' column to boolean (True/False) if it exists
                if 'starts' in df.columns:
                    df['starts'] = df['starts'].apply(lambda x: True if x == 1 else False)
                else:
                    print(f"'starts' column not found in {csv_file}, skipping the conversion.")
                
                # Step 3: Reorder the columns, but first check for missing columns
                existing_columns = [col for col in desired_column_order if col in df.columns]
                df = df[existing_columns]
                
                # Step 4: Rename 'position_y' to 'position' if 'position_y' exists
                if 'position_y' in df.columns:
                    df = df.rename(columns={'position_y': 'position'})
                
                # Save the modified CSV file back
                df.to_csv(file_path, index=False)
                print(f"Processed and saved {csv_file} in {mid_dir}")
# Out:
# 'starts' column not found in Miguel_Almirón.csv, skipping the conversion.
# Processed and saved Miguel_Almirón.csv in merged_data/2021-22/MID
# 'starts' column not found in Joseph_Hungbo.csv, skipping the conversion.
# Processed and saved Joseph_Hungbo.csv in merged_data/2021-22/MID
# 'starts' column not found in Lukas_Rupp.csv, skipping the conversion.
# Processed and saved Lukas_Rupp.csv in merged_data/2021-22/MID
# 'starts' column not found in Edo_Kayembe.csv, skipping the conversion.
# Processed and saved Edo_Kayembe.csv in merged_data/2021-22/MID
# 'starts' column not found in Vitaly_Janelt.csv, skipping the conversion.
# Processed and saved Vitaly_Janelt.csv in merged_data/2021-22/MID
# 'starts' column not found in Morgan_Gibbs-White.csv, skipping the conversion.
# Processed and saved Morgan_Gibbs-White.csv in merged_data/2021-22/MID
# 'starts' column not found in Jonjo_Shelvey.csv, skipping the conversion.
# Processed and saved Jonjo_Shelvey.csv in merged_data/2021-22/MID
# 'starts' column not found in Dara_Costelloe.csv, skipping the conversion.
# Processed and saved Dara_Costelloe.csv in merged_data/2021-22/MID
# 'starts' column not found in Josh_Benson.csv, skipping the conversion.
# Processed and saved Josh_Benson.csv in merged_data/2021-22/MID
# 'starts' column not found in Bryan_Gil_Salvatierra.csv, skipping the conversion.
# Processed and saved Bryan_Gil_Salvatierra.csv in merged_data/2021-22/MID
# 'starts' column not found in Gylfi_Sigurdsson.csv, skipping the conversion.
# Processed and saved Gylfi_Sigurdsson.csv in merged_data/2021-22/MID
# 'starts' column not found in Tony_Springett.csv, skipping the conversion.
# Processed and saved Tony_Springett.csv in merged_data/2021-22/MID
# 'starts' column not found in Juraj_Kucka.csv, skipping the conversion.
# Processed and saved Juraj_Kucka.csv in merged_data/2021-22/MID
# 'starts' column not found in Marcelo_Flores.csv, skipping the conversion.
# Processed and saved Marcelo_Flores.csv in merged_data/2021-22/MID
# 'starts' column not found in N'Golo_Kanté.csv, skipping the conversion.
# Processed and saved N'Golo_Kanté.csv in merged_data/2021-22/MID
# 'starts' column not found in Donny_van_de_Beek.csv, skipping the conversion.
# Processed and saved Donny_van_de_Beek.csv in merged_data/2021-22/MID
# 'starts' column not found in Shandon_Baptiste.csv, skipping the conversion.
# Processed and saved Shandon_Baptiste.csv in merged_data/2021-22/MID
# 'starts' column not found in Hamza_Choudhury.csv, skipping the conversion.
# Processed and saved Hamza_Choudhury.csv in merged_data/2021-22/MID
# 'starts' column not found in Curtis_Jones.csv, skipping the conversion.
# Processed and saved Curtis_Jones.csv in merged_data/2021-22/MID
# 'starts' column not found in Alexis_Mac_Allister.csv, skipping the conversion.
# Processed and saved Alexis_Mac_Allister.csv in merged_data/2021-22/MID
# 'starts' column not found in Tom_Davies.csv, skipping the conversion.
# Processed and saved Tom_Davies.csv in merged_data/2021-22/MID
# 'starts' column not found in Mohamed_Elyounoussi.csv, skipping the conversion.
# Processed and saved Mohamed_Elyounoussi.csv in merged_data/2021-22/MID
# 'starts' column not found in Bruno_Guimarães_Rodriguez_Moura.csv, skipping the conversion.
# Processed and saved Bruno_Guimarães_Rodriguez_Moura.csv in merged_data/2021-22/MID
# 'starts' column not found in Oriol_Romeu_Vidal.csv, skipping the conversion.
# Processed and saved Oriol_Romeu_Vidal.csv in merged_data/2021-22/MID
# 'starts' column not found in Lewis_Hall.csv, skipping the conversion.
# Processed and saved Lewis_Hall.csv in merged_data/2021-22/MID
# 'starts' column not found in Yoane_Wissa.csv, skipping the conversion.
# Processed and saved Yoane_Wissa.csv in merged_data/2021-22/MID
# 'starts' column not found in Ian_Carlo_Poveda-Ocampo.csv, skipping the conversion.
# Processed and saved Ian_Carlo_Poveda-Ocampo.csv in merged_data/2021-22/MID
# 'starts' column not found in James_Maddison.csv, skipping the conversion.
# Processed and saved James_Maddison.csv in merged_data/2021-22/MID
# 'starts' column not found in Emiliano_Buendía_Stati.csv, skipping the conversion.
# Processed and saved Emiliano_Buendía_Stati.csv in merged_data/2021-22/MID
# 'starts' column not found in Ayotomiwa_Dele-Bashiru.csv, skipping the conversion.
# Processed and saved Ayotomiwa_Dele-Bashiru.csv in merged_data/2021-22/MID
# 'starts' column not found in Harvey_Barnes.csv, skipping the conversion.
# Processed and saved Harvey_Barnes.csv in merged_data/2021-22/MID
# 'starts' column not found in Jamie_Bowden.csv, skipping the conversion.
# Processed and saved Jamie_Bowden.csv in merged_data/2021-22/MID
# 'starts' column not found in Ross_Barkley.csv, skipping the conversion.
# Processed and saved Ross_Barkley.csv in merged_data/2021-22/MID
# 'starts' column not found in Frederico_Rodrigues_de_Paula_Santos.csv, skipping the conversion.
# Processed and saved Frederico_Rodrigues_de_Paula_Santos.csv in merged_data/2021-22/MID
# 'starts' column not found in Jesurun_Rak-Sakyi.csv, skipping the conversion.
# Processed and saved Jesurun_Rak-Sakyi.csv in merged_data/2021-22/MID
# 'starts' column not found in Cole_Palmer.csv, skipping the conversion.
# Processed and saved Cole_Palmer.csv in merged_data/2021-22/MID
# 'starts' column not found in Maxwell_Haygarth.csv, skipping the conversion.
# Processed and saved Maxwell_Haygarth.csv in merged_data/2021-22/MID
# 'starts' column not found in Pablo_Fornals.csv, skipping the conversion.
# Processed and saved Pablo_Fornals.csv in merged_data/2021-22/MID
# 'starts' column not found in Tyler_Dibling.csv, skipping the conversion.
# Processed and saved Tyler_Dibling.csv in merged_data/2021-22/MID
# 'starts' column not found in William_Smallbone.csv, skipping the conversion.
# Processed and saved William_Smallbone.csv in merged_data/2021-22/MID
# 'starts' column not found in Carney_Chukwuemeka.csv, skipping the conversion.
# Processed and saved Carney_Chukwuemeka.csv in merged_data/2021-22/MID
# 'starts' column not found in Anwar_El_Ghazi.csv, skipping the conversion.
# Processed and saved Anwar_El_Ghazi.csv in merged_data/2021-22/MID
# 'starts' column not found in Stuart_Dallas.csv, skipping the conversion.
# Processed and saved Stuart_Dallas.csv in merged_data/2021-22/MID
# 'starts' column not found in Mahmoud_Ahmed_Ibrahim_Hassan.csv, skipping the conversion.
# Processed and saved Mahmoud_Ahmed_Ibrahim_Hassan.csv in merged_data/2021-22/MID
# 'starts' column not found in Mason_Mount.csv, skipping the conversion.
# Processed and saved Mason_Mount.csv in merged_data/2021-22/MID
# 'starts' column not found in Kenny_McLean.csv, skipping the conversion.
# Processed and saved Kenny_McLean.csv in merged_data/2021-22/MID
# 'starts' column not found in Kaide_Gordon.csv, skipping the conversion.
# Processed and saved Kaide_Gordon.csv in merged_data/2021-22/MID
# 'starts' column not found in Luis_Díaz.csv, skipping the conversion.
# Processed and saved Luis_Díaz.csv in merged_data/2021-22/MID
# 'starts' column not found in Shola_Shoretire.csv, skipping the conversion.
# Processed and saved Shola_Shoretire.csv in merged_data/2021-22/MID
# 'starts' column not found in Daniel_Castelo_Podence.csv, skipping the conversion.
# Processed and saved Daniel_Castelo_Podence.csv in merged_data/2021-22/MID
# 'starts' column not found in Dale_Stephens.csv, skipping the conversion.
# Processed and saved Dale_Stephens.csv in merged_data/2021-22/MID
# 'starts' column not found in Saman_Ghoddos.csv, skipping the conversion.
# Processed and saved Saman_Ghoddos.csv in merged_data/2021-22/MID
# 'starts' column not found in Jacob_Ramsey.csv, skipping the conversion.
# Processed and saved Jacob_Ramsey.csv in merged_data/2021-22/MID
# 'starts' column not found in Thomas_Partey.csv, skipping the conversion.
# Processed and saved Thomas_Partey.csv in merged_data/2021-22/MID
# 'starts' column not found in Conor_Hourihane.csv, skipping the conversion.
# Processed and saved Conor_Hourihane.csv in merged_data/2021-22/MID
# 'starts' column not found in Dejan_Kulusevski.csv, skipping the conversion.
# Processed and saved Dejan_Kulusevski.csv in merged_data/2021-22/MID
# 'starts' column not found in Nampalys_Mendy.csv, skipping the conversion.
# Processed and saved Nampalys_Mendy.csv in merged_data/2021-22/MID
# 'starts' column not found in Kevin_De_Bruyne.csv, skipping the conversion.
# Processed and saved Kevin_De_Bruyne.csv in merged_data/2021-22/MID
# 'starts' column not found in Alex_Iwobi.csv, skipping the conversion.
# Processed and saved Alex_Iwobi.csv in merged_data/2021-22/MID
# 'starts' column not found in Nikola_Vlasic.csv, skipping the conversion.
# Processed and saved Nikola_Vlasic.csv in merged_data/2021-22/MID
# 'starts' column not found in James_Ward-Prowse.csv, skipping the conversion.
# Processed and saved James_Ward-Prowse.csv in merged_data/2021-22/MID
# 'starts' column not found in Abdoulaye_Doucouré.csv, skipping the conversion.
# Processed and saved Abdoulaye_Doucouré.csv in merged_data/2021-22/MID
# 'starts' column not found in Crysencio_Summerville.csv, skipping the conversion.
# Processed and saved Crysencio_Summerville.csv in merged_data/2021-22/MID
# 'starts' column not found in Jack_Grealish.csv, skipping the conversion.
# Processed and saved Jack_Grealish.csv in merged_data/2021-22/MID
# 'starts' column not found in Eberechi_Eze.csv, skipping the conversion.
# Processed and saved Eberechi_Eze.csv in merged_data/2021-22/MID
# 'starts' column not found in Sadio_Mané.csv, skipping the conversion.
# Processed and saved Sadio_Mané.csv in merged_data/2021-22/MID
# 'starts' column not found in Matthew_Craig.csv, skipping the conversion.
# Processed and saved Matthew_Craig.csv in merged_data/2021-22/MID
# 'starts' column not found in Ryan_Fraser.csv, skipping the conversion.
# Processed and saved Ryan_Fraser.csv in merged_data/2021-22/MID
# 'starts' column not found in Jeff_Hendrick.csv, skipping the conversion.
# Processed and saved Jeff_Hendrick.csv in merged_data/2021-22/MID
# 'starts' column not found in Jarrod_Bowen.csv, skipping the conversion.
# Processed and saved Jarrod_Bowen.csv in merged_data/2021-22/MID
# 'starts' column not found in Xherdan_Shaqiri.csv, skipping the conversion.
# Processed and saved Xherdan_Shaqiri.csv in merged_data/2021-22/MID
# 'starts' column not found in Ismaila_Sarr.csv, skipping the conversion.
# Processed and saved Ismaila_Sarr.csv in merged_data/2021-22/MID
# 'starts' column not found in Nohan_Kenneh.csv, skipping the conversion.
# Processed and saved Nohan_Kenneh.csv in merged_data/2021-22/MID
# 'starts' column not found in Fabian_Delph.csv, skipping the conversion.
# Processed and saved Fabian_Delph.csv in merged_data/2021-22/MID
# 'starts' column not found in Solomon_March.csv, skipping the conversion.
# Processed and saved Solomon_March.csv in merged_data/2021-22/MID
# 'starts' column not found in Paris_Maghoma.csv, skipping the conversion.
# Processed and saved Paris_Maghoma.csv in merged_data/2021-22/MID
# 'starts' column not found in Emile_Smith_Rowe.csv, skipping the conversion.
# Processed and saved Emile_Smith_Rowe.csv in merged_data/2021-22/MID
# 'starts' column not found in Alex_Kral.csv, skipping the conversion.
# Processed and saved Alex_Kral.csv in merged_data/2021-22/MID
# 'starts' column not found in Kalvin_Phillips.csv, skipping the conversion.
# Processed and saved Kalvin_Phillips.csv in merged_data/2021-22/MID
# 'starts' column not found in Harvey_Elliott.csv, skipping the conversion.
# Processed and saved Harvey_Elliott.csv in merged_data/2021-22/MID
# 'starts' column not found in Marco_Stiepermann.csv, skipping the conversion.
# Processed and saved Marco_Stiepermann.csv in merged_data/2021-22/MID
# 'starts' column not found in Fernando_Luiz_Rosa.csv, skipping the conversion.
# Processed and saved Fernando_Luiz_Rosa.csv in merged_data/2021-22/MID
# 'starts' column not found in Elliot_Anderson.csv, skipping the conversion.
# Processed and saved Elliot_Anderson.csv in merged_data/2021-22/MID
# 'starts' column not found in Andros_Townsend.csv, skipping the conversion.
# Processed and saved Andros_Townsend.csv in merged_data/2021-22/MID
# 'starts' column not found in Pablo_Hernández_Domínguez.csv, skipping the conversion.
# Processed and saved Pablo_Hernández_Domínguez.csv in merged_data/2021-22/MID
# 'starts' column not found in Diogo_Jota.csv, skipping the conversion.
# Processed and saved Diogo_Jota.csv in merged_data/2021-22/MID
# 'starts' column not found in Naby_Keita.csv, skipping the conversion.
# Processed and saved Naby_Keita.csv in merged_data/2021-22/MID
# 'starts' column not found in Takumi_Minamino.csv, skipping the conversion.
# Processed and saved Takumi_Minamino.csv in merged_data/2021-22/MID
# 'starts' column not found in Raheem_Sterling.csv, skipping the conversion.
# Processed and saved Raheem_Sterling.csv in merged_data/2021-22/MID
# 'starts' column not found in Mateo_Kovacic.csv, skipping the conversion.
# Processed and saved Mateo_Kovacic.csv in merged_data/2021-22/MID
# 'starts' column not found in Ainsley_Maitland-Niles.csv, skipping the conversion.
# Processed and saved Ainsley_Maitland-Niles.csv in merged_data/2021-22/MID
# 'starts' column not found in Pierre_Lees-Melou.csv, skipping the conversion.
# Processed and saved Pierre_Lees-Melou.csv in merged_data/2021-22/MID
# 'starts' column not found in Leandro_Trossard.csv, skipping the conversion.
# Processed and saved Leandro_Trossard.csv in merged_data/2021-22/MID
# 'starts' column not found in Daniel_James.csv, skipping the conversion.
# Processed and saved Daniel_James.csv in merged_data/2021-22/MID
# 'starts' column not found in Mohamed_Naser_El_Sayed_Elneny.csv, skipping the conversion.
# Processed and saved Mohamed_Naser_El_Sayed_Elneny.csv in merged_data/2021-22/MID
# 'starts' column not found in Jack_Jenkins.csv, skipping the conversion.
# Processed and saved Jack_Jenkins.csv in merged_data/2021-22/MID
# 'starts' column not found in Steven_Bergwijn.csv, skipping the conversion.
# Processed and saved Steven_Bergwijn.csv in merged_data/2021-22/MID
# 'starts' column not found in Aaron_Lennon.csv, skipping the conversion.
# Processed and saved Aaron_Lennon.csv in merged_data/2021-22/MID
# 'starts' column not found in Myles_Peart-Harris.csv, skipping the conversion.
# Processed and saved Myles_Peart-Harris.csv in merged_data/2021-22/MID
# 'starts' column not found in Luka_Milivojevic.csv, skipping the conversion.
# Processed and saved Luka_Milivojevic.csv in merged_data/2021-22/MID
# 'starts' column not found in Jordan_Henderson.csv, skipping the conversion.
# Processed and saved Jordan_Henderson.csv in merged_data/2021-22/MID
# 'starts' column not found in Moussa_Sissoko.csv, skipping the conversion.
# Processed and saved Moussa_Sissoko.csv in merged_data/2021-22/MID
# 'starts' column not found in Harry_Winks.csv, skipping the conversion.
# Processed and saved Harry_Winks.csv in merged_data/2021-22/MID
# 'starts' column not found in Josh_Martin.csv, skipping the conversion.
# Processed and saved Josh_Martin.csv in merged_data/2021-22/MID
# 'starts' column not found in Hannibal_Mejbri.csv, skipping the conversion.
# Processed and saved Hannibal_Mejbri.csv in merged_data/2021-22/MID
# 'starts' column not found in Martin_Ødegaard.csv, skipping the conversion.
# Processed and saved Martin_Ødegaard.csv in merged_data/2021-22/MID
# 'starts' column not found in Billy_Gilmour.csv, skipping the conversion.
# Processed and saved Billy_Gilmour.csv in merged_data/2021-22/MID
# 'starts' column not found in Morgan_Sanson.csv, skipping the conversion.
# Processed and saved Morgan_Sanson.csv in merged_data/2021-22/MID
# 'starts' column not found in Marc_Albrighton.csv, skipping the conversion.
# Processed and saved Marc_Albrighton.csv in merged_data/2021-22/MID
# 'starts' column not found in Pascal_Groß.csv, skipping the conversion.
# Processed and saved Pascal_Groß.csv in merged_data/2021-22/MID
# 'starts' column not found in Paul_Pogba.csv, skipping the conversion.
# Processed and saved Paul_Pogba.csv in merged_data/2021-22/MID
# 'starts' column not found in Mathias_Jensen.csv, skipping the conversion.
# Processed and saved Mathias_Jensen.csv in merged_data/2021-22/MID
# 'starts' column not found in Reiss_Nelson.csv, skipping the conversion.
# Processed and saved Reiss_Nelson.csv in merged_data/2021-22/MID
# 'starts' column not found in Tyler_Onyango.csv, skipping the conversion.
# Processed and saved Tyler_Onyango.csv in merged_data/2021-22/MID
# 'starts' column not found in Kieran_Dowell.csv, skipping the conversion.
# Processed and saved Kieran_Dowell.csv in merged_data/2021-22/MID
# 'starts' column not found in Mark_Noble.csv, skipping the conversion.
# Processed and saved Mark_Noble.csv in merged_data/2021-22/MID
# 'starts' column not found in Bernardo_Mota_Veiga_de_Carvalho_e_Silva.csv, skipping the conversion.
# Processed and saved Bernardo_Mota_Veiga_de_Carvalho_e_Silva.csv in merged_data/2021-22/MID
# 'starts' column not found in Saúl_Ñíguez.csv, skipping the conversion.
# Processed and saved Saúl_Ñíguez.csv in merged_data/2021-22/MID
# 'starts' column not found in Nemanja_Matic.csv, skipping the conversion.
# Processed and saved Nemanja_Matic.csv in merged_data/2021-22/MID
# 'starts' column not found in Lucas_Rodrigues_Moura_da_Silva.csv, skipping the conversion.
# Processed and saved Lucas_Rodrigues_Moura_da_Silva.csv in merged_data/2021-22/MID
# 'starts' column not found in Ryan_Giles.csv, skipping the conversion.
# Processed and saved Ryan_Giles.csv in merged_data/2021-22/MID
# 'starts' column not found in Philip_Zinckernagel.csv, skipping the conversion.
# Processed and saved Philip_Zinckernagel.csv in merged_data/2021-22/MID
# 'starts' column not found in Adama_Traoré.csv, skipping the conversion.
# Processed and saved Adama_Traoré.csv in merged_data/2021-22/MID
# 'starts' column not found in Andreas_Pereira.csv, skipping the conversion.
# Processed and saved Andreas_Pereira.csv in merged_data/2021-22/MID
# 'starts' column not found in Anthony_Gordon.csv, skipping the conversion.
# Processed and saved Anthony_Gordon.csv in merged_data/2021-22/MID
# 'starts' column not found in Francisco_Machado_Mota_de_Castro_Trincão.csv, skipping the conversion.
# Processed and saved Francisco_Machado_Mota_de_Castro_Trincão.csv in merged_data/2021-22/MID
# 'starts' column not found in Oghenekaro_Peter_Etebo.csv, skipping the conversion.
# Processed and saved Oghenekaro_Peter_Etebo.csv in merged_data/2021-22/MID
# 'starts' column not found in James_McAtee.csv, skipping the conversion.
# Processed and saved James_McAtee.csv in merged_data/2021-22/MID
# 'starts' column not found in Charlie_Savage.csv, skipping the conversion.
# Processed and saved Charlie_Savage.csv in merged_data/2021-22/MID
# 'starts' column not found in Jack_Harrison.csv, skipping the conversion.
# Processed and saved Jack_Harrison.csv in merged_data/2021-22/MID
# 'starts' column not found in Ibrahima_Diallo.csv, skipping the conversion.
# Processed and saved Ibrahima_Diallo.csv in merged_data/2021-22/MID
# 'starts' column not found in Moisés_Caicedo.csv, skipping the conversion.
# Processed and saved Moisés_Caicedo.csv in merged_data/2021-22/MID
# 'starts' column not found in Benjamin_Chrisene.csv, skipping the conversion.
# Processed and saved Benjamin_Chrisene.csv in merged_data/2021-22/MID
# 'starts' column not found in Saïd_Benrahma.csv, skipping the conversion.
# Processed and saved Saïd_Benrahma.csv in merged_data/2021-22/MID
# 'starts' column not found in Kgaogelo_Chauke.csv, skipping the conversion.
# Processed and saved Kgaogelo_Chauke.csv in merged_data/2021-22/MID
# 'starts' column not found in Christian_Nørgaard.csv, skipping the conversion.
# Processed and saved Christian_Nørgaard.csv in merged_data/2021-22/MID
# 'starts' column not found in Ben_Woodburn.csv, skipping the conversion.
# Processed and saved Ben_Woodburn.csv in merged_data/2021-22/MID
# 'starts' column not found in Tommy_Doyle.csv, skipping the conversion.
# Processed and saved Tommy_Doyle.csv in merged_data/2021-22/MID
# 'starts' column not found in Riyad_Mahrez.csv, skipping the conversion.
# Processed and saved Riyad_Mahrez.csv in merged_data/2021-22/MID
# 'starts' column not found in Christos_Tzolis.csv, skipping the conversion.
# Processed and saved Christos_Tzolis.csv in merged_data/2021-22/MID
# 'starts' column not found in Giovani_Lo_Celso.csv, skipping the conversion.
# Processed and saved Giovani_Lo_Celso.csv in merged_data/2021-22/MID
# 'starts' column not found in Michael_Olise.csv, skipping the conversion.
# Processed and saved Michael_Olise.csv in merged_data/2021-22/MID
# 'starts' column not found in Romeo_Lavia.csv, skipping the conversion.
# Processed and saved Romeo_Lavia.csv in merged_data/2021-22/MID
# 'starts' column not found in Albert_Sambi_Lokonga.csv, skipping the conversion.
# Processed and saved Albert_Sambi_Lokonga.csv in merged_data/2021-22/MID
# 'starts' column not found in Gabriel_Teodoro_Martinelli_Silva.csv, skipping the conversion.
# Processed and saved Gabriel_Teodoro_Martinelli_Silva.csv in merged_data/2021-22/MID
# 'starts' column not found in Leon_Bailey.csv, skipping the conversion.
# Processed and saved Leon_Bailey.csv in merged_data/2021-22/MID
# 'starts' column not found in Aaron_Ramsey.csv, skipping the conversion.
# Processed and saved Aaron_Ramsey.csv in merged_data/2021-22/MID
# 'starts' column not found in Mateusz_Klich.csv, skipping the conversion.
# Processed and saved Mateusz_Klich.csv in merged_data/2021-22/MID
# 'starts' column not found in Nicolas_Pépé.csv, skipping the conversion.
# Processed and saved Nicolas_Pépé.csv in merged_data/2021-22/MID
# 'starts' column not found in Stuart_McKinstry.csv, skipping the conversion.
# Processed and saved Stuart_McKinstry.csv in merged_data/2021-22/MID
# 'starts' column not found in Domingos_Quina.csv, skipping the conversion.
# Processed and saved Domingos_Quina.csv in merged_data/2021-22/MID
# 'starts' column not found in Archie_Gray.csv, skipping the conversion.
# Processed and saved Archie_Gray.csv in merged_data/2021-22/MID
# 'starts' column not found in Liam_Gibbs.csv, skipping the conversion.
# Processed and saved Liam_Gibbs.csv in merged_data/2021-22/MID
# 'starts' column not found in Ademola_Lookman.csv, skipping the conversion.
# Processed and saved Ademola_Lookman.csv in merged_data/2021-22/MID
# 'starts' column not found in Granit_Xhaka.csv, skipping the conversion.
# Processed and saved Granit_Xhaka.csv in merged_data/2021-22/MID
# 'starts' column not found in Josh_Brownhill.csv, skipping the conversion.
# Processed and saved Josh_Brownhill.csv in merged_data/2021-22/MID
# 'starts' column not found in Fabio_Henrique_Tavares.csv, skipping the conversion.
# Processed and saved Fabio_Henrique_Tavares.csv in merged_data/2021-22/MID
# 'starts' column not found in Charlie_Patino.csv, skipping the conversion.
# Processed and saved Charlie_Patino.csv in merged_data/2021-22/MID
# 'starts' column not found in Jairo_Riedewald.csv, skipping the conversion.
# Processed and saved Jairo_Riedewald.csv in merged_data/2021-22/MID
# 'starts' column not found in Kasey_McAteer.csv, skipping the conversion.
# Processed and saved Kasey_McAteer.csv in merged_data/2021-22/MID
# 'starts' column not found in Conor_Gallagher.csv, skipping the conversion.
# Processed and saved Conor_Gallagher.csv in merged_data/2021-22/MID
# 'starts' column not found in Will_Hughes.csv, skipping the conversion.
# Processed and saved Will_Hughes.csv in merged_data/2021-22/MID
# 'starts' column not found in Ozan_Tufan.csv, skipping the conversion.
# Processed and saved Ozan_Tufan.csv in merged_data/2021-22/MID
# 'starts' column not found in Sean_Longstaff.csv, skipping the conversion.
# Processed and saved Sean_Longstaff.csv in merged_data/2021-22/MID
# 'starts' column not found in Jacob_Murphy.csv, skipping the conversion.
# Processed and saved Jacob_Murphy.csv in merged_data/2021-22/MID
# 'starts' column not found in Christian_Eriksen.csv, skipping the conversion.
# Processed and saved Christian_Eriksen.csv in merged_data/2021-22/MID
# 'starts' column not found in Ken_Sema.csv, skipping the conversion.
# Processed and saved Ken_Sema.csv in merged_data/2021-22/MID
# 'starts' column not found in Yves_Bissouma.csv, skipping the conversion.
# Processed and saved Yves_Bissouma.csv in merged_data/2021-22/MID
# 'starts' column not found in Hélder_Wander_Sousa_de_Azevedo_e_Costa.csv, skipping the conversion.
# Processed and saved Hélder_Wander_Sousa_de_Azevedo_e_Costa.csv in merged_data/2021-22/MID
# 'starts' column not found in Harvey_Vale.csv, skipping the conversion.
# Processed and saved Harvey_Vale.csv in merged_data/2021-22/MID
# 'starts' column not found in Lucas_De_Bolle.csv, skipping the conversion.
# Processed and saved Lucas_De_Bolle.csv in merged_data/2021-22/MID
# 'starts' column not found in Jaden_Philogene-Bidace.csv, skipping the conversion.
# Processed and saved Jaden_Philogene-Bidace.csv in merged_data/2021-22/MID
# 'starts' column not found in Hakim_Ziyech.csv, skipping the conversion.
# Processed and saved Hakim_Ziyech.csv in merged_data/2021-22/MID
# 'starts' column not found in Mattéo_Guendouzi.csv, skipping the conversion.
# Processed and saved Mattéo_Guendouzi.csv in merged_data/2021-22/MID
# 'starts' column not found in Heung-Min_Son.csv, skipping the conversion.
# Processed and saved Heung-Min_Son.csv in merged_data/2021-22/MID
# 'starts' column not found in Conor_Coventry.csv, skipping the conversion.
# Processed and saved Conor_Coventry.csv in merged_data/2021-22/MID
# 'starts' column not found in Phil_Foden.csv, skipping the conversion.
# Processed and saved Phil_Foden.csv in merged_data/2021-22/MID
# 'starts' column not found in Adrian_Blake.csv, skipping the conversion.
# Processed and saved Adrian_Blake.csv in merged_data/2021-22/MID
# 'starts' column not found in Jan_Zamburek.csv, skipping the conversion.
# Processed and saved Jan_Zamburek.csv in merged_data/2021-22/MID
# 'starts' column not found in Philippe_Coutinho_Correia.csv, skipping the conversion.
# Processed and saved Philippe_Coutinho_Correia.csv in merged_data/2021-22/MID
# 'starts' column not found in Jadon_Sancho.csv, skipping the conversion.
# Processed and saved Jadon_Sancho.csv in merged_data/2021-22/MID
# 'starts' column not found in Johann_Berg_Gudmundsson.csv, skipping the conversion.
# Processed and saved Johann_Berg_Gudmundsson.csv in merged_data/2021-22/MID
# 'starts' column not found in Joe_White.csv, skipping the conversion.
# Processed and saved Joe_White.csv in merged_data/2021-22/MID
# 'starts' column not found in Jakub_Moder.csv, skipping the conversion.
# Processed and saved Jakub_Moder.csv in merged_data/2021-22/MID
# 'starts' column not found in Manuel_Lanzini.csv, skipping the conversion.
# Processed and saved Manuel_Lanzini.csv in merged_data/2021-22/MID
# 'starts' column not found in Kamil_Conteh.csv, skipping the conversion.
# Processed and saved Kamil_Conteh.csv in merged_data/2021-22/MID
# 'starts' column not found in Jeremy_Sarmiento.csv, skipping the conversion.
# Processed and saved Jeremy_Sarmiento.csv in merged_data/2021-22/MID
# 'starts' column not found in Pelenda_Joshua_Dasilva.csv, skipping the conversion.
# Processed and saved Pelenda_Joshua_Dasilva.csv in merged_data/2021-22/MID
# 'starts' column not found in Adam_Forshaw.csv, skipping the conversion.
# Processed and saved Adam_Forshaw.csv in merged_data/2021-22/MID
# 'starts' column not found in Stuart_Armstrong.csv, skipping the conversion.
# Processed and saved Stuart_Armstrong.csv in merged_data/2021-22/MID
# 'starts' column not found in Daniel_Chesters.csv, skipping the conversion.
# Processed and saved Daniel_Chesters.csv in merged_data/2021-22/MID
# 'starts' column not found in João_Filipe_Iria_Santos_Moutinho.csv, skipping the conversion.
# Processed and saved João_Filipe_Iria_Santos_Moutinho.csv in merged_data/2021-22/MID
# 'starts' column not found in Imrân_Louza.csv, skipping the conversion.
# Processed and saved Imrân_Louza.csv in merged_data/2021-22/MID
# 'starts' column not found in Ferran_Torres.csv, skipping the conversion.
# Processed and saved Ferran_Torres.csv in merged_data/2021-22/MID
# 'starts' column not found in Przemyslaw_Placheta.csv, skipping the conversion.
# Processed and saved Przemyslaw_Placheta.csv in merged_data/2021-22/MID
# 'starts' column not found in André_Filipe_Tavares_Gomes.csv, skipping the conversion.
# Processed and saved André_Filipe_Tavares_Gomes.csv in merged_data/2021-22/MID
# 'starts' column not found in Bruno_Miguel_Borges_Fernandes.csv, skipping the conversion.
# Processed and saved Bruno_Miguel_Borges_Fernandes.csv in merged_data/2021-22/MID
# 'starts' column not found in Jack_Cork.csv, skipping the conversion.
# Processed and saved Jack_Cork.csv in merged_data/2021-22/MID
# 'starts' column not found in Todd_Cantwell.csv, skipping the conversion.
# Processed and saved Todd_Cantwell.csv in merged_data/2021-22/MID
# 'starts' column not found in Kai_Havertz.csv, skipping the conversion.
# Processed and saved Kai_Havertz.csv in merged_data/2021-22/MID
# 'starts' column not found in Marvelous_Nakamba.csv, skipping the conversion.
# Processed and saved Marvelous_Nakamba.csv in merged_data/2021-22/MID
# 'starts' column not found in Nathan_Tella.csv, skipping the conversion.
# Processed and saved Nathan_Tella.csv in merged_data/2021-22/MID
# 'starts' column not found in Kiernan_Dewsbury-Hall.csv, skipping the conversion.
# Processed and saved Kiernan_Dewsbury-Hall.csv in merged_data/2021-22/MID
# 'starts' column not found in Douglas_Luiz_Soares_de_Paulo.csv, skipping the conversion.
# Processed and saved Douglas_Luiz_Soares_de_Paulo.csv in merged_data/2021-22/MID
# 'starts' column not found in Erik_Lamela.csv, skipping the conversion.
# Processed and saved Erik_Lamela.csv in merged_data/2021-22/MID
# 'starts' column not found in Dan_Gosling.csv, skipping the conversion.
# Processed and saved Dan_Gosling.csv in merged_data/2021-22/MID
# 'starts' column not found in Isaac_Price.csv, skipping the conversion.
# Processed and saved Isaac_Price.csv in merged_data/2021-22/MID
# 'starts' column not found in Alireza_Jahanbakhsh.csv, skipping the conversion.
# Processed and saved Alireza_Jahanbakhsh.csv in merged_data/2021-22/MID
# 'starts' column not found in Kwadwo_Baah.csv, skipping the conversion.
# Processed and saved Kwadwo_Baah.csv in merged_data/2021-22/MID
# 'starts' column not found in Leander_Dendoncker.csv, skipping the conversion.
# Processed and saved Leander_Dendoncker.csv in merged_data/2021-22/MID
# 'starts' column not found in Youri_Tielemans.csv, skipping the conversion.
# Processed and saved Youri_Tielemans.csv in merged_data/2021-22/MID
# 'starts' column not found in Pierre-Emile_Højbjerg.csv, skipping the conversion.
# Processed and saved Pierre-Emile_Højbjerg.csv in merged_data/2021-22/MID
# 'starts' column not found in Scott_Banks.csv, skipping the conversion.
# Processed and saved Scott_Banks.csv in merged_data/2021-22/MID
# 'starts' column not found in Ruben_Loftus-Cheek.csv, skipping the conversion.
# Processed and saved Ruben_Loftus-Cheek.csv in merged_data/2021-22/MID
# 'starts' column not found in John_McGinn.csv, skipping the conversion.
# Processed and saved John_McGinn.csv in merged_data/2021-22/MID
# 'starts' column not found in Omari_Hutchinson.csv, skipping the conversion.
# Processed and saved Omari_Hutchinson.csv in merged_data/2021-22/MID
# 'starts' column not found in Lewis_Bate.csv, skipping the conversion.
# Processed and saved Lewis_Bate.csv in merged_data/2021-22/MID
# 'starts' column not found in Bernard_Anício_Caldeira_Duarte.csv, skipping the conversion.
# Processed and saved Bernard_Anício_Caldeira_Duarte.csv in merged_data/2021-22/MID
# 'starts' column not found in Jonathan_Rowe.csv, skipping the conversion.
# Processed and saved Jonathan_Rowe.csv in merged_data/2021-22/MID
# 'starts' column not found in Demarai_Gray.csv, skipping the conversion.
# Processed and saved Demarai_Gray.csv in merged_data/2021-22/MID
# 'starts' column not found in Amad_Diallo.csv, skipping the conversion.
# Processed and saved Amad_Diallo.csv in merged_data/2021-22/MID
# 'starts' column not found in Bruno_André_Cavaco_Jordão.csv, skipping the conversion.
# Processed and saved Bruno_André_Cavaco_Jordão.csv in merged_data/2021-22/MID
# 'starts' column not found in Dilan_Markanday.csv, skipping the conversion.
# Processed and saved Dilan_Markanday.csv in merged_data/2021-22/MID
# 'starts' column not found in Tim_Iroegbunam.csv, skipping the conversion.
# Processed and saved Tim_Iroegbunam.csv in merged_data/2021-22/MID
# 'starts' column not found in Onel_Hernández.csv, skipping the conversion.
# Processed and saved Onel_Hernández.csv in merged_data/2021-22/MID
# 'starts' column not found in Harvey_White.csv, skipping the conversion.
# Processed and saved Harvey_White.csv in merged_data/2021-22/MID
# 'starts' column not found in Tyler_Morton.csv, skipping the conversion.
# Processed and saved Tyler_Morton.csv in merged_data/2021-22/MID
# 'starts' column not found in Jesse_Lingard.csv, skipping the conversion.
# Processed and saved Jesse_Lingard.csv in merged_data/2021-22/MID
# 'starts' column not found in Scott_McTominay.csv, skipping the conversion.
# Processed and saved Scott_McTominay.csv in merged_data/2021-22/MID
# 'starts' column not found in Tyler_Roberts.csv, skipping the conversion.
# Processed and saved Tyler_Roberts.csv in merged_data/2021-22/MID
# 'starts' column not found in Taylor_Richards.csv, skipping the conversion.
# Processed and saved Taylor_Richards.csv in merged_data/2021-22/MID
# 'starts' column not found in Salah-Eddine_Oulad_M'hand.csv, skipping the conversion.
# Processed and saved Salah-Eddine_Oulad_M'hand.csv in merged_data/2021-22/MID
# 'starts' column not found in Lucas_Torreira.csv, skipping the conversion.
# Processed and saved Lucas_Torreira.csv in merged_data/2021-22/MID
# 'starts' column not found in Charlie_Whitaker.csv, skipping the conversion.
# Processed and saved Charlie_Whitaker.csv in merged_data/2021-22/MID
# 'starts' column not found in Anthony_Elanga.csv, skipping the conversion.
# Processed and saved Anthony_Elanga.csv in merged_data/2021-22/MID
# 'starts' column not found in Alex_Oxlade-Chamberlain.csv, skipping the conversion.
# Processed and saved Alex_Oxlade-Chamberlain.csv in merged_data/2021-22/MID
# 'starts' column not found in Jorge_Luiz_Frello_Filho.csv, skipping the conversion.
# Processed and saved Jorge_Luiz_Frello_Filho.csv in merged_data/2021-22/MID
# 'starts' column not found in Miguel_Azeez.csv, skipping the conversion.
# Processed and saved Miguel_Azeez.csv in merged_data/2021-22/MID
# 'starts' column not found in Francisco_Jorge_Tomás_Oliveira.csv, skipping the conversion.
# Processed and saved Francisco_Jorge_Tomás_Oliveira.csv in merged_data/2021-22/MID
# 'starts' column not found in Mathias_Normann.csv, skipping the conversion.
# Processed and saved Mathias_Normann.csv in merged_data/2021-22/MID
# 'starts' column not found in Samuel_Edozie.csv, skipping the conversion.
# Processed and saved Samuel_Edozie.csv in merged_data/2021-22/MID
# 'starts' column not found in Chem_Campbell.csv, skipping the conversion.
# Processed and saved Chem_Campbell.csv in merged_data/2021-22/MID
# 'starts' column not found in Rúben_Diogo_da_Silva_Neves.csv, skipping the conversion.
# Processed and saved Rúben_Diogo_da_Silva_Neves.csv in merged_data/2021-22/MID
# 'starts' column not found in Rodrigo_Bentancur.csv, skipping the conversion.
# Processed and saved Rodrigo_Bentancur.csv in merged_data/2021-22/MID
# 'starts' column not found in Marcus_Rashford.csv, skipping the conversion.
# Processed and saved Marcus_Rashford.csv in merged_data/2021-22/MID
# 'starts' column not found in Marc_Leonard.csv, skipping the conversion.
# Processed and saved Marc_Leonard.csv in merged_data/2021-22/MID
# 'starts' column not found in Wilfried_Zaha.csv, skipping the conversion.
# Processed and saved Wilfried_Zaha.csv in merged_data/2021-22/MID
# 'starts' column not found in Steven_Alzate.csv, skipping the conversion.
# Processed and saved Steven_Alzate.csv in merged_data/2021-22/MID
# 'starts' column not found in Frank_Onyeka.csv, skipping the conversion.
# Processed and saved Frank_Onyeka.csv in merged_data/2021-22/MID
# 'starts' column not found in Tommi_O'Reilly.csv, skipping the conversion.
# Processed and saved Tommi_O'Reilly.csv in merged_data/2021-22/MID
# 'starts' column not found in Juan_Mata.csv, skipping the conversion.
# Processed and saved Juan_Mata.csv in merged_data/2021-22/MID
# 'starts' column not found in Thiago_Alcántara_do_Nascimento.csv, skipping the conversion.
# Processed and saved Thiago_Alcántara_do_Nascimento.csv in merged_data/2021-22/MID
# 'starts' column not found in James_McArthur.csv, skipping the conversion.
# Processed and saved James_McArthur.csv in merged_data/2021-22/MID
# 'starts' column not found in Raphael_Dias_Belloli.csv, skipping the conversion.
# Processed and saved Raphael_Dias_Belloli.csv in merged_data/2021-22/MID
# 'starts' column not found in Christian_Pulisic.csv, skipping the conversion.
# Processed and saved Christian_Pulisic.csv in merged_data/2021-22/MID
# 'starts' column not found in Pedro_Lomba_Neto.csv, skipping the conversion.
# Processed and saved Pedro_Lomba_Neto.csv in merged_data/2021-22/MID
# 'starts' column not found in Allan_Marques_Loureiro.csv, skipping the conversion.
# Processed and saved Allan_Marques_Loureiro.csv in merged_data/2021-22/MID
# 'starts' column not found in Mohamed_Salah.csv, skipping the conversion.
# Processed and saved Mohamed_Salah.csv in merged_data/2021-22/MID
# 'starts' column not found in Jean-Philippe_Gbamin.csv, skipping the conversion.
# Processed and saved Jean-Philippe_Gbamin.csv in merged_data/2021-22/MID
# 'starts' column not found in Lewis_Brunt.csv, skipping the conversion.
# Processed and saved Lewis_Brunt.csv in merged_data/2021-22/MID
# 'starts' column not found in Maxwel_Cornet.csv, skipping the conversion.
# Processed and saved Maxwel_Cornet.csv in merged_data/2021-22/MID
# 'starts' column not found in Mason_Greenwood.csv, skipping the conversion.
# Processed and saved Mason_Greenwood.csv in merged_data/2021-22/MID
# 'starts' column not found in James_Milner.csv, skipping the conversion.
# Processed and saved James_Milner.csv in merged_data/2021-22/MID
# 'starts' column not found in Moussa_Djenepo.csv, skipping the conversion.
# Processed and saved Moussa_Djenepo.csv in merged_data/2021-22/MID
# 'starts' column not found in Jeffrey_Schlupp.csv, skipping the conversion.
# Processed and saved Jeffrey_Schlupp.csv in merged_data/2021-22/MID
# 'starts' column not found in Ayoze_Pérez.csv, skipping the conversion.
# Processed and saved Ayoze_Pérez.csv in merged_data/2021-22/MID
# 'starts' column not found in Tariqe_Fosu-Henry.csv, skipping the conversion.
# Processed and saved Tariqe_Fosu-Henry.csv in merged_data/2021-22/MID
# 'starts' column not found in Dennis_Praet.csv, skipping the conversion.
# Processed and saved Dennis_Praet.csv in merged_data/2021-22/MID
# 'starts' column not found in Bryan_Mbeumo.csv, skipping the conversion.
# Processed and saved Bryan_Mbeumo.csv in merged_data/2021-22/MID
# 'starts' column not found in Callum_Hudson-Odoi.csv, skipping the conversion.
# Processed and saved Callum_Hudson-Odoi.csv in merged_data/2021-22/MID
# 'starts' column not found in Sonny_Perkins.csv, skipping the conversion.
# Processed and saved Sonny_Perkins.csv in merged_data/2021-22/MID
# 'starts' column not found in Armstrong_Oko-Flex.csv, skipping the conversion.
# Processed and saved Armstrong_Oko-Flex.csv in merged_data/2021-22/MID
# 'starts' column not found in Liam_McCarron.csv, skipping the conversion.
# Processed and saved Liam_McCarron.csv in merged_data/2021-22/MID
# 'starts' column not found in James_Rodríguez.csv, skipping the conversion.
# Processed and saved James_Rodríguez.csv in merged_data/2021-22/MID
# 'starts' column not found in Luke_Cundle.csv, skipping the conversion.
# Processed and saved Luke_Cundle.csv in merged_data/2021-22/MID
# 'starts' column not found in Tom_Cleverley.csv, skipping the conversion.
# Processed and saved Tom_Cleverley.csv in merged_data/2021-22/MID
# 'starts' column not found in Tanguy_Ndombele.csv, skipping the conversion.
# Processed and saved Tanguy_Ndombele.csv in merged_data/2021-22/MID
# 'starts' column not found in Theo_Walcott.csv, skipping the conversion.
# Processed and saved Theo_Walcott.csv in merged_data/2021-22/MID
# 'starts' column not found in Adam_Lallana.csv, skipping the conversion.
# Processed and saved Adam_Lallana.csv in merged_data/2021-22/MID
# 'starts' column not found in Wilfred_Ndidi.csv, skipping the conversion.
# Processed and saved Wilfred_Ndidi.csv in merged_data/2021-22/MID
# 'starts' column not found in Rodrigo_Hernandez.csv, skipping the conversion.
# Processed and saved Rodrigo_Hernandez.csv in merged_data/2021-22/MID
# 'starts' column not found in Joseph_Willock.csv, skipping the conversion.
# Processed and saved Joseph_Willock.csv in merged_data/2021-22/MID
# 'starts' column not found in Tomas_Soucek.csv, skipping the conversion.
# Processed and saved Tomas_Soucek.csv in merged_data/2021-22/MID
# 'starts' column not found in Declan_Rice.csv, skipping the conversion.
# Processed and saved Declan_Rice.csv in merged_data/2021-22/MID
# 'starts' column not found in Anthony_Mancini.csv, skipping the conversion.
# Processed and saved Anthony_Mancini.csv in merged_data/2021-22/MID
# 'starts' column not found in Oliver_Skipp.csv, skipping the conversion.
# Processed and saved Oliver_Skipp.csv in merged_data/2021-22/MID
# 'starts' column not found in Bertrand_Traoré.csv, skipping the conversion.
# Processed and saved Bertrand_Traoré.csv in merged_data/2021-22/MID
# 'starts' column not found in Boubakary_Soumaré.csv, skipping the conversion.
# Processed and saved Boubakary_Soumaré.csv in merged_data/2021-22/MID
# 'starts' column not found in Matthew_Longstaff.csv, skipping the conversion.
# Processed and saved Matthew_Longstaff.csv in merged_data/2021-22/MID
# 'starts' column not found in Jamie_Shackleton.csv, skipping the conversion.
# Processed and saved Jamie_Shackleton.csv in merged_data/2021-22/MID
# 'starts' column not found in Alejandro_Garnacho_Ferreyra.csv, skipping the conversion.
# Processed and saved Alejandro_Garnacho_Ferreyra.csv in merged_data/2021-22/MID
# 'starts' column not found in Willian_Borges_Da_Silva.csv, skipping the conversion.
# Processed and saved Willian_Borges_Da_Silva.csv in merged_data/2021-22/MID
# 'starts' column not found in Dwight_McNeil.csv, skipping the conversion.
# Processed and saved Dwight_McNeil.csv in merged_data/2021-22/MID
# 'starts' column not found in Sergi_Canós.csv, skipping the conversion.
# Processed and saved Sergi_Canós.csv in merged_data/2021-22/MID
# 'starts' column not found in Davy_Pröpper.csv, skipping the conversion.
# Processed and saved Davy_Pröpper.csv in merged_data/2021-22/MID
# 'starts' column not found in Isaac_Hayden.csv, skipping the conversion.
# Processed and saved Isaac_Hayden.csv in merged_data/2021-22/MID
# 'starts' column not found in Alfie_Devine.csv, skipping the conversion.
# Processed and saved Alfie_Devine.csv in merged_data/2021-22/MID
# 'starts' column not found in Nathaniel_Chalobah.csv, skipping the conversion.
# Processed and saved Nathaniel_Chalobah.csv in merged_data/2021-22/MID
# 'starts' column not found in Ilkay_Gündogan.csv, skipping the conversion.
# Processed and saved Ilkay_Gündogan.csv in merged_data/2021-22/MID
# 'starts' column not found in Ashley_Westwood.csv, skipping the conversion.
# Processed and saved Ashley_Westwood.csv in merged_data/2021-22/MID
# 'starts' column not found in Owen_Otasowie.csv, skipping the conversion.
# Processed and saved Owen_Otasowie.csv in merged_data/2021-22/MID
# 'starts' column not found in Nathan_Redmond.csv, skipping the conversion.
# Processed and saved Nathan_Redmond.csv in merged_data/2021-22/MID
# 'starts' column not found in Bamidele_Alli.csv, skipping the conversion.
# Processed and saved Bamidele_Alli.csv in merged_data/2021-22/MID
# 'starts' column not found in Milot_Rashica.csv, skipping the conversion.
# Processed and saved Milot_Rashica.csv in merged_data/2021-22/MID
# 'starts' column not found in Mads_Bidstrup.csv, skipping the conversion.
# Processed and saved Mads_Bidstrup.csv in merged_data/2021-22/MID
# 'starts' column not found in Bukayo_Saka.csv, skipping the conversion.
# Processed and saved Bukayo_Saka.csv in merged_data/2021-22/MID
# 'starts' column not found in Andriy_Yarmolenko.csv, skipping the conversion.
# Processed and saved Andriy_Yarmolenko.csv in merged_data/2021-22/MID
# 'starts' column not found in Enock_Mwepu.csv, skipping the conversion.
# Processed and saved Enock_Mwepu.csv in merged_data/2021-22/MID
# 'starts' column not found in Samuel_Kalu.csv, skipping the conversion.
# Processed and saved Samuel_Kalu.csv in merged_data/2021-22/MID
# Processed and saved Ryan_Yates.csv in merged_data/2022-23/MID
# Processed and saved Gonçalo_Manuel_Ganchinho_Guedes.csv in merged_data/2022-23/MID
# Processed and saved Joe_Rothwell.csv in merged_data/2022-23/MID
# Processed and saved Lucas_Tolentino_Coelho_de_Lima.csv in merged_data/2022-23/MID
# Processed and saved Mikkel_Damsgaard.csv in merged_data/2022-23/MID
# Processed and saved Vitaly_Janelt.csv in merged_data/2022-23/MID
# Processed and saved Morgan_Gibbs-White.csv in merged_data/2022-23/MID
# Processed and saved Jonjo_Shelvey.csv in merged_data/2022-23/MID
# Processed and saved Bryan_Gil_Salvatierra.csv in merged_data/2022-23/MID
# Processed and saved Miguel_Almirón_Rejala.csv in merged_data/2022-23/MID
# Processed and saved Dango_Ouattara.csv in merged_data/2022-23/MID
# Processed and saved N'Golo_Kanté.csv in merged_data/2022-23/MID
# Processed and saved Donny_van_de_Beek.csv in merged_data/2022-23/MID
# Processed and saved Shandon_Baptiste.csv in merged_data/2022-23/MID
# Processed and saved Carlos_Alcaraz.csv in merged_data/2022-23/MID
# Processed and saved Hamza_Choudhury.csv in merged_data/2022-23/MID
# Processed and saved Curtis_Jones.csv in merged_data/2022-23/MID
# Processed and saved Alexis_Mac_Allister.csv in merged_data/2022-23/MID
# Processed and saved Tom_Davies.csv in merged_data/2022-23/MID
# Processed and saved Junior_Stanislas.csv in merged_data/2022-23/MID
# Processed and saved Mohamed_Elyounoussi.csv in merged_data/2022-23/MID
# Processed and saved Siriki_Dembélé.csv in merged_data/2022-23/MID
# Processed and saved Jordan_Ayew.csv in merged_data/2022-23/MID
# Processed and saved Bruno_Guimarães_Rodriguez_Moura.csv in merged_data/2022-23/MID
# Processed and saved Oriol_Romeu_Vidal.csv in merged_data/2022-23/MID
# Processed and saved Josh_Onomah.csv in merged_data/2022-23/MID
# Processed and saved Lewis_Hall.csv in merged_data/2022-23/MID
# Processed and saved Yoane_Wissa.csv in merged_data/2022-23/MID
# Processed and saved James_Maddison.csv in merged_data/2022-23/MID
# Processed and saved Idrissa_Gueye.csv in merged_data/2022-23/MID
# Processed and saved Emiliano_Buendía_Stati.csv in merged_data/2022-23/MID
# Processed and saved Matthew_Dibley-Dias.csv in merged_data/2022-23/MID
# Processed and saved Harvey_Barnes.csv in merged_data/2022-23/MID
# Processed and saved Flynn_Downes.csv in merged_data/2022-23/MID
# Processed and saved Ross_Barkley.csv in merged_data/2022-23/MID
# Processed and saved Zidane_Iqbal.csv in merged_data/2022-23/MID
# Processed and saved Frederico_Rodrigues_de_Paula_Santos.csv in merged_data/2022-23/MID
# Processed and saved Jesurun_Rak-Sakyi.csv in merged_data/2022-23/MID
# Processed and saved Cole_Palmer.csv in merged_data/2022-23/MID
# Processed and saved Brenden_Aaronson.csv in merged_data/2022-23/MID
# Processed and saved Philip_Billing.csv in merged_data/2022-23/MID
# Processed and saved Carney_Chukwuemeka.csv in merged_data/2022-23/MID
# Processed and saved Anwar_El_Ghazi.csv in merged_data/2022-23/MID
# Processed and saved Mason_Mount.csv in merged_data/2022-23/MID
# Processed and saved Cameron_Peupion.csv in merged_data/2022-23/MID
# Processed and saved Luis_Díaz.csv in merged_data/2022-23/MID
# Processed and saved Daniel_Castelo_Podence.csv in merged_data/2022-23/MID
# Processed and saved Fábio_Freitas_Gouveia_Carvalho.csv in merged_data/2022-23/MID
# Processed and saved Wanya_Marçal-Madivadua.csv in merged_data/2022-23/MID
# Processed and saved Saman_Ghoddos.csv in merged_data/2022-23/MID
# Processed and saved Mauro_Bandeira.csv in merged_data/2022-23/MID
# Processed and saved Jacob_Ramsey.csv in merged_data/2022-23/MID
# Processed and saved Thomas_Partey.csv in merged_data/2022-23/MID
# Processed and saved Tyler_Adams.csv in merged_data/2022-23/MID
# Processed and saved Dejan_Kulusevski.csv in merged_data/2022-23/MID
# Processed and saved Nampalys_Mendy.csv in merged_data/2022-23/MID
# Processed and saved Weston_McKennie.csv in merged_data/2022-23/MID
# Processed and saved Kevin_De_Bruyne.csv in merged_data/2022-23/MID
# ...
# Processed and saved James_Ward-Prowse.csv in merged_data/2023-24/MID
# Processed and saved David_Ozoh.csv in merged_data/2023-24/MID
# Processed and saved Abdoulaye_Doucouré.csv in merged_data/2023-24/MID
# Processed and saved Jack_Grealish.csv in merged_data/2023-24/MID
# Processed and saved Eberechi_Eze.csv in merged_data/2023-24/MID
# Processed and saved Harry_Wilson.csv in merged_data/2023-24/MID
# Processed and saved Noni_Madueke.csv in merged_data/2023-24/MID
# Processed and saved Ryan_Christie.csv in merged_data/2023-24/MID
# Processed and saved Tomáš_Souček.csv in merged_data/2023-24/MID
# Processed and saved Ryan_Fraser.csv in merged_data/2023-24/MID
# Processed and saved Jarrod_Bowen.csv in merged_data/2023-24/MID
# Processed and saved Alejandro_Garnacho.csv in merged_data/2023-24/MID
# Processed and saved Marcus_Tavernier.csv in merged_data/2023-24/MID
# Processed and saved Anass_Zaroury.csv in merged_data/2023-24/MID
# Processed and saved Jóhann_Berg_Gudmundsson.csv in merged_data/2023-24/MID
# Processed and saved Anthony_Knockaert.csv in merged_data/2023-24/MID
# Processed and saved Dominik_Szoboszlai.csv in merged_data/2023-24/MID
# Processed and saved Enzo_Fernández.csv in merged_data/2023-24/MID
# Processed and saved Emile_Smith_Rowe.csv in merged_data/2023-24/MID
# Processed and saved Kalvin_Phillips.csv in merged_data/2023-24/MID
# Processed and saved Harry_Arter.csv in merged_data/2023-24/MID
# Processed and saved Harvey_Elliott.csv in merged_data/2023-24/MID
# Processed and saved Charles_Sagoe.csv in merged_data/2023-24/MID
# Processed and saved John_Fleck.csv in merged_data/2023-24/MID
# Processed and saved Han-Noah_Massengo.csv in merged_data/2023-24/MID
# Processed and saved Elliot_Anderson.csv in merged_data/2023-24/MID
# Processed and saved Andros_Townsend.csv in merged_data/2023-24/MID
# Processed and saved Yasin_Ayari.csv in merged_data/2023-24/MID
# Processed and saved Raheem_Sterling.csv in merged_data/2023-24/MID
# Processed and saved Ryan_Oné.csv in merged_data/2023-24/MID
# Processed and saved Leandro_Trossard.csv in merged_data/2023-24/MID
# Processed and saved Justin_Kluivert.csv in merged_data/2023-24/MID
# Processed and saved Jean-Ricner_Bellegarde.csv in merged_data/2023-24/MID
# Processed and saved Cheikhou_Kouyaté.csv in merged_data/2023-24/MID
# Processed and saved Mohamed_Elneny.csv in merged_data/2023-24/MID
# Processed and saved Myles_Peart-Harris.csv in merged_data/2023-24/MID
# Processed and saved Malcolm_Ebiowei.csv in merged_data/2023-24/MID
# Processed and saved Jordan_Henderson.csv in merged_data/2023-24/MID
# Processed and saved Ben_Pearson.csv in merged_data/2023-24/MID
# Processed and saved Hannibal_Mejbri.csv in merged_data/2023-24/MID
# Processed and saved Martin_Ødegaard.csv in merged_data/2023-24/MID
# Processed and saved Billy_Gilmour.csv in merged_data/2023-24/MID
# Processed and saved Morgan_Sanson.csv in merged_data/2023-24/MID
# Processed and saved Gustavo_Hamer.csv in merged_data/2023-24/MID
# Processed and saved Pascal_Groß.csv in merged_data/2023-24/MID
# Processed and saved Michael_Olakigbe.csv in merged_data/2023-24/MID
# Processed and saved Mathias_Jensen.csv in merged_data/2023-24/MID
# Processed and saved Reiss_Nelson.csv in merged_data/2023-24/MID
# Processed and saved Tyler_Onyango.csv in merged_data/2023-24/MID
# Processed and saved Andre_Brooks.csv in merged_data/2023-24/MID
# Processed and saved Jacob_Wright.csv in merged_data/2023-24/MID
# Processed and saved Ethan_Brierley.csv in merged_data/2023-24/MID
# Processed and saved Lewis_Miley.csv in merged_data/2023-24/MID
# Processed and saved Amadou_Onana.csv in merged_data/2023-24/MID
# Processed and saved Adama_Traoré.csv in merged_data/2023-24/MID
# Processed and saved Matt_Ritchie.csv in merged_data/2023-24/MID
# Processed and saved Anthony_Gordon.csv in merged_data/2023-24/MID
# Processed and saved Mikey_Moore.csv in merged_data/2023-24/MID
# Processed and saved James_McAtee.csv in merged_data/2023-24/MID
# Processed and saved Sandro_Tonali.csv in merged_data/2023-24/MID
# Processed and saved Jack_Harrison.csv in merged_data/2023-24/MID
# Processed and saved Saïd_Benrahma.csv in merged_data/2023-24/MID
# Processed and saved Jamal_Lowe.csv in merged_data/2023-24/MID
# Processed and saved Kevin_Schade.csv in merged_data/2023-24/MID
# Processed and saved Christian_Nørgaard.csv in merged_data/2023-24/MID
# Processed and saved Tommy_Doyle.csv in merged_data/2023-24/MID
# Processed and saved Riyad_Mahrez.csv in merged_data/2023-24/MID
# Processed and saved Giovani_Lo_Celso.csv in merged_data/2023-24/MID
# Processed and saved Alex_Mighten.csv in merged_data/2023-24/MID
# Processed and saved Jefferson_Lerma_Solís.csv in merged_data/2023-24/MID
# Processed and saved Michael_Olise.csv in merged_data/2023-24/MID
# Processed and saved Benicio_Baker-Boaitey.csv in merged_data/2023-24/MID
# Processed and saved Facundo_Buonanotte.csv in merged_data/2023-24/MID
# Processed and saved Jadan_Raymond.csv in merged_data/2023-24/MID
# Processed and saved Albert_Sambi_Lokonga.csv in merged_data/2023-24/MID
# Processed and saved Oliver_Norwood.csv in merged_data/2023-24/MID
# Processed and saved Bruno_Borges_Fernandes.csv in merged_data/2023-24/MID
# Processed and saved George_Earthy.csv in merged_data/2023-24/MID
# Processed and saved Josh_Bowler.csv in merged_data/2023-24/MID
# Processed and saved Mahmoud_Dahoud.csv in merged_data/2023-24/MID
# Processed and saved Leon_Bailey.csv in merged_data/2023-24/MID
# Processed and saved Cheick_Doucouré.csv in merged_data/2023-24/MID
# Processed and saved Mateo_Kovačić.csv in merged_data/2023-24/MID
# Processed and saved Jayden_Luker.csv in merged_data/2023-24/MID
# Processed and saved Aaron_Ramsey.csv in merged_data/2023-24/MID
# Processed and saved Nicolas_Pépé.csv in merged_data/2023-24/MID
# Processed and saved Sofyan_Amrabat.csv in merged_data/2023-24/MID
# Processed and saved Hamed_Traorè.csv in merged_data/2023-24/MID
# Processed and saved Saša_Lukić.csv in merged_data/2023-24/MID
# Processed and saved Pelly_Ruddock_Mpanzu.csv in merged_data/2023-24/MID
# Processed and saved Ryan_Gravenberch.csv in merged_data/2023-24/MID
# Processed and saved Moussa_Diaby.csv in merged_data/2023-24/MID
# Processed and saved Granit_Xhaka.csv in merged_data/2023-24/MID
# Processed and saved Wilson_Odobert.csv in merged_data/2023-24/MID
# Processed and saved Josh_Brownhill.csv in merged_data/2023-24/MID
# Processed and saved Yegor_Yarmoliuk.csv in merged_data/2023-24/MID
# Processed and saved Lesley_Ugochukwu.csv in merged_data/2023-24/MID
# Processed and saved Jairo_Riedewald.csv in merged_data/2023-24/MID
# Processed and saved Mohammed_Kudus.csv in merged_data/2023-24/MID
# Processed and saved Amadou_Diallo.csv in merged_data/2023-24/MID
# Processed and saved Dominic_Sadi.csv in merged_data/2023-24/MID
# Processed and saved Conor_Gallagher.csv in merged_data/2023-24/MID
# Processed and saved Will_Hughes.csv in merged_data/2023-24/MID
# Processed and saved Joe_Willock.csv in merged_data/2023-24/MID
# Processed and saved Lewis_O'Brien.csv in merged_data/2023-24/MID
# Processed and saved Sean_Longstaff.csv in merged_data/2023-24/MID
# Processed and saved Omari_Kellyman.csv in merged_data/2023-24/MID
# Processed and saved Sergi_Canós_Tenés.csv in merged_data/2023-24/MID
# Processed and saved Jacob_Murphy.csv in merged_data/2023-24/MID
# Processed and saved Christian_Eriksen.csv in merged_data/2023-24/MID
# Processed and saved Yves_Bissouma.csv in merged_data/2023-24/MID
# Processed and saved Ryan_Trevitt.csv in merged_data/2023-24/MID
# Processed and saved Boubacar_Traoré.csv in merged_data/2023-24/MID
# Processed and saved Jack_Hinshelwood.csv in merged_data/2023-24/MID
# Processed and saved Jaden_Philogene-Bidace.csv in merged_data/2023-24/MID
# Processed and saved Hakim_Ziyech.csv in merged_data/2023-24/MID
# Processed and saved Conor_Coventry.csv in merged_data/2023-24/MID
# Processed and saved Phil_Foden.csv in merged_data/2023-24/MID
# Processed and saved Edson_Álvarez_Velázquez.csv in merged_data/2023-24/MID
# Processed and saved Philippe_Coutinho_Correia.csv in merged_data/2023-24/MID
# Processed and saved Jadon_Sancho.csv in merged_data/2023-24/MID
# Processed and saved Matheus_Luiz_Nunes.csv in merged_data/2023-24/MID
# Processed and saved Romain_Faivre.csv in merged_data/2023-24/MID
# Processed and saved Joe_White.csv in merged_data/2023-24/MID
# Processed and saved Jakub_Moder.csv in merged_data/2023-24/MID
# Processed and saved Kaoru_Mitoma.csv in merged_data/2023-24/MID
# Processed and saved Ben_Osborn.csv in merged_data/2023-24/MID
# Processed and saved Jérémy_Doku.csv in merged_data/2023-24/MID
# Processed and saved Luca_Barrington.csv in merged_data/2023-24/MID
# Processed and saved Luke_Berry.csv in merged_data/2023-24/MID
# Processed and saved Dele_Alli.csv in merged_data/2023-24/MID
# Processed and saved Dion_Pereira.csv in merged_data/2023-24/MID
# Processed and saved Jack_Cork.csv in merged_data/2023-24/MID
# Processed and saved Kai_Havertz.csv in merged_data/2023-24/MID
# Processed and saved Marvelous_Nakamba.csv in merged_data/2023-24/MID
# Processed and saved Luke_Harris.csv in merged_data/2023-24/MID
# Processed and saved Douglas_Luiz_Soares_de_Paulo.csv in merged_data/2023-24/MID
# Processed and saved Oliver_Arblaster.csv in merged_data/2023-24/MID
# Processed and saved Stefan_Bajcetic.csv in merged_data/2023-24/MID
# Processed and saved Tahith_Chong.csv in merged_data/2023-24/MID
# Processed and saved Josh_Dasilva.csv in merged_data/2023-24/MID
# Processed and saved Jamie_McDonnell.csv in merged_data/2023-24/MID
# Processed and saved Allan_Saint-Maximin.csv in merged_data/2023-24/MID
# Processed and saved Julio_Enciso.csv in merged_data/2023-24/MID
# Processed and saved Manor_Solomon.csv in merged_data/2023-24/MID
# Processed and saved Son_Heung-min.csv in merged_data/2023-24/MID
# Processed and saved Máximo_Perrone.csv in merged_data/2023-24/MID
# Processed and saved Leander_Dendoncker.csv in merged_data/2023-24/MID
# Processed and saved Youri_Tielemans.csv in merged_data/2023-24/MID
# Processed and saved Pierre-Emile_Højbjerg.csv in merged_data/2023-24/MID
# Processed and saved Pablo_Sarabia.csv in merged_data/2023-24/MID
# Processed and saved Nicolò_Zaniolo.csv in merged_data/2023-24/MID
# Processed and saved Ibrahim_Sangaré.csv in merged_data/2023-24/MID
# Processed and saved Bobby_Clark.csv in merged_data/2023-24/MID
# Processed and saved John_McGinn.csv in merged_data/2023-24/MID
# Processed and saved Brandon_Aguilera_Zamora.csv in merged_data/2023-24/MID
# Processed and saved Josh_Cullen.csv in merged_data/2023-24/MID
# Processed and saved Tyrese_Francois.csv in merged_data/2023-24/MID
# Processed and saved Michale_Olakigbe.csv in merged_data/2023-24/MID
# Processed and saved James_Garner.csv in merged_data/2023-24/MID
# Processed and saved James_McConnell.csv in merged_data/2023-24/MID
# Processed and saved Orel_Mangala.csv in merged_data/2023-24/MID
# Processed and saved Zack_Nelson.csv in merged_data/2023-24/MID
# Processed and saved Demarai_Gray.csv in merged_data/2023-24/MID
# Processed and saved Amad_Diallo.csv in merged_data/2023-24/MID
# Processed and saved Joelinton_Cássio_Apolinário_de_Lira.csv in merged_data/2023-24/MID
# Processed and saved Fred_Onyedinma.csv in merged_data/2023-24/MID
# Processed and saved Daniel_Gore.csv in merged_data/2023-24/MID
# Processed and saved Tim_Iroegbunam.csv in merged_data/2023-24/MID
# Processed and saved Kobbie_Mainoo.csv in merged_data/2023-24/MID
# Processed and saved Scott_McTominay.csv in merged_data/2023-24/MID
# Processed and saved Tawanda_Chirewa.csv in merged_data/2023-24/MID
# Processed and saved Ben_Doak.csv in merged_data/2023-24/MID
# Processed and saved Roméo_Lavia.csv in merged_data/2023-24/MID
# Processed and saved Alex_Scott.csv in merged_data/2023-24/MID
# Processed and saved Anthony_Elanga.csv in merged_data/2023-24/MID
# Processed and saved Naouirou_Ahamada.csv in merged_data/2023-24/MID
# Processed and saved Lewis_Warrington.csv in merged_data/2023-24/MID
# Processed and saved Oscar_Bobb.csv in merged_data/2023-24/MID
# Processed and saved Rodrigo_Bentancur.csv in merged_data/2023-24/MID
# Processed and saved Marcus_Rashford.csv in merged_data/2023-24/MID
# Processed and saved Jeremy_Sarmiento_Morante.csv in merged_data/2023-24/MID
# Processed and saved Nicolás_Domínguez.csv in merged_data/2023-24/MID
# Processed and saved Frank_Onyeka.csv in merged_data/2023-24/MID
# Processed and saved João_Palhinha_Gonçalves.csv in merged_data/2023-24/MID
# Processed and saved Thiago_Alcántara_do_Nascimento.csv in merged_data/2023-24/MID
# Processed and saved Christian_Pulisic.csv in merged_data/2023-24/MID
# Processed and saved Simon_Adingra.csv in merged_data/2023-24/MID
# Processed and saved Morgan_Rogers.csv in merged_data/2023-24/MID
# Processed and saved Mohamed_Salah.csv in merged_data/2023-24/MID
# Processed and saved Jean-Philippe_Gbamin.csv in merged_data/2023-24/MID
# Processed and saved Gabriel_Martinelli_Silva.csv in merged_data/2023-24/MID
# Processed and saved Tom_Cairney.csv in merged_data/2023-24/MID
# Processed and saved Harrison_Reed.csv in merged_data/2023-24/MID
# Processed and saved Maxwel_Cornet.csv in merged_data/2023-24/MID
# Processed and saved James_Milner.csv in merged_data/2023-24/MID
# Processed and saved Ethan_Nwaneri.csv in merged_data/2023-24/MID
# Processed and saved Lewis_Orford.csv in merged_data/2023-24/MID
# Processed and saved Jeffrey_Schlupp.csv in merged_data/2023-24/MID
# Processed and saved Luca_Koleosho.csv in merged_data/2023-24/MID
# Processed and saved Kiano_Dyer.csv in merged_data/2023-24/MID
# Processed and saved Mykhailo_Mudryk.csv in merged_data/2023-24/MID
# Processed and saved Bryan_Mbeumo.csv in merged_data/2023-24/MID
# Processed and saved Callum_Hudson-Odoi.csv in merged_data/2023-24/MID
# Processed and saved Ty_Barnett.csv in merged_data/2023-24/MID
# Processed and saved Moisés_Caicedo_Corozo.csv in merged_data/2023-24/MID
# Processed and saved Enso_González.csv in merged_data/2023-24/MID
# Processed and saved Emiliano_Marcondes.csv in merged_data/2023-24/MID
# Processed and saved Sander_Berge.csv in merged_data/2023-24/MID
# Processed and saved Adam_Lallana.csv in merged_data/2023-24/MID
# Processed and saved David_Brooks.csv in merged_data/2023-24/MID
# Processed and saved Joe_Hodge.csv in merged_data/2023-24/MID
# Processed and saved Arnaut_Danjuma_Groeneveld.csv in merged_data/2023-24/MID
# Processed and saved Rodrigo_Hernandez.csv in merged_data/2023-24/MID
# Processed and saved Noha_Lemina.csv in merged_data/2023-24/MID
# Processed and saved Louie_Watson.csv in merged_data/2023-24/MID
# Processed and saved Declan_Rice.csv in merged_data/2023-24/MID
# Processed and saved Carlos_Baleba.csv in merged_data/2023-24/MID
# Processed and saved Oliver_Skipp.csv in merged_data/2023-24/MID
# Processed and saved Bertrand_Traoré.csv in merged_data/2023-24/MID
# Processed and saved Pablo_Fornals_Malla.csv in merged_data/2023-24/MID
# Processed and saved Facundo_Pellistri_Rebollo.csv in merged_data/2023-24/MID
# Processed and saved Anis_Slimane.csv in merged_data/2023-24/MID
# Processed and saved Giovanni_Reyna.csv in merged_data/2023-24/MID
# Processed and saved Jaidon_Anthony.csv in merged_data/2023-24/MID
# Processed and saved Dwight_McNeil.csv in merged_data/2023-24/MID
# Processed and saved Brennan_Johnson.csv in merged_data/2023-24/MID
# Processed and saved Yegor_Yarmolyuk.csv in merged_data/2023-24/MID
# Processed and saved Keane_Lewis-Potter.csv in merged_data/2023-24/MID
# Processed and saved Isaac_Hayden.csv in merged_data/2023-24/MID
# Processed and saved Mario_Lemina.csv in merged_data/2023-24/MID
# Processed and saved Boubacar_Kamara.csv in merged_data/2023-24/MID
# Processed and saved Lewis_Cook.csv in merged_data/2023-24/MID
# Processed and saved Matheus_França_de_Oliveira.csv in merged_data/2023-24/MID
# Processed and saved Solly_March.csv in merged_data/2023-24/MID
# Processed and saved Mike_Trésor.csv in merged_data/2023-24/MID
# Processed and saved Nathan_Redmond.csv in merged_data/2023-24/MID
# Processed and saved Micah_Hamilton.csv in merged_data/2023-24/MID
# Processed and saved Bukayo_Saka.csv in merged_data/2023-24/MID
# Processed and saved Wataru_Endo.csv in merged_data/2023-24/MID
# Processed and saved Jacob_Bruun_Larsen.csv in merged_data/2023-24/MID

# %%
import os
import pandas as pd

# RESTRUCTURING THE DEF FOLDER
merged_data_dir = 'merged_data'
seasons = ['2021-22', '2022-23', '2023-24']
def_folder = 'DEF'

# Columns to drop
columns_to_drop = ['position_x', 'kickoff_time', 'time', 'own_goals']

# Column order as specified for the DEF folder
desired_column_order = [
    'name', 'team', 'opponent_team', 'date', 'was_home', 'position_y', 'minutes', 'goals', 'xG', 'assists', 'xA',
    'total_points', 'shots', 'key_passes', 'ict_index', 'bonus', 'clean_sheets', 'goals_conceded', 'expected_goals_conceded', 'starts'
]

# Loop through each season and process the DEF folder
for season in seasons:
    def_dir = os.path.join(merged_data_dir, season, def_folder)
    
    if os.path.isdir(def_dir):
        for csv_file in os.listdir(def_dir):
            if csv_file.endswith('.csv'):
                file_path = os.path.join(def_dir, csv_file)
                
                # Read the CSV file
                df = pd.read_csv(file_path)
                
                # Step 1: Drop the unnecessary columns
                df = df.drop(columns=[col for col in columns_to_drop if col in df.columns], errors='ignore')
                
                # Step 2: Convert 'starts' column to boolean (True/False) if it exists
                if 'starts' in df.columns:
                    df['starts'] = df['starts'].apply(lambda x: True if x == 1 else False)
                else:
                    print(f"'starts' column not found in {csv_file}, skipping the conversion.")
                
                # Step 3: Reorder the columns, but first check for missing columns
                existing_columns = [col for col in desired_column_order if col in df.columns]
                df = df[existing_columns]
                
                # Step 4: Rename 'position_y' to 'position' if 'position_y' exists
                if 'position_y' in df.columns:
                    df = df.rename(columns={'position_y': 'position'})
                
                # Save the modified CSV file back
                df.to_csv(file_path, index=False)
                print(f"Processed and saved {csv_file} in {def_dir}")
# Out:
# 'starts' column not found in Nathan_Aké.csv, skipping the conversion.
# Processed and saved Nathan_Aké.csv in merged_data/2021-22/DEF
# 'starts' column not found in Andreas_Christensen.csv, skipping the conversion.
# Processed and saved Andreas_Christensen.csv in merged_data/2021-22/DEF
# 'starts' column not found in Pablo_Marí.csv, skipping the conversion.
# Processed and saved Pablo_Marí.csv in merged_data/2021-22/DEF
# 'starts' column not found in Tariq_Lamptey.csv, skipping the conversion.
# Processed and saved Tariq_Lamptey.csv in merged_data/2021-22/DEF
# 'starts' column not found in Samir_Caetano_de_Souza_Santos.csv, skipping the conversion.
# Processed and saved Samir_Caetano_de_Souza_Santos.csv in merged_data/2021-22/DEF
# 'starts' column not found in Adam_Webster.csv, skipping the conversion.
# Processed and saved Adam_Webster.csv in merged_data/2021-22/DEF
# 'starts' column not found in Zach_Awe.csv, skipping the conversion.
# Processed and saved Zach_Awe.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nathaniel_Phillips.csv, skipping the conversion.
# Processed and saved Nathaniel_Phillips.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jarrad_Branthwaite.csv, skipping the conversion.
# Processed and saved Jarrad_Branthwaite.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_Nelson.csv, skipping the conversion.
# Processed and saved Ben_Nelson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Joe_Rodon.csv, skipping the conversion.
# Processed and saved Joe_Rodon.csv in merged_data/2021-22/DEF
# 'starts' column not found in Harrison_Ashby.csv, skipping the conversion.
# Processed and saved Harrison_Ashby.csv in merged_data/2021-22/DEF
# 'starts' column not found in Issa_Diop.csv, skipping the conversion.
# Processed and saved Issa_Diop.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jonjoe_Kenny.csv, skipping the conversion.
# Processed and saved Jonjoe_Kenny.csv in merged_data/2021-22/DEF
# 'starts' column not found in Zak_Swanson.csv, skipping the conversion.
# Processed and saved Zak_Swanson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Tino_Livramento.csv, skipping the conversion.
# Processed and saved Tino_Livramento.csv in merged_data/2021-22/DEF
# 'starts' column not found in Benjamin_Chilwell.csv, skipping the conversion.
# Processed and saved Benjamin_Chilwell.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jarell_Quansah.csv, skipping the conversion.
# Processed and saved Jarell_Quansah.csv in merged_data/2021-22/DEF
# 'starts' column not found in Michael_Keane.csv, skipping the conversion.
# Processed and saved Michael_Keane.csv in merged_data/2021-22/DEF
# 'starts' column not found in Reece_Hannam.csv, skipping the conversion.
# Processed and saved Reece_Hannam.csv in merged_data/2021-22/DEF
# 'starts' column not found in Emerson_Palmieri_dos_Santos.csv, skipping the conversion.
# Processed and saved Emerson_Palmieri_dos_Santos.csv in merged_data/2021-22/DEF
# 'starts' column not found in Javier_Manquillo.csv, skipping the conversion.
# Processed and saved Javier_Manquillo.csv in merged_data/2021-22/DEF
# 'starts' column not found in Timothy_Castagne.csv, skipping the conversion.
# Processed and saved Timothy_Castagne.csv in merged_data/2021-22/DEF
# 'starts' column not found in Joel_Ward.csv, skipping the conversion.
# Processed and saved Joel_Ward.csv in merged_data/2021-22/DEF
# 'starts' column not found in Wesley_Fofana.csv, skipping the conversion.
# Processed and saved Wesley_Fofana.csv in merged_data/2021-22/DEF
# 'starts' column not found in Arthur_Masuaku.csv, skipping the conversion.
# Processed and saved Arthur_Masuaku.csv in merged_data/2021-22/DEF
# 'starts' column not found in Lucas_Digne.csv, skipping the conversion.
# Processed and saved Lucas_Digne.csv in merged_data/2021-22/DEF
# 'starts' column not found in Conrad_Egan-Riley.csv, skipping the conversion.
# Processed and saved Conrad_Egan-Riley.csv in merged_data/2021-22/DEF
# 'starts' column not found in Vontae_Daley-Campbell.csv, skipping the conversion.
# Processed and saved Vontae_Daley-Campbell.csv in merged_data/2021-22/DEF
# 'starts' column not found in Adam_Masina.csv, skipping the conversion.
# Processed and saved Adam_Masina.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ibrahima_Konaté.csv, skipping the conversion.
# Processed and saved Ibrahima_Konaté.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kurt_Zouma.csv, skipping the conversion.
# Processed and saved Kurt_Zouma.csv in merged_data/2021-22/DEF
# 'starts' column not found in Matt_Targett.csv, skipping the conversion.
# Processed and saved Matt_Targett.csv in merged_data/2021-22/DEF
# 'starts' column not found in Cody_Drameh.csv, skipping the conversion.
# Processed and saved Cody_Drameh.csv in merged_data/2021-22/DEF
# 'starts' column not found in Angelo_Ogbonna.csv, skipping the conversion.
# Processed and saved Angelo_Ogbonna.csv in merged_data/2021-22/DEF
# 'starts' column not found in Gabriel_Magalhães.csv, skipping the conversion.
# Processed and saved Gabriel_Magalhães.csv in merged_data/2021-22/DEF
# 'starts' column not found in Joel_Matip.csv, skipping the conversion.
# Processed and saved Joel_Matip.csv in merged_data/2021-22/DEF
# 'starts' column not found in Sergio_Reguilón.csv, skipping the conversion.
# Processed and saved Sergio_Reguilón.csv in merged_data/2021-22/DEF
# 'starts' column not found in Cédric_Soares.csv, skipping the conversion.
# Processed and saved Cédric_Soares.csv in merged_data/2021-22/DEF
# 'starts' column not found in Owen_Dodgson.csv, skipping the conversion.
# Processed and saved Owen_Dodgson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Andrew_Omobamidele.csv, skipping the conversion.
# Processed and saved Andrew_Omobamidele.csv in merged_data/2021-22/DEF
# 'starts' column not found in Pierre_Ekwah.csv, skipping the conversion.
# Processed and saved Pierre_Ekwah.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ethan_Ampadu.csv, skipping the conversion.
# Processed and saved Ethan_Ampadu.csv in merged_data/2021-22/DEF
# 'starts' column not found in Francisco_Sierralta.csv, skipping the conversion.
# Processed and saved Francisco_Sierralta.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nathan_Ferguson.csv, skipping the conversion.
# Processed and saved Nathan_Ferguson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Christian_Kabasele.csv, skipping the conversion.
# Processed and saved Christian_Kabasele.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jonathan_Tomkinson.csv, skipping the conversion.
# Processed and saved Jonathan_Tomkinson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_Davies.csv, skipping the conversion.
# Processed and saved Ben_Davies.csv in merged_data/2021-22/DEF
# 'starts' column not found in Conor_Coady.csv, skipping the conversion.
# Processed and saved Conor_Coady.csv in merged_data/2021-22/DEF
# 'starts' column not found in Luke_Shaw.csv, skipping the conversion.
# Processed and saved Luke_Shaw.csv in merged_data/2021-22/DEF
# 'starts' column not found in Mathias_Jorgensen.csv, skipping the conversion.
# Processed and saved Mathias_Jorgensen.csv in merged_data/2021-22/DEF
# 'starts' column not found in Reece_Welch.csv, skipping the conversion.
# Processed and saved Reece_Welch.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_Wilmot.csv, skipping the conversion.
# Processed and saved Ben_Wilmot.csv in merged_data/2021-22/DEF
# 'starts' column not found in Héctor_Junior_Firpo_Adames.csv, skipping the conversion.
# Processed and saved Héctor_Junior_Firpo_Adames.csv in merged_data/2021-22/DEF
# 'starts' column not found in Romain_Perraud.csv, skipping the conversion.
# Processed and saved Romain_Perraud.csv in merged_data/2021-22/DEF
# 'starts' column not found in Tyrone_Mings.csv, skipping the conversion.
# Processed and saved Tyrone_Mings.csv in merged_data/2021-22/DEF
# 'starts' column not found in Mason_Holgate.csv, skipping the conversion.
# Processed and saved Mason_Holgate.csv in merged_data/2021-22/DEF
# 'starts' column not found in Benjamin_Mendy.csv, skipping the conversion.
# Processed and saved Benjamin_Mendy.csv in merged_data/2021-22/DEF
# 'starts' column not found in Craig_Cathcart.csv, skipping the conversion.
# Processed and saved Craig_Cathcart.csv in merged_data/2021-22/DEF
# 'starts' column not found in Tyrick_Mitchell.csv, skipping the conversion.
# Processed and saved Tyrick_Mitchell.csv in merged_data/2021-22/DEF
# 'starts' column not found in Haydon_Roberts.csv, skipping the conversion.
# Processed and saved Haydon_Roberts.csv in merged_data/2021-22/DEF
# 'starts' column not found in Martin_Kelly.csv, skipping the conversion.
# Processed and saved Martin_Kelly.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kieran_Trippier.csv, skipping the conversion.
# Processed and saved Kieran_Trippier.csv in merged_data/2021-22/DEF
# 'starts' column not found in João_Pedro_Cavaco_Cancelo.csv, skipping the conversion.
# Processed and saved João_Pedro_Cavaco_Cancelo.csv in merged_data/2021-22/DEF
# 'starts' column not found in Robert_Kenedy_Nunes_do_Nascimento.csv, skipping the conversion.
# Processed and saved Robert_Kenedy_Nunes_do_Nascimento.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jeremy_Ngakia.csv, skipping the conversion.
# Processed and saved Jeremy_Ngakia.csv in merged_data/2021-22/DEF
# 'starts' column not found in Mads_Bech_Sørensen.csv, skipping the conversion.
# Processed and saved Mads_Bech_Sørensen.csv in merged_data/2021-22/DEF
# 'starts' column not found in Marcos_Alonso.csv, skipping the conversion.
# Processed and saved Marcos_Alonso.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ethan_Pinnock.csv, skipping the conversion.
# Processed and saved Ethan_Pinnock.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_Godfrey.csv, skipping the conversion.
# Processed and saved Ben_Godfrey.csv in merged_data/2021-22/DEF
# 'starts' column not found in Emerson_Aparecido_Leite_de_Souza_Junior.csv, skipping the conversion.
# Processed and saved Emerson_Aparecido_Leite_de_Souza_Junior.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jonathan_Castro_Otto.csv, skipping the conversion.
# Processed and saved Jonathan_Castro_Otto.csv in merged_data/2021-22/DEF
# 'starts' column not found in Matthew_Cash.csv, skipping the conversion.
# Processed and saved Matthew_Cash.csv in merged_data/2021-22/DEF
# 'starts' column not found in Dimitris_Giannoulis.csv, skipping the conversion.
# Processed and saved Dimitris_Giannoulis.csv in merged_data/2021-22/DEF
# 'starts' column not found in Danny_Rose.csv, skipping the conversion.
# Processed and saved Danny_Rose.csv in merged_data/2021-22/DEF
# 'starts' column not found in James_Morris.csv, skipping the conversion.
# Processed and saved James_Morris.csv in merged_data/2021-22/DEF
# 'starts' column not found in John_Stones.csv, skipping the conversion.
# Processed and saved John_Stones.csv in merged_data/2021-22/DEF
# 'starts' column not found in Aymeric_Laporte.csv, skipping the conversion.
# Processed and saved Aymeric_Laporte.csv in merged_data/2021-22/DEF
# 'starts' column not found in Cheikhou_Kouyaté.csv, skipping the conversion.
# Processed and saved Cheikhou_Kouyaté.csv in merged_data/2021-22/DEF
# 'starts' column not found in Alex_Kirk.csv, skipping the conversion.
# Processed and saved Alex_Kirk.csv in merged_data/2021-22/DEF
# 'starts' column not found in Konstantinos_Tsimikas.csv, skipping the conversion.
# Processed and saved Konstantinos_Tsimikas.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jack_Stephens.csv, skipping the conversion.
# Processed and saved Jack_Stephens.csv in merged_data/2021-22/DEF
# 'starts' column not found in Marcel_Lavinier.csv, skipping the conversion.
# Processed and saved Marcel_Lavinier.csv in merged_data/2021-22/DEF
# 'starts' column not found in William_Troost-Ekong.csv, skipping the conversion.
# Processed and saved William_Troost-Ekong.csv in merged_data/2021-22/DEF
# 'starts' column not found in Liam_Cooper.csv, skipping the conversion.
# Processed and saved Liam_Cooper.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kyle_Walker.csv, skipping the conversion.
# Processed and saved Kyle_Walker.csv in merged_data/2021-22/DEF
# 'starts' column not found in Fernando_Marçal.csv, skipping the conversion.
# Processed and saved Fernando_Marçal.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jonny_Evans.csv, skipping the conversion.
# Processed and saved Jonny_Evans.csv in merged_data/2021-22/DEF
# 'starts' column not found in Tobi_Omole.csv, skipping the conversion.
# Processed and saved Tobi_Omole.csv in merged_data/2021-22/DEF
# 'starts' column not found in Matt_Ritchie.csv, skipping the conversion.
# Processed and saved Matt_Ritchie.csv in merged_data/2021-22/DEF
# 'starts' column not found in Virgil_van_Dijk.csv, skipping the conversion.
# Processed and saved Virgil_van_Dijk.csv in merged_data/2021-22/DEF
# 'starts' column not found in Pascal_Struijk.csv, skipping the conversion.
# Processed and saved Pascal_Struijk.csv in merged_data/2021-22/DEF
# 'starts' column not found in Francisco_Femenía_Far.csv, skipping the conversion.
# Processed and saved Francisco_Femenía_Far.csv in merged_data/2021-22/DEF
# 'starts' column not found in Aaron_Wan-Bissaka.csv, skipping the conversion.
# Processed and saved Aaron_Wan-Bissaka.csv in merged_data/2021-22/DEF
# 'starts' column not found in Finley_Stevens.csv, skipping the conversion.
# Processed and saved Finley_Stevens.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nathan_Patterson.csv, skipping the conversion.
# Processed and saved Nathan_Patterson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Fabian_Schär.csv, skipping the conversion.
# Processed and saved Fabian_Schär.csv in merged_data/2021-22/DEF
# 'starts' column not found in Axel_Tuanzebe.csv, skipping the conversion.
# Processed and saved Axel_Tuanzebe.csv in merged_data/2021-22/DEF
# 'starts' column not found in Eric_Bailly.csv, skipping the conversion.
# Processed and saved Eric_Bailly.csv in merged_data/2021-22/DEF
# 'starts' column not found in Lewis_Dunk.csv, skipping the conversion.
# Processed and saved Lewis_Dunk.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kristoffer_Ajer.csv, skipping the conversion.
# Processed and saved Kristoffer_Ajer.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ed_Turns.csv, skipping the conversion.
# Processed and saved Ed_Turns.csv in merged_data/2021-22/DEF
# 'starts' column not found in Frederik_Alves.csv, skipping the conversion.
# Processed and saved Frederik_Alves.csv in merged_data/2021-22/DEF
# 'starts' column not found in Niels_Nkounkou.csv, skipping the conversion.
# Processed and saved Niels_Nkounkou.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ryan_Sessegnon.csv, skipping the conversion.
# Processed and saved Ryan_Sessegnon.csv in merged_data/2021-22/DEF
# 'starts' column not found in Dion_Sanderson.csv, skipping the conversion.
# Processed and saved Dion_Sanderson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Phil_Jones.csv, skipping the conversion.
# Processed and saved Phil_Jones.csv in merged_data/2021-22/DEF
# 'starts' column not found in Rayan_Ait_Nouri.csv, skipping the conversion.
# Processed and saved Rayan_Ait_Nouri.csv in merged_data/2021-22/DEF
# 'starts' column not found in Lyanco_Evangelista_Silveira_Neves_Vojnovic.csv, skipping the conversion.
# Processed and saved Lyanco_Evangelista_Silveira_Neves_Vojnovic.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_White.csv, skipping the conversion.
# Processed and saved Ben_White.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_Gibson.csv, skipping the conversion.
# Processed and saved Ben_Gibson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Toti_António_Gomes.csv, skipping the conversion.
# Processed and saved Toti_António_Gomes.csv in merged_data/2021-22/DEF
# 'starts' column not found in Josh_Feeney.csv, skipping the conversion.
# Processed and saved Josh_Feeney.csv in merged_data/2021-22/DEF
# 'starts' column not found in Luke_Thomas.csv, skipping the conversion.
# Processed and saved Luke_Thomas.csv in merged_data/2021-22/DEF
# 'starts' column not found in Bali_Mumba.csv, skipping the conversion.
# Processed and saved Bali_Mumba.csv in merged_data/2021-22/DEF
# 'starts' column not found in Marc_Cucurella.csv, skipping the conversion.
# Processed and saved Marc_Cucurella.csv in merged_data/2021-22/DEF
# 'starts' column not found in Michal_Karbownik.csv, skipping the conversion.
# Processed and saved Michal_Karbownik.csv in merged_data/2021-22/DEF
# 'starts' column not found in Phil_Bardsley.csv, skipping the conversion.
# Processed and saved Phil_Bardsley.csv in merged_data/2021-22/DEF
# 'starts' column not found in Hassane_Kamara.csv, skipping the conversion.
# Processed and saved Hassane_Kamara.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ki-Jana_Hoever.csv, skipping the conversion.
# Processed and saved Ki-Jana_Hoever.csv in merged_data/2021-22/DEF
# 'starts' column not found in Charlie_Cresswell.csv, skipping the conversion.
# Processed and saved Charlie_Cresswell.csv in merged_data/2021-22/DEF
# 'starts' column not found in Christian_Marques.csv, skipping the conversion.
# Processed and saved Christian_Marques.csv in merged_data/2021-22/DEF
# 'starts' column not found in Dynel_Simeu.csv, skipping the conversion.
# Processed and saved Dynel_Simeu.csv in merged_data/2021-22/DEF
# 'starts' column not found in Julian_Jeanvier.csv, skipping the conversion.
# Processed and saved Julian_Jeanvier.csv in merged_data/2021-22/DEF
# 'starts' column not found in James_Tomkins.csv, skipping the conversion.
# Processed and saved James_Tomkins.csv in merged_data/2021-22/DEF
# 'starts' column not found in Aaron_Cresswell.csv, skipping the conversion.
# Processed and saved Aaron_Cresswell.csv in merged_data/2021-22/DEF
# 'starts' column not found in Mads_Roerslev_Rasmussen.csv, skipping the conversion.
# Processed and saved Mads_Roerslev_Rasmussen.csv in merged_data/2021-22/DEF
# 'starts' column not found in Mohammed_Salisu.csv, skipping the conversion.
# Processed and saved Mohammed_Salisu.csv in merged_data/2021-22/DEF
# 'starts' column not found in Thierry_Small.csv, skipping the conversion.
# Processed and saved Thierry_Small.csv in merged_data/2021-22/DEF
# 'starts' column not found in Robin_Koch.csv, skipping the conversion.
# Processed and saved Robin_Koch.csv in merged_data/2021-22/DEF
# 'starts' column not found in Grant_Hanley.csv, skipping the conversion.
# Processed and saved Grant_Hanley.csv in merged_data/2021-22/DEF
# 'starts' column not found in Joseph_Gomez.csv, skipping the conversion.
# Processed and saved Joseph_Gomez.csv in merged_data/2021-22/DEF
# 'starts' column not found in Joachim_Andersen.csv, skipping the conversion.
# Processed and saved Joachim_Andersen.csv in merged_data/2021-22/DEF
# 'starts' column not found in Daniel_Amartey.csv, skipping the conversion.
# Processed and saved Daniel_Amartey.csv in merged_data/2021-22/DEF
# 'starts' column not found in Takehiro_Tomiyasu.csv, skipping the conversion.
# Processed and saved Takehiro_Tomiyasu.csv in merged_data/2021-22/DEF
# 'starts' column not found in Dominic_Thompson.csv, skipping the conversion.
# Processed and saved Dominic_Thompson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ajibola_Alese.csv, skipping the conversion.
# Processed and saved Ajibola_Alese.csv in merged_data/2021-22/DEF
# 'starts' column not found in James_Tarkowski.csv, skipping the conversion.
# Processed and saved James_Tarkowski.csv in merged_data/2021-22/DEF
# 'starts' column not found in Odeluga_Offiah.csv, skipping the conversion.
# Processed and saved Odeluga_Offiah.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jamal_Baptiste.csv, skipping the conversion.
# Processed and saved Jamal_Baptiste.csv in merged_data/2021-22/DEF
# 'starts' column not found in Reece_James.csv, skipping the conversion.
# Processed and saved Reece_James.csv in merged_data/2021-22/DEF
# 'starts' column not found in Owen_Beck.csv, skipping the conversion.
# Processed and saved Owen_Beck.csv in merged_data/2021-22/DEF
# 'starts' column not found in Pontus_Jansson.csv, skipping the conversion.
# Processed and saved Pontus_Jansson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nuno_Varela_Tavares.csv, skipping the conversion.
# Processed and saved Nuno_Varela_Tavares.csv in merged_data/2021-22/DEF
# 'starts' column not found in Yerry_Mina.csv, skipping the conversion.
# Processed and saved Yerry_Mina.csv in merged_data/2021-22/DEF
# 'starts' column not found in Luke_Mbete.csv, skipping the conversion.
# Processed and saved Luke_Mbete.csv in merged_data/2021-22/DEF
# 'starts' column not found in Willy_Boly.csv, skipping the conversion.
# Processed and saved Willy_Boly.csv in merged_data/2021-22/DEF
# 'starts' column not found in Davinson_Sánchez.csv, skipping the conversion.
# Processed and saved Davinson_Sánchez.csv in merged_data/2021-22/DEF
# 'starts' column not found in Seamus_Coleman.csv, skipping the conversion.
# Processed and saved Seamus_Coleman.csv in merged_data/2021-22/DEF
# 'starts' column not found in Diego_Llorente.csv, skipping the conversion.
# Processed and saved Diego_Llorente.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nathaniel_Clyne.csv, skipping the conversion.
# Processed and saved Nathaniel_Clyne.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ryan_Bertrand.csv, skipping the conversion.
# Processed and saved Ryan_Bertrand.csv in merged_data/2021-22/DEF
# 'starts' column not found in Cristian_Romero.csv, skipping the conversion.
# Processed and saved Cristian_Romero.csv in merged_data/2021-22/DEF
# 'starts' column not found in Bernardo_Fernandes_Da_Silva_Junior.csv, skipping the conversion.
# Processed and saved Bernardo_Fernandes_Da_Silva_Junior.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ciaran_Clark.csv, skipping the conversion.
# Processed and saved Ciaran_Clark.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jan_Bednarek.csv, skipping the conversion.
# Processed and saved Jan_Bednarek.csv in merged_data/2021-22/DEF
# 'starts' column not found in Dan_Burn.csv, skipping the conversion.
# Processed and saved Dan_Burn.csv in merged_data/2021-22/DEF
# 'starts' column not found in Rúben_Santos_Gato_Alves_Dias.csv, skipping the conversion.
# Processed and saved Rúben_Santos_Gato_Alves_Dias.csv in merged_data/2021-22/DEF
# 'starts' column not found in Trent_Alexander-Arnold.csv, skipping the conversion.
# Processed and saved Trent_Alexander-Arnold.csv in merged_data/2021-22/DEF
# 'starts' column not found in Craig_Dawson.csv, skipping the conversion.
# Processed and saved Craig_Dawson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ashley_Young.csv, skipping the conversion.
# Processed and saved Ashley_Young.csv in merged_data/2021-22/DEF
# 'starts' column not found in Emil_Krafth.csv, skipping the conversion.
# Processed and saved Emil_Krafth.csv in merged_data/2021-22/DEF
# 'starts' column not found in Oleksandr_Zinchenko.csv, skipping the conversion.
# Processed and saved Oleksandr_Zinchenko.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jamaal_Lascelles.csv, skipping the conversion.
# Processed and saved Jamaal_Lascelles.csv in merged_data/2021-22/DEF
# 'starts' column not found in Joël_Veltman.csv, skipping the conversion.
# Processed and saved Joël_Veltman.csv in merged_data/2021-22/DEF
# 'starts' column not found in Rob_Holding.csv, skipping the conversion.
# Processed and saved Rob_Holding.csv in merged_data/2021-22/DEF
# 'starts' column not found in Brandon_Williams.csv, skipping the conversion.
# Processed and saved Brandon_Williams.csv in merged_data/2021-22/DEF
# 'starts' column not found in Matthew_Lowton.csv, skipping the conversion.
# Processed and saved Matthew_Lowton.csv in merged_data/2021-22/DEF
# 'starts' column not found in Japhet_Tanganga.csv, skipping the conversion.
# Processed and saved Japhet_Tanganga.csv in merged_data/2021-22/DEF
# 'starts' column not found in Shane_Duffy.csv, skipping the conversion.
# Processed and saved Shane_Duffy.csv in merged_data/2021-22/DEF
# 'starts' column not found in José_Diogo_Dalot_Teixeira.csv, skipping the conversion.
# Processed and saved José_Diogo_Dalot_Teixeira.csv in merged_data/2021-22/DEF
# 'starts' column not found in Bobby_Thomas.csv, skipping the conversion.
# Processed and saved Bobby_Thomas.csv in merged_data/2021-22/DEF
# 'starts' column not found in Charlie_Taylor.csv, skipping the conversion.
# Processed and saved Charlie_Taylor.csv in merged_data/2021-22/DEF
# 'starts' column not found in Hugo_Bueno.csv, skipping the conversion.
# Processed and saved Hugo_Bueno.csv in merged_data/2021-22/DEF
# 'starts' column not found in Matthew_Pollock.csv, skipping the conversion.
# Processed and saved Matthew_Pollock.csv in merged_data/2021-22/DEF
# 'starts' column not found in Vladimir_Coufal.csv, skipping the conversion.
# Processed and saved Vladimir_Coufal.csv in merged_data/2021-22/DEF
# 'starts' column not found in Christoph_Zimmermann.csv, skipping the conversion.
# Processed and saved Christoph_Zimmermann.csv in merged_data/2021-22/DEF
# 'starts' column not found in Max_Kilman.csv, skipping the conversion.
# Processed and saved Max_Kilman.csv in merged_data/2021-22/DEF
# 'starts' column not found in Trevoh_Chalobah.csv, skipping the conversion.
# Processed and saved Trevoh_Chalobah.csv in merged_data/2021-22/DEF
# 'starts' column not found in Rico_Henry.csv, skipping the conversion.
# Processed and saved Rico_Henry.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kaine_Hayden.csv, skipping the conversion.
# Processed and saved Kaine_Hayden.csv in merged_data/2021-22/DEF
# 'starts' column not found in Rhys_Williams.csv, skipping the conversion.
# Processed and saved Rhys_Williams.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jannik_Vestergaard.csv, skipping the conversion.
# Processed and saved Jannik_Vestergaard.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_Johnson.csv, skipping the conversion.
# Processed and saved Ben_Johnson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Matt_Doherty.csv, skipping the conversion.
# Processed and saved Matt_Doherty.csv in merged_data/2021-22/DEF
# 'starts' column not found in Alex_Nicolao_Telles.csv, skipping the conversion.
# Processed and saved Alex_Nicolao_Telles.csv in merged_data/2021-22/DEF
# 'starts' column not found in Toby_Alderweireld.csv, skipping the conversion.
# Processed and saved Toby_Alderweireld.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kevin_Long.csv, skipping the conversion.
# Processed and saved Kevin_Long.csv in merged_data/2021-22/DEF
# 'starts' column not found in Neco_Williams.csv, skipping the conversion.
# Processed and saved Neco_Williams.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ozan_Kabak.csv, skipping the conversion.
# Processed and saved Ozan_Kabak.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ben_Mee.csv, skipping the conversion.
# Processed and saved Ben_Mee.csv in merged_data/2021-22/DEF
# 'starts' column not found in Çaglar_Söyüncü.csv, skipping the conversion.
# Processed and saved Çaglar_Söyüncü.csv in merged_data/2021-22/DEF
# 'starts' column not found in Federico_Fernández.csv, skipping the conversion.
# Processed and saved Federico_Fernández.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nicolas_Nkoulou.csv, skipping the conversion.
# Processed and saved Nicolas_Nkoulou.csv in merged_data/2021-22/DEF
# 'starts' column not found in Antonio_Rüdiger.csv, skipping the conversion.
# Processed and saved Antonio_Rüdiger.csv in merged_data/2021-22/DEF
# 'starts' column not found in Marc_Navarro.csv, skipping the conversion.
# Processed and saved Marc_Navarro.csv in merged_data/2021-22/DEF
# 'starts' column not found in Mazeed_Ogungbo.csv, skipping the conversion.
# Processed and saved Mazeed_Ogungbo.csv in merged_data/2021-22/DEF
# 'starts' column not found in Romain_Saïss.csv, skipping the conversion.
# Processed and saved Romain_Saïss.csv in merged_data/2021-22/DEF
# 'starts' column not found in Leo_Fuhr_Hjelde.csv, skipping the conversion.
# Processed and saved Leo_Fuhr_Hjelde.csv in merged_data/2021-22/DEF
# 'starts' column not found in Calum_Chambers.csv, skipping the conversion.
# Processed and saved Calum_Chambers.csv in merged_data/2021-22/DEF
# 'starts' column not found in Vitalii_Mykolenko.csv, skipping the conversion.
# Processed and saved Vitalii_Mykolenko.csv in merged_data/2021-22/DEF
# 'starts' column not found in Paul_Dummett.csv, skipping the conversion.
# Processed and saved Paul_Dummett.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ryan_Alebiosu.csv, skipping the conversion.
# Processed and saved Ryan_Alebiosu.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jamal_Lewis.csv, skipping the conversion.
# Processed and saved Jamal_Lewis.csv in merged_data/2021-22/DEF
# 'starts' column not found in Malang_Sarr.csv, skipping the conversion.
# Processed and saved Malang_Sarr.csv in merged_data/2021-22/DEF
# 'starts' column not found in Björn_Engels.csv, skipping the conversion.
# Processed and saved Björn_Engels.csv in merged_data/2021-22/DEF
# 'starts' column not found in William_Saliba.csv, skipping the conversion.
# Processed and saved William_Saliba.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ezri_Konsa_Ngoyo.csv, skipping the conversion.
# Processed and saved Ezri_Konsa_Ngoyo.csv in merged_data/2021-22/DEF
# 'starts' column not found in Tayo_Adaramola.csv, skipping the conversion.
# Processed and saved Tayo_Adaramola.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kyle_Walker-Peters.csv, skipping the conversion.
# Processed and saved Kyle_Walker-Peters.csv in merged_data/2021-22/DEF
# 'starts' column not found in Héctor_Bellerín.csv, skipping the conversion.
# Processed and saved Héctor_Bellerín.csv in merged_data/2021-22/DEF
# 'starts' column not found in Thiago_Emiliano_da_Silva.csv, skipping the conversion.
# Processed and saved Thiago_Emiliano_da_Silva.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nathan_Collins.csv, skipping the conversion.
# Processed and saved Nathan_Collins.csv in merged_data/2021-22/DEF
# 'starts' column not found in Conor_Bradley.csv, skipping the conversion.
# Processed and saved Conor_Bradley.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kieran_Tierney.csv, skipping the conversion.
# Processed and saved Kieran_Tierney.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jacob_Sørensen.csv, skipping the conversion.
# Processed and saved Jacob_Sørensen.csv in merged_data/2021-22/DEF
# 'starts' column not found in César_Azpilicueta.csv, skipping the conversion.
# Processed and saved César_Azpilicueta.csv in merged_data/2021-22/DEF
# 'starts' column not found in Sam_Byram.csv, skipping the conversion.
# Processed and saved Sam_Byram.csv in merged_data/2021-22/DEF
# 'starts' column not found in Yan_Valery.csv, skipping the conversion.
# Processed and saved Yan_Valery.csv in merged_data/2021-22/DEF
# 'starts' column not found in Lamare_Bogarde.csv, skipping the conversion.
# Processed and saved Lamare_Bogarde.csv in merged_data/2021-22/DEF
# 'starts' column not found in Victor_Lindelöf.csv, skipping the conversion.
# Processed and saved Victor_Lindelöf.csv in merged_data/2021-22/DEF
# 'starts' column not found in Yerson_Mosquera_Valdelamar.csv, skipping the conversion.
# Processed and saved Yerson_Mosquera_Valdelamar.csv in merged_data/2021-22/DEF
# 'starts' column not found in Jarosław_Jach.csv, skipping the conversion.
# Processed and saved Jarosław_Jach.csv in merged_data/2021-22/DEF
# 'starts' column not found in Connor_Roberts.csv, skipping the conversion.
# Processed and saved Connor_Roberts.csv in merged_data/2021-22/DEF
# 'starts' column not found in Nélson_Cabral_Semedo.csv, skipping the conversion.
# Processed and saved Nélson_Cabral_Semedo.csv in merged_data/2021-22/DEF
# 'starts' column not found in Marc_Guéhi.csv, skipping the conversion.
# Processed and saved Marc_Guéhi.csv in merged_data/2021-22/DEF
# 'starts' column not found in Frédéric_Guilbert.csv, skipping the conversion.
# Processed and saved Frédéric_Guilbert.csv in merged_data/2021-22/DEF
# 'starts' column not found in Eric_Dier.csv, skipping the conversion.
# Processed and saved Eric_Dier.csv in merged_data/2021-22/DEF
# 'starts' column not found in Raphaël_Varane.csv, skipping the conversion.
# Processed and saved Raphaël_Varane.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kortney_Hause.csv, skipping the conversion.
# Processed and saved Kortney_Hause.csv in merged_data/2021-22/DEF
# 'starts' column not found in Charlie_Goode.csv, skipping the conversion.
# Processed and saved Charlie_Goode.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ricardo_Domingos_Barbosa_Pereira.csv, skipping the conversion.
# Processed and saved Ricardo_Domingos_Barbosa_Pereira.csv in merged_data/2021-22/DEF
# 'starts' column not found in Harry_Maguire.csv, skipping the conversion.
# Processed and saved Harry_Maguire.csv in merged_data/2021-22/DEF
# 'starts' column not found in Konstantinos_Mavropanos.csv, skipping the conversion.
# Processed and saved Konstantinos_Mavropanos.csv in merged_data/2021-22/DEF
# 'starts' column not found in Max_Aarons.csv, skipping the conversion.
# Processed and saved Max_Aarons.csv in merged_data/2021-22/DEF
# 'starts' column not found in James_Justin.csv, skipping the conversion.
# Processed and saved James_Justin.csv in merged_data/2021-22/DEF
# 'starts' column not found in Luke_Ayling.csv, skipping the conversion.
# Processed and saved Luke_Ayling.csv in merged_data/2021-22/DEF
# 'starts' column not found in Sead_Kolasinac.csv, skipping the conversion.
# Processed and saved Sead_Kolasinac.csv in merged_data/2021-22/DEF
# 'starts' column not found in Ryan_Fredericks.csv, skipping the conversion.
# Processed and saved Ryan_Fredericks.csv in merged_data/2021-22/DEF
# 'starts' column not found in Winston_Reid.csv, skipping the conversion.
# Processed and saved Winston_Reid.csv in merged_data/2021-22/DEF
# 'starts' column not found in Andrew_Robertson.csv, skipping the conversion.
# Processed and saved Andrew_Robertson.csv in merged_data/2021-22/DEF
# 'starts' column not found in Erik_Pieters.csv, skipping the conversion.
# Processed and saved Erik_Pieters.csv in merged_data/2021-22/DEF
# 'starts' column not found in Serge_Aurier.csv, skipping the conversion.
# Processed and saved Serge_Aurier.csv in merged_data/2021-22/DEF
# 'starts' column not found in Kris_Moore.csv, skipping the conversion.
# Processed and saved Kris_Moore.csv in merged_data/2021-22/DEF
# 'starts' column not found in Joshua_Wilson-Esbrand.csv, skipping the conversion.
# Processed and saved Joshua_Wilson-Esbrand.csv in merged_data/2021-22/DEF
# Processed and saved Nathan_Aké.csv in merged_data/2022-23/DEF
# Processed and saved Tariq_Lamptey.csv in merged_data/2022-23/DEF
# Processed and saved Adam_Webster.csv in merged_data/2022-23/DEF
# Processed and saved Mohamed_Dräger.csv in merged_data/2022-23/DEF
# Processed and saved Kalidou_Koulibaly.csv in merged_data/2022-23/DEF
# Processed and saved Moussa_Niakhaté.csv in merged_data/2022-23/DEF
# Processed and saved Nathaniel_Phillips.csv in merged_data/2022-23/DEF
# Processed and saved Jarrad_Branthwaite.csv in merged_data/2022-23/DEF
# Processed and saved Joe_Rodon.csv in merged_data/2022-23/DEF
# Processed and saved Harrison_Ashby.csv in merged_data/2022-23/DEF
# Processed and saved Issa_Diop.csv in merged_data/2022-23/DEF
# Processed and saved Jakub_Kiwior.csv in merged_data/2022-23/DEF
# Processed and saved Clément_Lenglet.csv in merged_data/2022-23/DEF
# Processed and saved Benjamin_White.csv in merged_data/2022-23/DEF
# Processed and saved Tino_Livramento.csv in merged_data/2022-23/DEF
# Processed and saved Lisandro_Martínez.csv in merged_data/2022-23/DEF
# Processed and saved Harry_Toffolo.csv in merged_data/2022-23/DEF
# Processed and saved Michael_Keane.csv in merged_data/2022-23/DEF
# Processed and saved Emerson_Palmieri_dos_Santos.csv in merged_data/2022-23/DEF
# Processed and saved Timothy_Castagne.csv in merged_data/2022-23/DEF
# Processed and saved Joel_Ward.csv in merged_data/2022-23/DEF
# Processed and saved Wesley_Fofana.csv in merged_data/2022-23/DEF
# Processed and saved Arthur_Masuaku.csv in merged_data/2022-23/DEF
# Processed and saved Stuart_Dallas.csv in merged_data/2022-23/DEF
# Processed and saved Matty_Cash.csv in merged_data/2022-23/DEF
# Processed and saved Lucas_Digne.csv in merged_data/2022-23/DEF
# Processed and saved Dexter_Lembikisa.csv in merged_data/2022-23/DEF
# Processed and saved Max_Kinsey-Wellings.csv in merged_data/2022-23/DEF
# Processed and saved Ibrahima_Konaté.csv in merged_data/2022-23/DEF
# Processed and saved Sergio_Gómez.csv in merged_data/2022-23/DEF
# Processed and saved Kurt_Zouma.csv in merged_data/2022-23/DEF
# Processed and saved Matt_Targett.csv in merged_data/2022-23/DEF
# Processed and saved Cody_Drameh.csv in merged_data/2022-23/DEF
# Processed and saved Thilo_Kehrer.csv in merged_data/2022-23/DEF
# Processed and saved Angelo_Ogbonna.csv in merged_data/2022-23/DEF
# Processed and saved Joel_Matip.csv in merged_data/2022-23/DEF
# Processed and saved Sergio_Reguilón.csv in merged_data/2022-23/DEF
# Processed and saved Sebastian_Revan.csv in merged_data/2022-23/DEF
# Processed and saved Ethan_Ampadu.csv in merged_data/2022-23/DEF
# Processed and saved Kofi_Balmer.csv in merged_data/2022-23/DEF
# Processed and saved Nathan_Ferguson.csv in merged_data/2022-23/DEF
# Processed and saved Nayef_Aguerd.csv in merged_data/2022-23/DEF
# Processed and saved Ben_Davies.csv in merged_data/2022-23/DEF
# Processed and saved Conor_Coady.csv in merged_data/2022-23/DEF
# Processed and saved Luke_Shaw.csv in merged_data/2022-23/DEF
# Processed and saved Mathias_Jorgensen.csv in merged_data/2022-23/DEF
# Processed and saved Reece_Welch.csv in merged_data/2022-23/DEF
# Processed and saved Diogo_Dalot_Teixeira.csv in merged_data/2022-23/DEF
# Processed and saved Romain_Perraud.csv in merged_data/2022-23/DEF
# Processed and saved Tyrone_Mings.csv in merged_data/2022-23/DEF
# Processed and saved Duje_Caleta-Car.csv in merged_data/2022-23/DEF
# Processed and saved Mason_Holgate.csv in merged_data/2022-23/DEF
# Processed and saved Rúben_Gato_Alves_Dias.csv in merged_data/2022-23/DEF
# Processed and saved Pervis_Estupiñán.csv in merged_data/2022-23/DEF
# Processed and saved Felipe_Augusto_de_Almeida_Monteiro.csv in merged_data/2022-23/DEF
# Processed and saved Alfie_Gilchrist.csv in merged_data/2022-23/DEF
# Processed and saved Owen_Bevan.csv in merged_data/2022-23/DEF
# Processed and saved Tyrick_Mitchell.csv in merged_data/2022-23/DEF
# Processed and saved Haydon_Roberts.csv in merged_data/2022-23/DEF
# Processed and saved Scott_McKenna.csv in merged_data/2022-23/DEF
# Processed and saved Kieran_Trippier.csv in merged_data/2022-23/DEF
# Processed and saved Robert_Kenedy_Nunes_do_Nascimento.csv in merged_data/2022-23/DEF
# Processed and saved Mads_Bech_Sørensen.csv in merged_data/2022-23/DEF
# Processed and saved Rayan_Aït-Nouri.csv in merged_data/2022-23/DEF
# Processed and saved Ludwig_Augustinsson.csv in merged_data/2022-23/DEF
# Processed and saved Marcos_Alonso.csv in merged_data/2022-23/DEF
# Processed and saved Jordan_Zemura.csv in merged_data/2022-23/DEF
# Processed and saved Marc_Cucurella_Saseta.csv in merged_data/2022-23/DEF
# Processed and saved Ishé_Samuels-Smith.csv in merged_data/2022-23/DEF
# Processed and saved Ethan_Pinnock.csv in merged_data/2022-23/DEF
# Processed and saved Ben_Godfrey.csv in merged_data/2022-23/DEF
# Processed and saved Jonathan_Castro_Otto.csv in merged_data/2022-23/DEF
# Processed and saved John_Stones.csv in merged_data/2022-23/DEF
# Processed and saved Adam_Smith.csv in merged_data/2022-23/DEF
# Processed and saved Aymeric_Laporte.csv in merged_data/2022-23/DEF
# Processed and saved Cédric_Alves_Soares.csv in merged_data/2022-23/DEF
# Processed and saved Bashir_Humphreys.csv in merged_data/2022-23/DEF
# Processed and saved Konstantinos_Tsimikas.csv in merged_data/2022-23/DEF
# Processed and saved Hugo_Bueno_López.csv in merged_data/2022-23/DEF
# Processed and saved Jack_Stephens.csv in merged_data/2022-23/DEF
# Processed and saved Gabriel_dos_Santos_Magalhães.csv in merged_data/2022-23/DEF
# Processed and saved Richie_Laryea.csv in merged_data/2022-23/DEF
# Processed and saved Josh_Wilson-Esbrand.csv in merged_data/2022-23/DEF
# Processed and saved Liam_Cooper.csv in merged_data/2022-23/DEF
# Processed and saved Jan_Paul_van_Hecke.csv in merged_data/2022-23/DEF
# Processed and saved Kyle_Walker.csv in merged_data/2022-23/DEF
# Processed and saved Marcos_Senesi.csv in merged_data/2022-23/DEF
# Processed and saved Jonny_Evans.csv in merged_data/2022-23/DEF
# Processed and saved Matt_Ritchie.csv in merged_data/2022-23/DEF
# Processed and saved Ben_Chilwell.csv in merged_data/2022-23/DEF
# Processed and saved Virgil_van_Dijk.csv in merged_data/2022-23/DEF
# Processed and saved Pascal_Struijk.csv in merged_data/2022-23/DEF
# Processed and saved Aaron_Wan-Bissaka.csv in merged_data/2022-23/DEF
# Processed and saved Nathan_Patterson.csv in merged_data/2022-23/DEF
# Processed and saved Fabian_Schär.csv in merged_data/2022-23/DEF
# Processed and saved Jack_Stacey.csv in merged_data/2022-23/DEF
# Processed and saved Steve_Cook.csv in merged_data/2022-23/DEF
# Processed and saved Eric_Bailly.csv in merged_data/2022-23/DEF
# Processed and saved Wout_Faes.csv in merged_data/2022-23/DEF
# Processed and saved Lewis_Dunk.csv in merged_data/2022-23/DEF
# Processed and saved Kristoffer_Ajer.csv in merged_data/2022-23/DEF
# Processed and saved Junior_Firpo_Adames.csv in merged_data/2022-23/DEF
# Processed and saved Chris_Mepham.csv in merged_data/2022-23/DEF
# Processed and saved Ed_Turns.csv in merged_data/2022-23/DEF
# Processed and saved Niels_Nkounkou.csv in merged_data/2022-23/DEF
# Processed and saved Ryan_Sessegnon.csv in merged_data/2022-23/DEF
# Processed and saved Phil_Jones.csv in merged_data/2022-23/DEF
# Processed and saved Rasmus_Kristensen.csv in merged_data/2022-23/DEF
# Processed and saved Levi_Colwill.csv in merged_data/2022-23/DEF
# Processed and saved Rico_Lewis.csv in merged_data/2022-23/DEF
# Processed and saved Lyanco_Silveira_Neves_Vojnovic.csv in merged_data/2022-23/DEF
# Processed and saved João_Cancelo.csv in merged_data/2022-23/DEF
# Processed and saved Toti_António_Gomes.csv in merged_data/2022-23/DEF
# Processed and saved Pedro_Porro.csv in merged_data/2022-23/DEF
# Processed and saved Luke_Thomas.csv in merged_data/2022-23/DEF
# Processed and saved Lloyd_Kelly.csv in merged_data/2022-23/DEF
# Processed and saved Ricardo_Barbosa_Pereira.csv in merged_data/2022-23/DEF
# Processed and saved Harry_Souttar.csv in merged_data/2022-23/DEF
# Processed and saved Tosin_Adarabioyo.csv in merged_data/2022-23/DEF
# Processed and saved James_Tomkins.csv in merged_data/2022-23/DEF
# Processed and saved Sven_Botman.csv in merged_data/2022-23/DEF
# Processed and saved Luke_Mbete-Tabu.csv in merged_data/2022-23/DEF
# Processed and saved Aaron_Cresswell.csv in merged_data/2022-23/DEF
# Processed and saved Mads_Roerslev_Rasmussen.csv in merged_data/2022-23/DEF
# Processed and saved Sergi_Canós_Tenés.csv in merged_data/2022-23/DEF
# Processed and saved Layvin_Kurzawa.csv in merged_data/2022-23/DEF
# Processed and saved Mohammed_Salisu.csv in merged_data/2022-23/DEF
# Processed and saved Robin_Koch.csv in merged_data/2022-23/DEF
# Processed and saved James_Bree.csv in merged_data/2022-23/DEF
# Processed and saved Joseph_Gomez.csv in merged_data/2022-23/DEF
# Processed and saved Joachim_Andersen.csv in merged_data/2022-23/DEF
# Processed and saved Pablo_Marí_Villar.csv in merged_data/2022-23/DEF
# Processed and saved Kaelan_Casey.csv in merged_data/2022-23/DEF
# Processed and saved Daniel_Amartey.csv in merged_data/2022-23/DEF
# Processed and saved Loïc_Mbe_Soh.csv in merged_data/2022-23/DEF
# Processed and saved Takehiro_Tomiyasu.csv in merged_data/2022-23/DEF
# Processed and saved Reuell_Walters.csv in merged_data/2022-23/DEF
# Processed and saved Dominic_Thompson.csv in merged_data/2022-23/DEF
# Processed and saved James_Tarkowski.csv in merged_data/2022-23/DEF
# Processed and saved Odeluga_Offiah.csv in merged_data/2022-23/DEF
# Processed and saved Matt_Clarke.csv in merged_data/2022-23/DEF
# Processed and saved Reece_James.csv in merged_data/2022-23/DEF
# Processed and saved Pontus_Jansson.csv in merged_data/2022-23/DEF
# Processed and saved Nuno_Varela_Tavares.csv in merged_data/2022-23/DEF
# Processed and saved Yerry_Mina.csv in merged_data/2022-23/DEF
# Processed and saved Marc_Jurado_Gomez.csv in merged_data/2022-23/DEF
# Processed and saved Rhys_Bennett.csv in merged_data/2022-23/DEF
# Processed and saved Sepp_van_den_Berg.csv in merged_data/2022-23/DEF
# Processed and saved Chris_Richards.csv in merged_data/2022-23/DEF
# Processed and saved Willy_Boly.csv in merged_data/2022-23/DEF
# Processed and saved Davinson_Sánchez.csv in merged_data/2022-23/DEF
# Processed and saved Seamus_Coleman.csv in merged_data/2022-23/DEF
# Processed and saved Ben_Greenwood.csv in merged_data/2022-23/DEF
# Processed and saved Diego_Llorente.csv in merged_data/2022-23/DEF
# Processed and saved Lino_Sousa.csv in merged_data/2022-23/DEF
# Processed and saved Nathaniel_Clyne.csv in merged_data/2022-23/DEF
# Processed and saved Manuel_Akanji.csv in merged_data/2022-23/DEF
# Processed and saved Omar_Richards.csv in merged_data/2022-23/DEF
# Processed and saved Ryan_Bertrand.csv in merged_data/2022-23/DEF
# Processed and saved Cristian_Romero.csv in merged_data/2022-23/DEF
# Processed and saved Ciaran_Clark.csv in merged_data/2022-23/DEF
# Processed and saved Jan_Bednarek.csv in merged_data/2022-23/DEF
# Processed and saved Dan_Burn.csv in merged_data/2022-23/DEF
# Processed and saved Trent_Alexander-Arnold.csv in merged_data/2022-23/DEF
# Processed and saved Craig_Dawson.csv in merged_data/2022-23/DEF
# Processed and saved James_Hill.csv in merged_data/2022-23/DEF
# Processed and saved Ashley_Young.csv in merged_data/2022-23/DEF
# Processed and saved Emil_Krafth.csv in merged_data/2022-23/DEF
# Processed and saved Armel_Bella-Kotchap.csv in merged_data/2022-23/DEF
# Processed and saved Oleksandr_Zinchenko.csv in merged_data/2022-23/DEF
# Processed and saved Imari_Samuels.csv in merged_data/2022-23/DEF
# Processed and saved Jamaal_Lascelles.csv in merged_data/2022-23/DEF
# Processed and saved Joël_Veltman.csv in merged_data/2022-23/DEF
# Processed and saved Rob_Holding.csv in merged_data/2022-23/DEF
# Processed and saved Luke_Chambers.csv in merged_data/2022-23/DEF
# Processed and saved Brandon_Williams.csv in merged_data/2022-23/DEF
# Processed and saved Japhet_Tanganga.csv in merged_data/2022-23/DEF
# Processed and saved Illia_Zabarnyi.csv in merged_data/2022-23/DEF
# Processed and saved Shane_Duffy.csv in merged_data/2022-23/DEF
# Processed and saved Renan_Augusto_Lodi_dos_Santos.csv in merged_data/2022-23/DEF
# Processed and saved Tim_Ream.csv in merged_data/2022-23/DEF
# Processed and saved Tyrell_Malacia.csv in merged_data/2022-23/DEF
# Processed and saved Juan_Larios_López.csv in merged_data/2022-23/DEF
# Processed and saved Maximilian_Wöber.csv in merged_data/2022-23/DEF
# Processed and saved Alex_Telles.csv in merged_data/2022-23/DEF
# Processed and saved Vladimir_Coufal.csv in merged_data/2022-23/DEF
# Processed and saved Alexandre_Moreno_Lopera.csv in merged_data/2022-23/DEF
# Processed and saved Max_Kilman.csv in merged_data/2022-23/DEF
# Processed and saved Trevoh_Chalobah.csv in merged_data/2022-23/DEF
# Processed and saved Rico_Henry.csv in merged_data/2022-23/DEF
# Processed and saved Giulian_Biancone.csv in merged_data/2022-23/DEF
# Processed and saved Rhys_Williams.csv in merged_data/2022-23/DEF
# Processed and saved Jannik_Vestergaard.csv in merged_data/2022-23/DEF
# Processed and saved Ben_Johnson.csv in merged_data/2022-23/DEF
# Processed and saved Matt_Doherty.csv in merged_data/2022-23/DEF
# Processed and saved Kenny_Tete.csv in merged_data/2022-23/DEF
# Processed and saved Emerson_Leite_de_Souza_Junior.csv in merged_data/2022-23/DEF
# Processed and saved Kyle_John.csv in merged_data/2022-23/DEF
# Processed and saved James_Furlong.csv in merged_data/2022-23/DEF
# Processed and saved Loïc_Badé.csv in merged_data/2022-23/DEF
# Processed and saved Stefan_Parkes.csv in merged_data/2022-23/DEF
# Processed and saved Neco_Williams.csv in merged_data/2022-23/DEF
# Processed and saved Ben_Mee.csv in merged_data/2022-23/DEF
# ...
# Processed and saved Kieran_Tierney.csv in merged_data/2022-23/DEF
# Processed and saved Calvin_Ramsay.csv in merged_data/2022-23/DEF
# Processed and saved César_Azpilicueta.csv in merged_data/2022-23/DEF
# Processed and saved Victor_Kristiansen.csv in merged_data/2022-23/DEF
# Processed and saved Yan_Valery.csv in merged_data/2022-23/DEF
# Processed and saved Diego_Carlos_Santos_Silva.csv in merged_data/2022-23/DEF
# Processed and saved Lamare_Bogarde.csv in merged_data/2022-23/DEF
# Processed and saved Victor_Lindelöf.csv in merged_data/2022-23/DEF
# Processed and saved Yerson_Mosquera_Valdelamar.csv in merged_data/2022-23/DEF
# Processed and saved Djed_Spence.csv in merged_data/2022-23/DEF
# Processed and saved Joe_Worrall.csv in merged_data/2022-23/DEF
# Processed and saved Rúben_Nascimento_Vinagre.csv in merged_data/2022-23/DEF
# Processed and saved Nélson_Cabral_Semedo.csv in merged_data/2022-23/DEF
# Processed and saved Marc_Guéhi.csv in merged_data/2022-23/DEF
# Processed and saved Frédéric_Guilbert.csv in merged_data/2022-23/DEF
# Processed and saved Eric_Dier.csv in merged_data/2022-23/DEF
# Processed and saved Raphaël_Varane.csv in merged_data/2022-23/DEF
# Processed and saved Kortney_Hause.csv in merged_data/2022-23/DEF
# Processed and saved Charlie_Goode.csv in merged_data/2022-23/DEF
# Processed and saved Harry_Maguire.csv in merged_data/2022-23/DEF
# Processed and saved James_Justin.csv in merged_data/2022-23/DEF
# Processed and saved Luke_Ayling.csv in merged_data/2022-23/DEF
# Processed and saved Ryan_Fredericks.csv in merged_data/2022-23/DEF
# Processed and saved Andrew_Robertson.csv in merged_data/2022-23/DEF
# Processed and saved Joe_Bryan.csv in merged_data/2022-23/DEF
# Processed and saved Serge_Aurier.csv in merged_data/2022-23/DEF
# Processed and saved Nathan_Aké.csv in merged_data/2023-24/DEF
# Processed and saved Tariq_Lamptey.csv in merged_data/2023-24/DEF
# Processed and saved Adam_Webster.csv in merged_data/2023-24/DEF
# Processed and saved Moussa_Niakhaté.csv in merged_data/2023-24/DEF
# Processed and saved Nathaniel_Phillips.csv in merged_data/2023-24/DEF
# Processed and saved Jarrad_Branthwaite.csv in merged_data/2023-24/DEF
# Processed and saved Joe_Rodon.csv in merged_data/2023-24/DEF
# Processed and saved Lewis_Hall.csv in merged_data/2023-24/DEF
# Processed and saved Issa_Diop.csv in merged_data/2023-24/DEF
# Processed and saved Jakub_Kiwior.csv in merged_data/2023-24/DEF
# Processed and saved Callum_Scanlon.csv in merged_data/2023-24/DEF
# Processed and saved Anel_Ahmedhodžić.csv in merged_data/2023-24/DEF
# Processed and saved Clément_Lenglet.csv in merged_data/2023-24/DEF
# Processed and saved Tino_Livramento.csv in merged_data/2023-24/DEF
# Processed and saved Lisandro_Martínez.csv in merged_data/2023-24/DEF
# Processed and saved Jarell_Quansah.csv in merged_data/2023-24/DEF
# Processed and saved Djed_Spence.csv in merged_data/2023-24/DEF
# Processed and saved Joe_Worrall.csv in merged_data/2023-24/DEF
# Processed and saved Connor_Roberts.csv in merged_data/2023-24/DEF
# Processed and saved Nélson_Cabral_Semedo.csv in merged_data/2023-24/DEF
# Processed and saved Marc_Guéhi.csv in merged_data/2023-24/DEF
# Processed and saved Yasser_Larouci.csv in merged_data/2023-24/DEF
# Processed and saved Eric_Dier.csv in merged_data/2023-24/DEF
# Processed and saved Raphaël_Varane.csv in merged_data/2023-24/DEF
# Processed and saved Charlie_Goode.csv in merged_data/2023-24/DEF
# Processed and saved Micky_van_de_Ven.csv in merged_data/2023-24/DEF
# Processed and saved Harry_Maguire.csv in merged_data/2023-24/DEF
# Processed and saved Konstantinos_Mavropanos.csv in merged_data/2023-24/DEF
# Processed and saved Max_Aarons.csv in merged_data/2023-24/DEF
# Processed and saved Christian_Chigozie.csv in merged_data/2023-24/DEF
# Processed and saved Ryan_Fredericks.csv in merged_data/2023-24/DEF
# Processed and saved Andrew_Robertson.csv in merged_data/2023-24/DEF
# Processed and saved Daiki_Hashioka.csv in merged_data/2023-24/DEF
# Processed and saved Serge_Aurier.csv in merged_data/2023-24/DEF
# Processed and saved Ben_Jackson.csv in merged_data/2023-24/DEF
# Processed and saved Josh_Acheampong.csv in merged_data/2023-24/DEF
# Processed and saved Malo_Gusto.csv in merged_data/2023-24/DEF

# %%
import os
import pandas as pd
#RESTRUCTURING THE GK DATA 
merged_data_dir = 'merged_data'
seasons = ['2021-22', '2022-23', '2023-24']
gk_folder = 'GK'

# Columns to drop
columns_to_drop = ['position_x', 'kickoff_time', 'time', 'own_goals', 'goals', 'shots', 'xG', 'assists', 'key_passes', 'position_y']

# Column order as specified for the GK folder
desired_column_order = [
    'name', 'team', 'opponent_team', 'date', 'was_home', 'minutes', 'goals_conceded', 'expected_goals_conceded',
    'saves', 'penalties_saved', 'total_points', 'bonus', 'clean_sheets', 'xA', 'starts'
]

# Loop through each season and process the GK folder
for season in seasons:
    gk_dir = os.path.join(merged_data_dir, season, gk_folder)
    
    if os.path.isdir(gk_dir):
        for csv_file in os.listdir(gk_dir):
            if csv_file.endswith('.csv'):
                file_path = os.path.join(gk_dir, csv_file)
                
                # Read the CSV file
                df = pd.read_csv(file_path)
                
                # Step 1: Drop the unnecessary columns
                df = df.drop(columns=[col for col in columns_to_drop if col in df.columns], errors='ignore')
                
                # Step 2: Convert 'starts' and 'clean_sheets' columns to boolean (True/False) if they exist
                if 'starts' in df.columns:
                    df['starts'] = df['starts'].apply(lambda x: True if x == 1 else False)
                else:
                    print(f"'starts' column not found in {csv_file}, skipping the conversion.")
                
                if 'clean_sheets' in df.columns:
                    df['clean_sheets'] = df['clean_sheets'].apply(lambda x: True if x == 1 else False)
                else:
                    print(f"'clean_sheets' column not found in {csv_file}, skipping the conversion.")
                
                # Step 3: Reorder the columns, but first check for missing columns
                existing_columns = [col for col in desired_column_order if col in df.columns]
                df = df[existing_columns]
                
                # Save the modified CSV file back
                df.to_csv(file_path, index=False)
                print(f"Processed and saved {csv_file} in {gk_dir}")
# Out:
# 'starts' column not found in Patrik_Gunnarsson.csv, skipping the conversion.
# Processed and saved Patrik_Gunnarsson.csv in merged_data/2021-22/GK
# 'starts' column not found in Freddie_Woodman.csv, skipping the conversion.
# Processed and saved Freddie_Woodman.csv in merged_data/2021-22/GK
# 'starts' column not found in Martin_Dubravka.csv, skipping the conversion.
# Processed and saved Martin_Dubravka.csv in merged_data/2021-22/GK
# 'starts' column not found in Hugo_Lloris.csv, skipping the conversion.
# Processed and saved Hugo_Lloris.csv in merged_data/2021-22/GK
# 'starts' column not found in James_Storer.csv, skipping the conversion.
# Processed and saved James_Storer.csv in merged_data/2021-22/GK
# 'starts' column not found in Harry_Lewis.csv, skipping the conversion.
# Processed and saved Harry_Lewis.csv in merged_data/2021-22/GK
# 'starts' column not found in Viljami_Sinisalo.csv, skipping the conversion.
# Processed and saved Viljami_Sinisalo.csv in merged_data/2021-22/GK
# 'starts' column not found in Angus_Gunn.csv, skipping the conversion.
# Processed and saved Angus_Gunn.csv in merged_data/2021-22/GK
# 'starts' column not found in Brandon_Austin.csv, skipping the conversion.
# Processed and saved Brandon_Austin.csv in merged_data/2021-22/GK
# 'starts' column not found in Illan_Meslier.csv, skipping the conversion.
# Processed and saved Illan_Meslier.csv in merged_data/2021-22/GK
# 'starts' column not found in Lukasz_Fabianski.csv, skipping the conversion.
# Processed and saved Lukasz_Fabianski.csv in merged_data/2021-22/GK
# 'starts' column not found in Vincent_Angelini.csv, skipping the conversion.
# Processed and saved Vincent_Angelini.csv in merged_data/2021-22/GK
# 'starts' column not found in Willy_Caballero.csv, skipping the conversion.
# Processed and saved Willy_Caballero.csv in merged_data/2021-22/GK
# 'starts' column not found in Karl_Hein.csv, skipping the conversion.
# Processed and saved Karl_Hein.csv in merged_data/2021-22/GK
# 'starts' column not found in Asmir_Begović.csv, skipping the conversion.
# Processed and saved Asmir_Begović.csv in merged_data/2021-22/GK
# 'starts' column not found in Cieran_Slicker.csv, skipping the conversion.
# Processed and saved Cieran_Slicker.csv in merged_data/2021-22/GK
# 'starts' column not found in Mathew_Ryan.csv, skipping the conversion.
# Processed and saved Mathew_Ryan.csv in merged_data/2021-22/GK
# 'starts' column not found in José_Malheiro_de_Sá.csv, skipping the conversion.
# Processed and saved José_Malheiro_de_Sá.csv in merged_data/2021-22/GK
# 'starts' column not found in Marcus_Bettinelli.csv, skipping the conversion.
# Processed and saved Marcus_Bettinelli.csv in merged_data/2021-22/GK
# 'starts' column not found in Filip_Marschall.csv, skipping the conversion.
# Processed and saved Filip_Marschall.csv in merged_data/2021-22/GK
# 'starts' column not found in Darren_Randolph.csv, skipping the conversion.
# Processed and saved Darren_Randolph.csv in merged_data/2021-22/GK
# 'starts' column not found in Jon_McCracken.csv, skipping the conversion.
# Processed and saved Jon_McCracken.csv in merged_data/2021-22/GK
# 'starts' column not found in Fraser_Forster.csv, skipping the conversion.
# Processed and saved Fraser_Forster.csv in merged_data/2021-22/GK
# 'starts' column not found in Francisco_Casilla_Cortés.csv, skipping the conversion.
# Processed and saved Francisco_Casilla_Cortés.csv in merged_data/2021-22/GK
# 'starts' column not found in Mark_Gillespie.csv, skipping the conversion.
# Processed and saved Mark_Gillespie.csv in merged_data/2021-22/GK
# 'starts' column not found in Danny_Ward.csv, skipping the conversion.
# Processed and saved Danny_Ward.csv in merged_data/2021-22/GK
# 'starts' column not found in Álvaro_Fernández.csv, skipping the conversion.
# Processed and saved Álvaro_Fernández.csv in merged_data/2021-22/GK
# 'starts' column not found in Aaron_Ramsdale.csv, skipping the conversion.
# Processed and saved Aaron_Ramsdale.csv in merged_data/2021-22/GK
# 'starts' column not found in Karl_Darlow.csv, skipping the conversion.
# Processed and saved Karl_Darlow.csv in merged_data/2021-22/GK
# 'starts' column not found in Remi_Matthews.csv, skipping the conversion.
# Processed and saved Remi_Matthews.csv in merged_data/2021-22/GK
# 'starts' column not found in Alex_McCarthy.csv, skipping the conversion.
# Processed and saved Alex_McCarthy.csv in merged_data/2021-22/GK
# 'starts' column not found in Rui_Pedro_dos_Santos_Patrício.csv, skipping the conversion.
# Processed and saved Rui_Pedro_dos_Santos_Patrício.csv in merged_data/2021-22/GK
# 'starts' column not found in Jed_Steer.csv, skipping the conversion.
# Processed and saved Jed_Steer.csv in merged_data/2021-22/GK
# 'starts' column not found in Joe_Hart.csv, skipping the conversion.
# Processed and saved Joe_Hart.csv in merged_data/2021-22/GK
# 'starts' column not found in Will_Norris.csv, skipping the conversion.
# Processed and saved Will_Norris.csv in merged_data/2021-22/GK
# 'starts' column not found in Kasper_Schmeichel.csv, skipping the conversion.
# Processed and saved Kasper_Schmeichel.csv in merged_data/2021-22/GK
# 'starts' column not found in John_Ruddy.csv, skipping the conversion.
# Processed and saved John_Ruddy.csv in merged_data/2021-22/GK
# 'starts' column not found in Robin_Olsen.csv, skipping the conversion.
# Processed and saved Robin_Olsen.csv in merged_data/2021-22/GK
# 'starts' column not found in Michael_McGovern.csv, skipping the conversion.
# Processed and saved Michael_McGovern.csv in merged_data/2021-22/GK
# 'starts' column not found in Alphonse_Areola.csv, skipping the conversion.
# Processed and saved Alphonse_Areola.csv in merged_data/2021-22/GK
# 'starts' column not found in Matthew_Cox.csv, skipping the conversion.
# Processed and saved Matthew_Cox.csv in merged_data/2021-22/GK
# 'starts' column not found in Bailey_Peacock-Farrell.csv, skipping the conversion.
# Processed and saved Bailey_Peacock-Farrell.csv in merged_data/2021-22/GK
# 'starts' column not found in Pierluigi_Gollini.csv, skipping the conversion.
# Processed and saved Pierluigi_Gollini.csv in merged_data/2021-22/GK
# 'starts' column not found in Daniel_Bachmann.csv, skipping the conversion.
# Processed and saved Daniel_Bachmann.csv in merged_data/2021-22/GK
# 'starts' column not found in Tom_Heaton.csv, skipping the conversion.
# Processed and saved Tom_Heaton.csv in merged_data/2021-22/GK
# 'starts' column not found in Jonas_Lössl.csv, skipping the conversion.
# Processed and saved Jonas_Lössl.csv in merged_data/2021-22/GK
# 'starts' column not found in Arthur_Okonkwo.csv, skipping the conversion.
# Processed and saved Arthur_Okonkwo.csv in merged_data/2021-22/GK
# 'starts' column not found in Louie_Moulden.csv, skipping the conversion.
# Processed and saved Louie_Moulden.csv in merged_data/2021-22/GK
# 'starts' column not found in Kristoffer_Klaesson.csv, skipping the conversion.
# Processed and saved Kristoffer_Klaesson.csv in merged_data/2021-22/GK
# 'starts' column not found in Wayne_Hennessey.csv, skipping the conversion.
# Processed and saved Wayne_Hennessey.csv in merged_data/2021-22/GK
# 'starts' column not found in Rúnar_Alex_Rúnarsson.csv, skipping the conversion.
# Processed and saved Rúnar_Alex_Rúnarsson.csv in merged_data/2021-22/GK
# 'starts' column not found in Jason_Steele.csv, skipping the conversion.
# Processed and saved Jason_Steele.csv in merged_data/2021-22/GK
# 'starts' column not found in Ellery_Balcombe.csv, skipping the conversion.
# Processed and saved Ellery_Balcombe.csv in merged_data/2021-22/GK
# 'starts' column not found in Adrián_San_Miguel_del_Castillo.csv, skipping the conversion.
# Processed and saved Adrián_San_Miguel_del_Castillo.csv in merged_data/2021-22/GK
# 'starts' column not found in Zack_Steffen.csv, skipping the conversion.
# Processed and saved Zack_Steffen.csv in merged_data/2021-22/GK
# 'starts' column not found in João_Virgínia.csv, skipping the conversion.
# Processed and saved João_Virgínia.csv in merged_data/2021-22/GK
# 'starts' column not found in David_Raya_Martin.csv, skipping the conversion.
# Processed and saved David_Raya_Martin.csv in merged_data/2021-22/GK
# 'starts' column not found in Robert_Sánchez.csv, skipping the conversion.
# Processed and saved Robert_Sánchez.csv in merged_data/2021-22/GK
# 'starts' column not found in Marcelo_de_Araújo_Pitaluga_Filho.csv, skipping the conversion.
# Processed and saved Marcelo_de_Araújo_Pitaluga_Filho.csv in merged_data/2021-22/GK
# 'starts' column not found in Ben_Foster.csv, skipping the conversion.
# Processed and saved Ben_Foster.csv in merged_data/2021-22/GK
# 'starts' column not found in Andreas_Söndergaard.csv, skipping the conversion.
# Processed and saved Andreas_Söndergaard.csv in merged_data/2021-22/GK
# 'starts' column not found in Kepa_Arrizabalaga.csv, skipping the conversion.
# Processed and saved Kepa_Arrizabalaga.csv in merged_data/2021-22/GK
# 'starts' column not found in Thomas_McGill.csv, skipping the conversion.
# Processed and saved Thomas_McGill.csv in merged_data/2021-22/GK
# 'starts' column not found in David_de_Gea.csv, skipping the conversion.
# Processed and saved David_de_Gea.csv in merged_data/2021-22/GK
# 'starts' column not found in Robert_Elliot.csv, skipping the conversion.
# Processed and saved Robert_Elliot.csv in merged_data/2021-22/GK
# 'starts' column not found in Harry_Tyrer.csv, skipping the conversion.
# Processed and saved Harry_Tyrer.csv in merged_data/2021-22/GK
# 'starts' column not found in Dean_Henderson.csv, skipping the conversion.
# Processed and saved Dean_Henderson.csv in merged_data/2021-22/GK
# 'starts' column not found in Tim_Krul.csv, skipping the conversion.
# Processed and saved Tim_Krul.csv in merged_data/2021-22/GK
# 'starts' column not found in Nick_Pope.csv, skipping the conversion.
# Processed and saved Nick_Pope.csv in merged_data/2021-22/GK
# 'starts' column not found in Ederson_Santana_de_Moraes.csv, skipping the conversion.
# Processed and saved Ederson_Santana_de_Moraes.csv in merged_data/2021-22/GK
# 'starts' column not found in Eldin_Jakupovic.csv, skipping the conversion.
# Processed and saved Eldin_Jakupovic.csv in merged_data/2021-22/GK
# 'starts' column not found in Scott_Carson.csv, skipping the conversion.
# Processed and saved Scott_Carson.csv in merged_data/2021-22/GK
# 'starts' column not found in Kjell_Scherpen.csv, skipping the conversion.
# Processed and saved Kjell_Scherpen.csv in merged_data/2021-22/GK
# 'starts' column not found in Vicente_Guaita.csv, skipping the conversion.
# Processed and saved Vicente_Guaita.csv in merged_data/2021-22/GK
# 'starts' column not found in Andy_Lonergan.csv, skipping the conversion.
# Processed and saved Andy_Lonergan.csv in merged_data/2021-22/GK
# 'starts' column not found in Emiliano_Martínez.csv, skipping the conversion.
# Processed and saved Emiliano_Martínez.csv in merged_data/2021-22/GK
# 'starts' column not found in Caoimhin_Kelleher.csv, skipping the conversion.
# Processed and saved Caoimhin_Kelleher.csv in merged_data/2021-22/GK
# 'starts' column not found in Bernd_Leno.csv, skipping the conversion.
# Processed and saved Bernd_Leno.csv in merged_data/2021-22/GK
# 'starts' column not found in Jack_Butland.csv, skipping the conversion.
# Processed and saved Jack_Butland.csv in merged_data/2021-22/GK
# 'starts' column not found in Alisson_Ramses_Becker.csv, skipping the conversion.
# Processed and saved Alisson_Ramses_Becker.csv in merged_data/2021-22/GK
# 'starts' column not found in Jordan_Pickford.csv, skipping the conversion.
# Processed and saved Jordan_Pickford.csv in merged_data/2021-22/GK
# 'starts' column not found in Edouard_Mendy.csv, skipping the conversion.
# Processed and saved Edouard_Mendy.csv in merged_data/2021-22/GK
# 'starts' column not found in Sam_Waller.csv, skipping the conversion.
# Processed and saved Sam_Waller.csv in merged_data/2021-22/GK
# Processed and saved Martin_Dubravka.csv in merged_data/2022-23/GK
# Processed and saved Matija_Šarkić.csv in merged_data/2022-23/GK
# Processed and saved Hugo_Lloris.csv in merged_data/2022-23/GK
# Processed and saved Stefan_Ortega_Moreno.csv in merged_data/2022-23/GK
# Processed and saved Viljami_Sinisalo.csv in merged_data/2022-23/GK
# Processed and saved Brandon_Austin.csv in merged_data/2022-23/GK
# Processed and saved Illan_Meslier.csv in merged_data/2022-23/GK
# Processed and saved Lukasz_Fabianski.csv in merged_data/2022-23/GK
# Processed and saved Willy_Caballero.csv in merged_data/2022-23/GK
# Processed and saved Daniel_Iversen.csv in merged_data/2022-23/GK
# Processed and saved Gavin_Bazunu.csv in merged_data/2022-23/GK
# Processed and saved Karl_Hein.csv in merged_data/2022-23/GK
# Processed and saved Asmir_Begović.csv in merged_data/2022-23/GK
# Processed and saved David_De_Gea_Quintana.csv in merged_data/2022-23/GK
# Processed and saved Norberto_Murara_Neto.csv in merged_data/2022-23/GK
# Processed and saved José_Malheiro_de_Sá.csv in merged_data/2022-23/GK
# Processed and saved Marcus_Bettinelli.csv in merged_data/2022-23/GK
# Processed and saved Krisztián_Hegyi.csv in merged_data/2022-23/GK
# Processed and saved Filip_Marschall.csv in merged_data/2022-23/GK
# Processed and saved Darren_Randolph.csv in merged_data/2022-23/GK
# Processed and saved Tom_McGill.csv in merged_data/2022-23/GK
# Processed and saved Daniel_Bentley.csv in merged_data/2022-23/GK
# Processed and saved Mateusz_Lis.csv in merged_data/2022-23/GK
# Processed and saved Alex_Smithies.csv in merged_data/2022-23/GK
# Processed and saved Mark_Travers.csv in merged_data/2022-23/GK
# Processed and saved George_Shelvey.csv in merged_data/2022-23/GK
# Processed and saved Fraser_Forster.csv in merged_data/2022-23/GK
# Processed and saved Mark_Gillespie.csv in merged_data/2022-23/GK
# Processed and saved Danny_Ward.csv in merged_data/2022-23/GK
# Processed and saved Joseph_Whitworth.csv in merged_data/2022-23/GK
# Processed and saved Nathan_Bishop.csv in merged_data/2022-23/GK
# Processed and saved Aaron_Ramsdale.csv in merged_data/2022-23/GK
# Processed and saved Karl_Darlow.csv in merged_data/2022-23/GK
# Processed and saved Harvey_Davies.csv in merged_data/2022-23/GK
# Processed and saved Cameron_Plain.csv in merged_data/2022-23/GK
# Processed and saved Remi_Matthews.csv in merged_data/2022-23/GK
# Processed and saved Brice_Samba.csv in merged_data/2022-23/GK
# Processed and saved Alex_McCarthy.csv in merged_data/2022-23/GK
# Processed and saved Loris_Karius.csv in merged_data/2022-23/GK
# Processed and saved Owen_Goodman.csv in merged_data/2022-23/GK
# Processed and saved Oliwier_Zych.csv in merged_data/2022-23/GK
# Processed and saved Matt_Turner.csv in merged_data/2022-23/GK
# Processed and saved Thomas_Strakosha.csv in merged_data/2022-23/GK
# Processed and saved Kasper_Schmeichel.csv in merged_data/2022-23/GK
# Processed and saved Emiliano_Martínez_Romero.csv in merged_data/2022-23/GK
# Processed and saved Robin_Olsen.csv in merged_data/2022-23/GK
# Processed and saved Paulo_Gazzaniga_Farias.csv in merged_data/2022-23/GK
# Processed and saved Alphonse_Areola.csv in merged_data/2022-23/GK
# Processed and saved Matthew_Cox.csv in merged_data/2022-23/GK
# Processed and saved Joel_Robles.csv in merged_data/2022-23/GK
# Processed and saved Tom_Heaton.csv in merged_data/2022-23/GK
# Processed and saved Sam_Johnstone.csv in merged_data/2022-23/GK
# Processed and saved Kristoffer_Klaesson.csv in merged_data/2022-23/GK
# Processed and saved Wayne_Hennessey.csv in merged_data/2022-23/GK
# Processed and saved Jason_Steele.csv in merged_data/2022-23/GK
# Processed and saved Ellery_Balcombe.csv in merged_data/2022-23/GK
# Processed and saved Adrián_San_Miguel_del_Castillo.csv in merged_data/2022-23/GK
# Processed and saved Zack_Steffen.csv in merged_data/2022-23/GK
# Processed and saved Matej_Kovár.csv in merged_data/2022-23/GK
# Processed and saved David_Raya_Martin.csv in merged_data/2022-23/GK
# Processed and saved Robert_Sánchez.csv in merged_data/2022-23/GK
# Processed and saved Will_Dennis.csv in merged_data/2022-23/GK
# Processed and saved Kepa_Arrizabalaga.csv in merged_data/2022-23/GK
# Processed and saved Marek_Rodák.csv in merged_data/2022-23/GK
# Processed and saved James_Wright.csv in merged_data/2022-23/GK
# Processed and saved Ethan_Wady.csv in merged_data/2022-23/GK
# Processed and saved Robin_Olsen.csv in merged_data/2023-24/GK
# Processed and saved Alphonse_Areola.csv in merged_data/2023-24/GK
# Processed and saved Matthew_Cox.csv in merged_data/2023-24/GK
# Processed and saved Wes_Foderingham.csv in merged_data/2023-24/GK
# Processed and saved Tom_Heaton.csv in merged_data/2023-24/GK
# Processed and saved Matt_Macey.csv in merged_data/2023-24/GK
# Processed and saved Odysseas_Vlachodimos.csv in merged_data/2023-24/GK
# Processed and saved Bart_Verbruggen.csv in merged_data/2023-24/GK
# Processed and saved Sam_Johnstone.csv in merged_data/2023-24/GK
# Processed and saved Arijanet_Muric.csv in merged_data/2023-24/GK
# Processed and saved Wayne_Hennessey.csv in merged_data/2023-24/GK
# Processed and saved Jason_Steele.csv in merged_data/2023-24/GK
# Processed and saved Zack_Steffen.csv in merged_data/2023-24/GK
# Processed and saved Tom_King.csv in merged_data/2023-24/GK
# Processed and saved David_Raya_Martin.csv in merged_data/2023-24/GK
# Processed and saved Mark_Flekken.csv in merged_data/2023-24/GK
# Processed and saved Robert_Sánchez.csv in merged_data/2023-24/GK
# Processed and saved Joe_Whitworth.csv in merged_data/2023-24/GK
# Processed and saved Marek_Rodák.csv in merged_data/2023-24/GK
# Processed and saved James_Wright.csv in merged_data/2023-24/GK
# Processed and saved André_Onana.csv in merged_data/2023-24/GK
# Processed and saved Joe_Gauci.csv in merged_data/2023-24/GK
# Processed and saved Dean_Henderson.csv in merged_data/2023-24/GK
# Processed and saved Nick_Pope.csv in merged_data/2023-24/GK
# Processed and saved Joseph_Anang.csv in merged_data/2023-24/GK
# Processed and saved Scott_Carson.csv in merged_data/2023-24/GK
# Processed and saved Guglielmo_Vicario.csv in merged_data/2023-24/GK
# Processed and saved Vicente_Guaita.csv in merged_data/2023-24/GK
# Processed and saved Caoimhin_Kelleher.csv in merged_data/2023-24/GK
# Processed and saved Bernd_Leno.csv in merged_data/2023-24/GK
# Processed and saved Jordan_Pickford.csv in merged_data/2023-24/GK

# %%
### CALUCLATING FORM FOR THE FWD & MID DATA 
import os
import pandas as pd

# Path to merged_data directory
root_dir = 'merged_data'

# Function to calculate form over last five games (or as many as available)
def calculate_form(series, num_games=5):
    form = []
    for i in range(len(series)):
        if i < num_games:
            form.append(series[:i].mean() if i > 0 else 0)  # Avoid empty slice error
        else:
            form.append(series[i-num_games:i].mean())
    return form

# Function to get stats from last season
def get_last_season_stats(player_name, last_season_dir, position):
    # The previous season's file path should point to the respective FWD/MID directory
    last_season_file = os.path.join(last_season_dir, position, player_name)
    
    print(f"Looking for {player_name} in {last_season_file}")  # Debugging
    
    if os.path.exists(last_season_file):
        last_season_df = pd.read_csv(last_season_file)
        if not last_season_df.empty:
            # Ensure the file has the necessary columns
            required_columns = ['goals', 'assists', 'xG', 'xA', 'total_points', 'minutes']
            if all(col in last_season_df.columns for col in required_columns):
                total_goals = last_season_df['goals'].sum()
                total_assists = last_season_df['assists'].sum()
                total_xG = last_season_df['xG'].sum()
                total_xA = last_season_df['xA'].sum()
                total_points = last_season_df['total_points'].sum()
                total_minutes = last_season_df['minutes'].sum()
                points_per_minute = total_points / total_minutes if total_minutes > 0 else 0
                
                print(f"Stats found for {player_name}: Goals: {total_goals}, Assists: {total_assists}, xG: {total_xG}, xA: {total_xA}, Points/Min: {points_per_minute}")  # Debugging
                
                return total_goals, total_assists, total_xG, total_xA, points_per_minute
            else:
                print(f"Missing columns in {last_season_file}")  # Debugging
    else:
        print(f"File {last_season_file} not found.")  # Debugging
    
    return 0, 0, 0, 0, 0

# Loop through both FWD and MID directories across all seasons
for season in ['2021-22', '2022-23', '2023-24']:
    for position in ['FWD', 'MID']:
        position_dir = os.path.join(root_dir, season, position)
        last_season_dir = os.path.join(root_dir, f'{int(season[:4])-1}-{int(season[5:7])-1}')
        
        # Check if position directory exists
        if not os.path.exists(position_dir):
            print(f"Directory {position_dir} does not exist. Skipping.")
            continue

        # Loop through each CSV file in the position directory
        for player_file in os.listdir(position_dir):
            player_path = os.path.join(position_dir, player_file)
            
            # Read the CSV file and check for empty or corrupted files
            try:
                df = pd.read_csv(player_path)
            except pd.errors.EmptyDataError:
                print(f"File {player_path} is empty or corrupted. Skipping.")
                continue
            
            # Check if required columns exist before processing
            required_columns = ['total_points', 'xG', 'assists', 'minutes']
            if not all(col in df.columns for col in required_columns):
                print(f"File {player_path} is missing required columns. Skipping.")
                continue
            
            # 1. Create 'form' column
            df['form'] = calculate_form(df['total_points'])
            
            # 2. Create 'xG&A_form' column
            df['xG&A_form'] = calculate_form(df[['xG', 'assists']].sum(axis=1))
            
            # 3. Create 'minutes per game' column
            df['minutes_per_game'] = df['minutes'].cumsum() / (df.index + 1)
            
            # 4. Get last season stats (only for 2022-23 and 2023-24 seasons)
            if season in ['2022-23', '2023-24']:
                last_season_goals, last_season_assists, last_season_xG, last_season_xA, last_season_ppm = get_last_season_stats(player_file, last_season_dir, position)
                df['last_season_goals'] = last_season_goals
                df['last_season_assists'] = last_season_assists
                df['last_season_xG'] = last_season_xG
                df['last_season_xA'] = last_season_xA
                df['last_season_points_per_minute'] = last_season_ppm
            
            # Round all numerical columns to two decimal places
            df = df.round(2)
            
            # Save the updated dataframe back to the CSV file
            df.to_csv(player_path, index=False)

print("All forward and midfielder CSV files have been processed and rounded to two decimal places.")
# Out:
# File merged_data/2021-22/FWD/Isaac_Success_Ajayi.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Jordan_Hugill.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Adedapo_Awokoya-Mebude.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Kayky_da_Silva_Chagas.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Gabriel_Fernando_de_Jesus.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Halil_Dervişoğlu.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Shaqai_Forde.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Mika_Biereth.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/João_Pedro_Junqueira_de_Jesus.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Joseph_McGlynn.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Florin_Andone.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Richarlison_de_Andrade.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Mbwana_Ally_Samatta.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Thomas_Dickson-Peters.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Tiago_Çukur.csv is missing required columns. Skipping.
# File merged_data/2021-22/FWD/Stipe_Perica.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Dara_Costelloe.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Marcelo_Flores.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/N'Golo_Kanté.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Ayotomiwa_Dele-Bashiru.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Frederico_Rodrigues_de_Paula_Santos.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Maxwell_Haygarth.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Tyler_Dibling.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Mahmoud_Ahmed_Ibrahim_Hassan.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Daniel_Castelo_Podence.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Nohan_Kenneh.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Paris_Maghoma.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Marco_Stiepermann.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Fernando_Luiz_Rosa.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Mohamed_Naser_El_Sayed_Elneny.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Myles_Peart-Harris.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Bernardo_Mota_Veiga_de_Carvalho_e_Silva.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Lucas_Rodrigues_Moura_da_Silva.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Philip_Zinckernagel.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Francisco_Machado_Mota_de_Castro_Trincão.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Kgaogelo_Chauke.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Tommy_Doyle.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Romeo_Lavia.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Domingos_Quina.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Fabio_Henrique_Tavares.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Hélder_Wander_Sousa_de_Azevedo_e_Costa.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Lucas_De_Bolle.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Mattéo_Guendouzi.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Conor_Coventry.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Kamil_Conteh.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Pelenda_Joshua_Dasilva.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/João_Filipe_Iria_Santos_Moutinho.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/André_Filipe_Tavares_Gomes.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Bruno_Miguel_Borges_Fernandes.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Kwadwo_Baah.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Omari_Hutchinson.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Bernard_Anício_Caldeira_Duarte.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Bruno_André_Cavaco_Jordão.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Dilan_Markanday.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Salah-Eddine_Oulad_M'hand.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Lucas_Torreira.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Jorge_Luiz_Frello_Filho.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Francisco_Jorge_Tomás_Oliveira.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Samuel_Edozie.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Rúben_Diogo_da_Silva_Neves.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Tommi_O'Reilly.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Raphael_Dias_Belloli.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Pedro_Lomba_Neto.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Allan_Marques_Loureiro.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Armstrong_Oko-Flex.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Willian_Borges_Da_Silva.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Alfie_Devine.csv is missing required columns. Skipping.
# Looking for Jamie_Vardy.csv in merged_data/2021-22/FWD/Jamie_Vardy.csv
# Stats found for Jamie_Vardy.csv: Goals: 15.0, Assists: 2.0, xG: 9.990000000000002, xA: 1.6000000000000003, Points/Min: 0.07384786229872294
# File merged_data/2022-23/FWD/Terry_Ablade.csv is missing required columns. Skipping.
# Looking for Odsonne_Edouard.csv in merged_data/2021-22/FWD/Odsonne_Edouard.csv
# Stats found for Odsonne_Edouard.csv: Goals: 6.0, Assists: 4.0, xG: 6.55, xA: 2.17, Points/Min: 0.055984555984555984
# Looking for Pierre-Emerick_Aubameyang.csv in merged_data/2021-22/FWD/Pierre-Emerick_Aubameyang.csv
# Stats found for Pierre-Emerick_Aubameyang.csv: Goals: 5.0, Assists: 1.0, xG: 8.92, xA: 1.05, Points/Min: 0.04247104247104247
# File merged_data/2022-23/FWD/Mateo_Joseph_Fernández.csv is missing required columns. Skipping.
# File merged_data/2021-22/MID/Joe_Rothwell.csv not found.
# File merged_data/2022-23/MID/Lucas_Tolentino_Coelho_de_Lima.csv is missing required columns. Skipping.
# Looking for Mikkel_Damsgaard.csv in merged_data/2021-22/MID/Mikkel_Damsgaard.csv
# File merged_data/2021-22/MID/Mikkel_Damsgaard.csv not found.
# Looking for Vitaly_Janelt.csv in merged_data/2021-22/MID/Vitaly_Janelt.csv
# Stats found for Vitaly_Janelt.csv: Goals: 4.0, Assists: 0.0, xG: 3.0, xA: 1.83, Points/Min: 0.0392156862745098
# Looking for Morgan_Gibbs-White.csv in merged_data/2021-22/MID/Morgan_Gibbs-White.csv
# Stats found for Morgan_Gibbs-White.csv: Goals: 0.0, Assists: 0.0, xG: 0.1, xA: 0.0, Points/Min: 0.14285714285714285
# Looking for Jonjo_Shelvey.csv in merged_data/2021-22/MID/Jonjo_Shelvey.csv
# Stats found for Jonjo_Shelvey.csv: Goals: 2.0, Assists: 1.0, xG: 0.88, xA: 1.04, Points/Min: 0.03180212014134275
# Looking for Bryan_Gil_Salvatierra.csv in merged_data/2021-22/MID/Bryan_Gil_Salvatierra.csv
# Stats found for Bryan_Gil_Salvatierra.csv: Goals: 0.0, Assists: 0.0, xG: 1.07, xA: 0.47000000000000003, Points/Min: 0.10465116279069768
# Looking for Miguel_Almirón_Rejala.csv in merged_data/2021-22/MID/Miguel_Almirón_Rejala.csv
# File merged_data/2021-22/MID/Miguel_Almirón_Rejala.csv not found.
# Looking for Dango_Ouattara.csv in merged_data/2021-22/MID/Dango_Ouattara.csv
# File merged_data/2021-22/MID/Dango_Ouattara.csv not found.
# File merged_data/2022-23/MID/N'Golo_Kanté.csv is missing required columns. Skipping.
# Looking for Donny_van_de_Beek.csv in merged_data/2021-22/MID/Donny_van_de_Beek.csv
# Stats found for Donny_van_de_Beek.csv: Goals: 2.0, Assists: 0.0, xG: 1.5100000000000002, xA: 0.43000000000000005, Points/Min: 0.056363636363636366
# Looking for Shandon_Baptiste.csv in merged_data/2021-22/MID/Shandon_Baptiste.csv
# Stats found for Shandon_Baptiste.csv: Goals: 1.0, Assists: 0.0, xG: 0.58, xA: 0.55, Points/Min: 0.03897550111358575
# Looking for Carlos_Alcaraz.csv in merged_data/2021-22/MID/Carlos_Alcaraz.csv
# File merged_data/2021-22/MID/Carlos_Alcaraz.csv not found.
# File merged_data/2022-23/MID/Hamza_Choudhury.csv is missing required columns. Skipping.
# Looking for Curtis_Jones.csv in merged_data/2021-22/MID/Curtis_Jones.csv
# Stats found for Curtis_Jones.csv: Goals: 1.0, Assists: 1.0, xG: 0.8300000000000001, xA: 0.68, Points/Min: 0.04711425206124853
# Looking for Alexis_Mac_Allister.csv in merged_data/2021-22/MID/Alexis_Mac_Allister.csv
# Stats found for Alexis_Mac_Allister.csv: Goals: 5.0, Assists: 2.0, xG: 6.82, xA: 2.12, Points/Min: 0.04403409090909091
# Looking for Tom_Davies.csv in merged_data/2021-22/MID/Tom_Davies.csv
# Stats found for Tom_Davies.csv: Goals: 1.0, Assists: 0.0, xG: 1.0, xA: 0.0, Points/Min: 0.05217391304347826
# Looking for Junior_Stanislas.csv in merged_data/2021-22/MID/Junior_Stanislas.csv
# File merged_data/2021-22/MID/Junior_Stanislas.csv not found.
# Looking for Mohamed_Elyounoussi.csv in merged_data/2021-22/MID/Mohamed_Elyounoussi.csv
# Stats found for Mohamed_Elyounoussi.csv: Goals: 4.0, Assists: 2.0, xG: 6.569999999999999, xA: 2.2199999999999998, Points/Min: 0.04413928396272683
# Looking for Siriki_Dembélé.csv in merged_data/2021-22/MID/Siriki_Dembélé.csv
# File merged_data/2021-22/MID/Siriki_Dembélé.csv not found.
# Looking for Jordan_Ayew.csv in merged_data/2021-22/MID/Jordan_Ayew.csv
# File merged_data/2021-22/MID/Jordan_Ayew.csv not found.
# Looking for Bruno_Guimarães_Rodriguez_Moura.csv in merged_data/2021-22/MID/Bruno_Guimarães_Rodriguez_Moura.csv
# Stats found for Bruno_Guimarães_Rodriguez_Moura.csv: Goals: 5, Assists: 1, xG: 4.11, xA: 1.75, Points/Min: 0.06498545101842872
# Looking for Oriol_Romeu_Vidal.csv in merged_data/2021-22/MID/Oriol_Romeu_Vidal.csv
# Stats found for Oriol_Romeu_Vidal.csv: Goals: 2.0, Assists: 2.0, xG: 1.4900000000000002, xA: 3.0700000000000003, Points/Min: 0.03044982698961938
# Looking for Josh_Onomah.csv in merged_data/2021-22/MID/Josh_Onomah.csv
# File merged_data/2021-22/MID/Josh_Onomah.csv not found.
# Looking for Lewis_Hall.csv in merged_data/2021-22/MID/Lewis_Hall.csv
# Stats found for Lewis_Hall.csv: Goals: 0.0, Assists: 0.0, xG: 0.0, xA: 0.0, Points/Min: 0
# Looking for Yoane_Wissa.csv in merged_data/2021-22/MID/Yoane_Wissa.csv
# Stats found for Yoane_Wissa.csv: Goals: 7.0, Assists: 1.0, xG: 3.4000000000000004, xA: 0.6799999999999999, Points/Min: 0.07255520504731862
# Looking for James_Maddison.csv in merged_data/2021-22/MID/James_Maddison.csv
# Stats found for James_Maddison.csv: Goals: 12.0, Assists: 8.0, xG: 6.489999999999999, xA: 5.6499999999999995, Points/Min: 0.07375713121434394
# Looking for Idrissa_Gueye.csv in merged_data/2021-22/MID/Idrissa_Gueye.csv
# File merged_data/2021-22/MID/Idrissa_Gueye.csv not found.
# Looking for Emiliano_Buendía_Stati.csv in merged_data/2021-22/MID/Emiliano_Buendía_Stati.csv
# Stats found for Emiliano_Buendía_Stati.csv: Goals: 4.0, Assists: 6.0, xG: 3.07, xA: 4.66, Points/Min: 0.05670376258611553
# File merged_data/2022-23/MID/Matthew_Dibley-Dias.csv is missing required columns. Skipping.
# Looking for Harvey_Barnes.csv in merged_data/2021-22/MID/Harvey_Barnes.csv
# Stats found for Harvey_Barnes.csv: Goals: 6.0, Assists: 10.0, xG: 6.220000000000001, xA: 4.47, Points/Min: 0.06539379474940334
# Looking for Flynn_Downes.csv in merged_data/2021-22/MID/Flynn_Downes.csv
# File merged_data/2021-22/MID/Flynn_Downes.csv not found.
# File merged_data/2022-23/MID/Ross_Barkley.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Zidane_Iqbal.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Frederico_Rodrigues_de_Paula_Santos.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Jesurun_Rak-Sakyi.csv is missing required columns. Skipping.
# Looking for Cole_Palmer.csv in merged_data/2021-22/MID/Cole_Palmer.csv
# Stats found for Cole_Palmer.csv: Goals: 0.0, Assists: 0.0, xG: 0.28, xA: 0.45, Points/Min: 0.0743801652892562
# Looking for Brenden_Aaronson.csv in merged_data/2021-22/MID/Brenden_Aaronson.csv
# File merged_data/2021-22/MID/Brenden_Aaronson.csv not found.
# Looking for Philip_Billing.csv in merged_data/2021-22/MID/Philip_Billing.csv
# File merged_data/2021-22/MID/Philip_Billing.csv not found.
# Looking for Carney_Chukwuemeka.csv in merged_data/2021-22/MID/Carney_Chukwuemeka.csv
# Stats found for Carney_Chukwuemeka.csv: Goals: 0.0, Assists: 1.0, xG: 0.6299999999999999, xA: 0.99, Points/Min: 0.054982817869415807
# File merged_data/2022-23/MID/Anwar_El_Ghazi.csv is missing required columns. Skipping.
# Looking for Mason_Mount.csv in merged_data/2021-22/MID/Mason_Mount.csv
# Stats found for Mason_Mount.csv: Goals: 11.0, Assists: 10.0, xG: 8.5, xA: 7.23, Points/Min: 0.07167090754877015
# Looking for Cameron_Peupion.csv in merged_data/2021-22/MID/Cameron_Peupion.csv
# File merged_data/2021-22/MID/Cameron_Peupion.csv not found.
# Looking for Luis_Díaz.csv in merged_data/2021-22/MID/Luis_Díaz.csv
# Stats found for Luis_Díaz.csv: Goals: 4.0, Assists: 3.0, xG: 4.27, xA: 2.17, Points/Min: 0.06687565308254964
# File merged_data/2022-23/MID/Daniel_Castelo_Podence.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Fábio_Freitas_Gouveia_Carvalho.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Wanya_Marçal-Madivadua.csv is missing required columns. Skipping.
# Looking for Saman_Ghoddos.csv in merged_data/2021-22/MID/Saman_Ghoddos.csv
# Stats found for Saman_Ghoddos.csv: Goals: 1.0, Assists: 1.0, xG: 0.71, xA: 1.18, Points/Min: 0.05725190839694656
# File merged_data/2022-23/MID/Mauro_Bandeira.csv is missing required columns. Skipping.
# Looking for Jacob_Ramsey.csv in merged_data/2021-22/MID/Jacob_Ramsey.csv
# Stats found for Jacob_Ramsey.csv: Goals: 6.0, Assists: 1.0, xG: 3.82, xA: 2.0100000000000002, Points/Min: 0.044219066937119675
# Looking for Thomas_Partey.csv in merged_data/2021-22/MID/Thomas_Partey.csv
# Stats found for Thomas_Partey.csv: Goals: 2.0, Assists: 1.0, xG: 3.0300000000000002, xA: 0.8700000000000001, Points/Min: 0.03502713369511593
# Looking for Tyler_Adams.csv in merged_data/2021-22/MID/Tyler_Adams.csv
# File merged_data/2021-22/MID/Tyler_Adams.csv not found.
# Looking for Dejan_Kulusevski.csv in merged_data/2021-22/MID/Dejan_Kulusevski.csv
# Stats found for Dejan_Kulusevski.csv: Goals: 5, Assists: 8, xG: 3.02, xA: 4.140000000000001, Points/Min: 0.07863383637807785
# Looking for Nampalys_Mendy.csv in merged_data/2021-22/MID/Nampalys_Mendy.csv
# Stats found for Nampalys_Mendy.csv: Goals: 0.0, Assists: 0.0, xG: 0.02, xA: 0.03, Points/Min: 0.023255813953488372
# Looking for Weston_McKennie.csv in merged_data/2021-22/MID/Weston_McKennie.csv
# File merged_data/2021-22/MID/Weston_McKennie.csv not found.
# Looking for Kevin_De_Bruyne.csv in merged_data/2021-22/MID/Kevin_De_Bruyne.csv
# Stats found for Kevin_De_Bruyne.csv: Goals: 15.0, Assists: 8.0, xG: 5.930000000000001, xA: 11.280000000000001, Points/Min: 0.08925318761384335
# Looking for Alex_Iwobi.csv in merged_data/2021-22/MID/Alex_Iwobi.csv
# Stats found for Alex_Iwobi.csv: Goals: 2.0, Assists: 2.0, xG: 2.4, xA: 3.0700000000000003, Points/Min: 0.03844258255298177
# Looking for Remo_Freuler.csv in merged_data/2021-22/MID/Remo_Freuler.csv
# File merged_data/2021-22/MID/Remo_Freuler.csv not found.
# Looking for Shea_Charles.csv in merged_data/2021-22/MID/Shea_Charles.csv
# File merged_data/2021-22/MID/Shea_Charles.csv not found.
# File merged_data/2022-23/MID/Nikola_Vlasic.csv is missing required columns. Skipping.
# Looking for James_Ward-Prowse.csv in merged_data/2021-22/MID/James_Ward-Prowse.csv
# Stats found for James_Ward-Prowse.csv: Goals: 10.0, Assists: 5.0, xG: 5.08, xA: 6.39, Points/Min: 0.049455676516329705
# Looking for David_Ozoh.csv in merged_data/2021-22/MID/David_Ozoh.csv
# File merged_data/2021-22/MID/David_Ozoh.csv not found.
# Looking for Abdoulaye_Doucouré.csv in merged_data/2021-22/MID/Abdoulaye_Doucouré.csv
# Stats found for Abdoulaye_Doucouré.csv: Goals: 2.0, Assists: 4.0, xG: 2.6600000000000006, xA: 2.42, Points/Min: 0.03548895899053628
# Looking for Crysencio_Summerville.csv in merged_data/2021-22/MID/Crysencio_Summerville.csv
# Stats found for Crysencio_Summerville.csv: Goals: 0.0, Assists: 0.0, xG: 0.32999999999999996, xA: 0.04, Points/Min: 0.047619047619047616
# Looking for Jack_Grealish.csv in merged_data/2021-22/MID/Jack_Grealish.csv
# Stats found for Jack_Grealish.csv: Goals: 3.0, Assists: 3.0, xG: 5.53, xA: 5.4799999999999995, Points/Min: 0.04502617801047121
# Looking for Eberechi_Eze.csv in merged_data/2021-22/MID/Eberechi_Eze.csv
# Stats found for Eberechi_Eze.csv: Goals: 1.0, Assists: 1.0, xG: 0.45, xA: 0.9699999999999999, Points/Min: 0.05175292153589316
# Looking for Harry_Wilson.csv in merged_data/2021-22/MID/Harry_Wilson.csv
# File merged_data/2021-22/MID/Harry_Wilson.csv not found.
# Looking for Noni_Madueke.csv in merged_data/2021-22/MID/Noni_Madueke.csv
# File merged_data/2021-22/MID/Noni_Madueke.csv not found.
# Stats found for Elliot_Anderson.csv: Goals: 0.0, Assists: 0.0, xG: 0.0, xA: 0.0, Points/Min: 0
# Looking for Andros_Townsend.csv in merged_data/2021-22/MID/Andros_Townsend.csv
# Stats found for Andros_Townsend.csv: Goals: 3.0, Assists: 2.0, xG: 2.27, xA: 2.8600000000000003, Points/Min: 0.045454545454545456
# Looking for Yasin_Ayari.csv in merged_data/2021-22/MID/Yasin_Ayari.csv
# File merged_data/2021-22/MID/Yasin_Ayari.csv not found.
# Looking for Naby_Keita.csv in merged_data/2021-22/MID/Naby_Keita.csv
# Stats found for Naby_Keita.csv: Goals: 3.0, Assists: 1.0, xG: 2.1500000000000004, xA: 1.8100000000000003, Points/Min: 0.055603079555175364
# File merged_data/2022-23/MID/Andrey_Nascimento_dos_Santos.csv is missing required columns. Skipping.
# Looking for Raheem_Sterling.csv in merged_data/2021-22/MID/Raheem_Sterling.csv
# Stats found for Raheem_Sterling.csv: Goals: 13.0, Assists: 5.0, xG: 15.81, xA: 5.04, Points/Min: 0.07685054219707685
# Looking for Mateo_Kovacic.csv in merged_data/2021-22/MID/Mateo_Kovacic.csv
# Stats found for Mateo_Kovacic.csv: Goals: 2.0, Assists: 5.0, xG: 1.6900000000000002, xA: 4.13, Points/Min: 0.04896907216494845
# Looking for Ainsley_Maitland-Niles.csv in merged_data/2021-22/MID/Ainsley_Maitland-Niles.csv
# Stats found for Ainsley_Maitland-Niles.csv: Goals: 0.0, Assists: 0.0, xG: 0.19, xA: 0.34, Points/Min: 0.045627376425855515
# Looking for Leandro_Trossard.csv in merged_data/2021-22/MID/Leandro_Trossard.csv
# Stats found for Leandro_Trossard.csv: Goals: 8.0, Assists: 3.0, xG: 7.949999999999999, xA: 5.279999999999999, Points/Min: 0.050303246521584015
# File merged_data/2022-23/MID/Hwang_Hee-chan.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Nico_O'Reilly.csv is missing required columns. Skipping.
# Looking for Daniel_James.csv in merged_data/2021-22/MID/Daniel_James.csv
# Stats found for Daniel_James.csv: Goals: 4.0, Assists: 4.0, xG: 7.719999999999999, xA: 4.27, Points/Min: 0.03656086781840096
# Looking for Adama_Traoré_Diarra.csv in merged_data/2021-22/MID/Adama_Traoré_Diarra.csv
# File merged_data/2021-22/MID/Adama_Traoré_Diarra.csv not found.
# Looking for Cheikhou_Kouyaté.csv in merged_data/2021-22/MID/Cheikhou_Kouyaté.csv
# File merged_data/2021-22/MID/Cheikhou_Kouyaté.csv not found.
# File merged_data/2022-23/MID/Steven_Bergwijn.csv is missing required columns. Skipping.
# Looking for Mohamed_Elneny.csv in merged_data/2021-22/MID/Mohamed_Elneny.csv
# File merged_data/2021-22/MID/Mohamed_Elneny.csv not found.
# Looking for Luka_Milivojevic.csv in merged_data/2021-22/MID/Luka_Milivojevic.csv
# Stats found for Luka_Milivojevic.csv: Goals: 0.0, Assists: 0.0, xG: 0.29000000000000004, xA: 0.64, Points/Min: 0.024771838331160364
# Looking for Malcolm_Ebiowei.csv in merged_data/2021-22/MID/Malcolm_Ebiowei.csv
# File merged_data/2021-22/MID/Malcolm_Ebiowei.csv not found.
# Looking for Jordan_Henderson.csv in merged_data/2021-22/MID/Jordan_Henderson.csv
# Stats found for Jordan_Henderson.csv: Goals: 2.0, Assists: 5.0, xG: 1.3800000000000001, xA: 4.1899999999999995, Points/Min: 0.04243827160493827
# Looking for Ben_Pearson.csv in merged_data/2021-22/MID/Ben_Pearson.csv
# File merged_data/2021-22/MID/Ben_Pearson.csv not found.
# Looking for Harry_Winks.csv in merged_data/2021-22/MID/Harry_Winks.csv
# Stats found for Harry_Winks.csv: Goals: 0.0, Assists: 1.0, xG: 0.07, xA: 1.5300000000000002, Points/Min: 0.03650442477876106
# Looking for Andrew_Moran.csv in merged_data/2021-22/MID/Andrew_Moran.csv
# File merged_data/2021-22/MID/Andrew_Moran.csv not found.
# Looking for Martin_Ødegaard.csv in merged_data/2021-22/MID/Martin_Ødegaard.csv
# Stats found for Martin_Ødegaard.csv: Goals: 7.0, Assists: 4.0, xG: 4.22, xA: 6.61, Points/Min: 0.04708842559309849
# Looking for Billy_Gilmour.csv in merged_data/2021-22/MID/Billy_Gilmour.csv
# Stats found for Billy_Gilmour.csv: Goals: 0.0, Assists: 1.0, xG: 0.8500000000000001, xA: 1.05, Points/Min: 0.026457883369330453
# Looking for Morgan_Sanson.csv in merged_data/2021-22/MID/Morgan_Sanson.csv
# Stats found for Morgan_Sanson.csv: Goals: 0.0, Assists: 0.0, xG: 0.01, xA: 0.03, Points/Min: 0.03724928366762178
# Looking for Marc_Albrighton.csv in merged_data/2021-22/MID/Marc_Albrighton.csv
# Stats found for Marc_Albrighton.csv: Goals: 1.0, Assists: 2.0, xG: 0.49, xA: 1.7000000000000002, Points/Min: 0.0354924578527063
# Looking for Pascal_Groß.csv in merged_data/2021-22/MID/Pascal_Groß.csv
# Stats found for Pascal_Groß.csv: Goals: 2.0, Assists: 4.0, xG: 2.85, xA: 5.7700000000000005, Points/Min: 0.04328578455484506
# Looking for Michael_Olakigbe.csv in merged_data/2021-22/MID/Michael_Olakigbe.csv
# File merged_data/2021-22/MID/Michael_Olakigbe.csv not found.
# Looking for Mathias_Jensen.csv in merged_data/2021-22/MID/Mathias_Jensen.csv
# Stats found for Mathias_Jensen.csv: Goals: 0.0, Assists: 1.0, xG: 2.71, xA: 3.16, Points/Min: 0.033962264150943396
# Looking for Reiss_Nelson.csv in merged_data/2021-22/MID/Reiss_Nelson.csv
# Stats found for Reiss_Nelson.csv: Goals: 0.0, Assists: 0.0, xG: 0.04, xA: 0.06, Points/Min: 0.05263157894736842
# File merged_data/2022-23/MID/Carlos_Ribeiro_Dias.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Danilo_dos_Santos_de_Oliveira.csv is missing required columns. Skipping.
# Looking for Lewis_Miley.csv in merged_data/2021-22/MID/Lewis_Miley.csv
# File merged_data/2021-22/MID/Lewis_Miley.csv not found.
# File merged_data/2022-23/MID/Claudio_Gomes.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Lucas_Rodrigues_Moura_da_Silva.csv is missing required columns. Skipping.
# Looking for Amadou_Onana.csv in merged_data/2021-22/MID/Amadou_Onana.csv
# File merged_data/2021-22/MID/Amadou_Onana.csv not found.
# Looking for Anthony_Gordon.csv in merged_data/2021-22/MID/Anthony_Gordon.csv
# Stats found for Anthony_Gordon.csv: Goals: 4.0, Assists: 2.0, xG: 3.45, xA: 3.77, Points/Min: 0.04391743522178305
# Looking for James_McAtee.csv in merged_data/2021-22/MID/James_McAtee.csv
# Stats found for James_McAtee.csv: Goals: 0.0, Assists: 0.0, xG: 0.09, xA: 0.0, Points/Min: 0.1111111111111111
# File merged_data/2022-23/MID/Lewis_Payne.csv is missing required columns. Skipping.
# Looking for Jack_Harrison.csv in merged_data/2021-22/MID/Jack_Harrison.csv
# Stats found for Jack_Harrison.csv: Goals: 8.0, Assists: 1.0, xG: 5.1499999999999995, xA: 3.45, Points/Min: 0.04435178165276725
# Looking for Ibrahima_Diallo.csv in merged_data/2021-22/MID/Ibrahima_Diallo.csv
# Stats found for Ibrahima_Diallo.csv: Goals: 0.0, Assists: 2.0, xG: 0.33999999999999997, xA: 1.05, Points/Min: 0.04330708661417323
# Looking for Connor_Ronan.csv in merged_data/2021-22/MID/Connor_Ronan.csv
# File merged_data/2021-22/MID/Connor_Ronan.csv not found.
# File merged_data/2022-23/MID/Mateus_Cardoso_Lemos_Martins.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Ivan_Neves_Abreu_Cavaleiro.csv is missing required columns. Skipping.
# Looking for Saïd_Benrahma.csv in merged_data/2021-22/MID/Saïd_Benrahma.csv
# Stats found for Saïd_Benrahma.csv: Goals: 8.0, Assists: 6.0, xG: 6.129999999999999, xA: 4.790000000000001, Points/Min: 0.06382978723404255
# Looking for Jamal_Lowe.csv in merged_data/2021-22/MID/Jamal_Lowe.csv
# File merged_data/2021-22/MID/Jamal_Lowe.csv not found.
# Looking for Arnaut_Danjuma.csv in merged_data/2021-22/MID/Arnaut_Danjuma.csv
# File merged_data/2021-22/MID/Arnaut_Danjuma.csv not found.
# Looking for Kevin_Schade.csv in merged_data/2021-22/MID/Kevin_Schade.csv
# File merged_data/2021-22/MID/Kevin_Schade.csv not found.
# Looking for Christian_Nørgaard.csv in merged_data/2021-22/MID/Christian_Nørgaard.csv
# Stats found for Christian_Nørgaard.csv: Goals: 3.0, Assists: 4.0, xG: 4.98, xA: 4.04, Points/Min: 0.03307138179436804
# Looking for Riyad_Mahrez.csv in merged_data/2021-22/MID/Riyad_Mahrez.csv
# Stats found for Riyad_Mahrez.csv: Goals: 11.0, Assists: 5.0, xG: 10.12, xA: 3.94, Points/Min: 0.09090909090909091
# Looking for Alex_Mighten.csv in merged_data/2021-22/MID/Alex_Mighten.csv
# File merged_data/2021-22/MID/Alex_Mighten.csv not found.
# Looking for Jefferson_Lerma_Solís.csv in merged_data/2021-22/MID/Jefferson_Lerma_Solís.csv
# File merged_data/2021-22/MID/Jefferson_Lerma_Solís.csv not found.
# Looking for Michael_Olise.csv in merged_data/2021-22/MID/Michael_Olise.csv
# Stats found for Michael_Olise.csv: Goals: 2.0, Assists: 5.0, xG: 1.4800000000000002, xA: 4.95, Points/Min: 0.064773735581189
# Looking for Facundo_Buonanotte.csv in merged_data/2021-22/MID/Facundo_Buonanotte.csv
# File merged_data/2021-22/MID/Facundo_Buonanotte.csv not found.
# Looking for Albert_Sambi_Lokonga.csv in merged_data/2021-22/MID/Albert_Sambi_Lokonga.csv
# Stats found for Albert_Sambi_Lokonga.csv: Goals: 0.0, Assists: 0.0, xG: 0.5900000000000001, xA: 0.86, Points/Min: 0.0283436669619132
# Looking for Bruno_Borges_Fernandes.csv in merged_data/2021-22/MID/Bruno_Borges_Fernandes.csv
# File merged_data/2021-22/MID/Bruno_Borges_Fernandes.csv not found.
# File merged_data/2022-23/MID/Yago_de_Santiago_Alonso.csv is missing required columns. Skipping.
# Looking for Mislav_Orsic.csv in merged_data/2021-22/MID/Mislav_Orsic.csv
# File merged_data/2021-22/MID/Mislav_Orsic.csv not found.
# Looking for Leon_Bailey.csv in merged_data/2021-22/MID/Leon_Bailey.csv
# Stats found for Leon_Bailey.csv: Goals: 1.0, Assists: 2.0, xG: 1.5000000000000002, xA: 0.6800000000000002, Points/Min: 0.04933333333333333
# Looking for Cheick_Doucouré.csv in merged_data/2021-22/MID/Cheick_Doucouré.csv
# File merged_data/2021-22/MID/Cheick_Doucouré.csv not found.
# File merged_data/2022-23/MID/Amario_Cozier-Duberry.csv is missing required columns. Skipping.
# Looking for Mateusz_Klich.csv in merged_data/2021-22/MID/Mateusz_Klich.csv
# Stats found for Mateusz_Klich.csv: Goals: 1.0, Assists: 2.0, xG: 2.69, xA: 1.9100000000000001, Points/Min: 0.0294543698696282
# File merged_data/2022-23/MID/Nicolas_Pépé.csv is missing required columns. Skipping.
# Looking for Hamed_Traorè.csv in merged_data/2021-22/MID/Hamed_Traorè.csv
# File merged_data/2021-22/MID/Hamed_Traorè.csv not found.
# Looking for Denis_Zakaria.csv in merged_data/2021-22/MID/Denis_Zakaria.csv
# File merged_data/2021-22/MID/Denis_Zakaria.csv not found.
# Looking for Archie_Gray.csv in merged_data/2021-22/MID/Archie_Gray.csv
# Stats found for Archie_Gray.csv: Goals: 0.0, Assists: 0.0, xG: 0.99, xA: 1.1600000000000001, Points/Min: 0
# File merged_data/2022-23/MID/Will_Smallbone.csv is missing required columns. Skipping.
# Looking for Granit_Xhaka.csv in merged_data/2021-22/MID/Granit_Xhaka.csv
# Stats found for Granit_Xhaka.csv: Goals: 1.0, Assists: 2.0, xG: 1.1, xA: 2.44, Points/Min: 0.02578427159432746
# File merged_data/2022-23/MID/Ben_Knight.csv is missing required columns. Skipping.
# Looking for Jack_Colback.csv in merged_data/2021-22/MID/Jack_Colback.csv
# File merged_data/2021-22/MID/Jack_Colback.csv not found.
# File merged_data/2022-23/MID/Fabio_Henrique_Tavares.csv is missing required columns. Skipping.
# File merged_data/2022-23/MID/Sammy_Braybrooke.csv is missing required columns. Skipping.
# Looking for Jairo_Riedewald.csv in merged_data/2021-22/MID/Jairo_Riedewald.csv
# Looking for Luis_Sinisterra_Lucumí.csv in merged_data/2021-22/MID/Luis_Sinisterra_Lucumí.csv
# File merged_data/2021-22/MID/Luis_Sinisterra_Lucumí.csv not found.
# File merged_data/2022-23/MID/Antony_Matheus_dos_Santos.csv is missing required columns. Skipping.
# ...
# Stats found for Pierre-Emile_Højbjerg.csv: Goals: 4.0, Assists: 5.0, xG: 1.5400000000000003, xA: 3.1999999999999997, Points/Min: 0.03832641328648994
# Looking for Pablo_Sarabia.csv in merged_data/2022-23/MID/Pablo_Sarabia.csv
# Stats found for Pablo_Sarabia.csv: Goals: 1.0, Assists: 0.0, xG: 2.5400000000000005, xA: 0.77, Points/Min: 0.03534031413612566
# Looking for Nicolò_Zaniolo.csv in merged_data/2022-23/MID/Nicolò_Zaniolo.csv
# File merged_data/2022-23/MID/Nicolò_Zaniolo.csv not found.
# Looking for Ibrahim_Sangaré.csv in merged_data/2022-23/MID/Ibrahim_Sangaré.csv
# File merged_data/2022-23/MID/Ibrahim_Sangaré.csv not found.
# Looking for Bobby_Clark.csv in merged_data/2022-23/MID/Bobby_Clark.csv
# Stats found for Bobby_Clark.csv: Goals: 0.0, Assists: 0.0, xG: 0.0, xA: 0.0, Points/Min: 0.14285714285714285
# Looking for John_McGinn.csv in merged_data/2022-23/MID/John_McGinn.csv
# Stats found for John_McGinn.csv: Goals: 1.0, Assists: 3.0, xG: 1.9400000000000004, xA: 3.4200000000000004, Points/Min: 0.033432392273402674
# Looking for Brandon_Aguilera_Zamora.csv in merged_data/2022-23/MID/Brandon_Aguilera_Zamora.csv
# File merged_data/2022-23/MID/Brandon_Aguilera_Zamora.csv not found.
# Looking for Josh_Cullen.csv in merged_data/2022-23/MID/Josh_Cullen.csv
# File merged_data/2022-23/MID/Josh_Cullen.csv not found.
# Looking for Tyrese_Francois.csv in merged_data/2022-23/MID/Tyrese_Francois.csv
# Stats found for Tyrese_Francois.csv: Goals: 0.0, Assists: 0.0, xG: 0.0, xA: 0.0, Points/Min: 1.0
# Looking for Michale_Olakigbe.csv in merged_data/2022-23/MID/Michale_Olakigbe.csv
# File merged_data/2022-23/MID/Michale_Olakigbe.csv not found.
# Looking for James_Garner.csv in merged_data/2022-23/MID/James_Garner.csv
# Stats found for James_Garner.csv: Goals: 0.0, Assists: 1.0, xG: 0.84, xA: 0.44000000000000006, Points/Min: 0.031407035175879394
# Looking for James_McConnell.csv in merged_data/2022-23/MID/James_McConnell.csv
# File merged_data/2022-23/MID/James_McConnell.csv not found.
# Looking for Orel_Mangala.csv in merged_data/2022-23/MID/Orel_Mangala.csv
# Stats found for Orel_Mangala.csv: Goals: 1.0, Assists: 1.0, xG: 0.38, xA: 0.42000000000000004, Points/Min: 0.03240440699935191
# Looking for Zack_Nelson.csv in merged_data/2022-23/MID/Zack_Nelson.csv
# File merged_data/2022-23/MID/Zack_Nelson.csv not found.
# Looking for Demarai_Gray.csv in merged_data/2022-23/MID/Demarai_Gray.csv
# File merged_data/2022-23/MID/Wataru_Endo.csv not found.
# Looking for Jacob_Bruun_Larsen.csv in merged_data/2022-23/MID/Jacob_Bruun_Larsen.csv
# File merged_data/2022-23/MID/Jacob_Bruun_Larsen.csv not found.
# All forward and midfielder CSV files have been processed and rounded to two decimal places.

# %%
#CALCULATING FORM FOR THE DEFENDER FOLDER 
import os
import pandas as pd

# Path to merged_data directory
root_dir = 'merged_data'

# Function to calculate form over last five games (or as many as available)
def calculate_form(series, num_games=5):
    form = []
    for i in range(len(series)):
        if i < num_games:
            form.append(series[:i].mean() if i > 0 else 0)  # Avoid empty slice error
        else:
            form.append(series[i-num_games:i].mean())
    return form

# Function to get stats from last season for defenders
def get_last_season_stats_defender(player_name, last_season_dir):
    last_season_file = os.path.join(last_season_dir, 'DEF', player_name)
    
    print(f"Looking for {player_name} in {last_season_file}")  # Debugging
    
    if os.path.exists(last_season_file):
        last_season_df = pd.read_csv(last_season_file)
        if not last_season_df.empty:
            # Ensure the file has the necessary columns
            required_columns = ['xG', 'xA', 'expected_goals_conceded', 'minutes', 'clean_sheets']
            if all(col in last_season_df.columns for col in required_columns):
                total_xG = last_season_df['xG'].sum()
                total_xA = last_season_df['xA'].sum()
                total_expected_goals_conceded = last_season_df['expected_goals_conceded'].sum()
                
                # Calculate last season clean sheet probability
                clean_sheet_games = last_season_df[(last_season_df['minutes'] > 60) & (last_season_df['clean_sheets'] == True)]
                total_games = last_season_df[last_season_df['minutes'] > 60]
                if not total_games.empty:
                    last_season_clean_sheet_prob = len(clean_sheet_games) / len(total_games)
                else:
                    last_season_clean_sheet_prob = 0
                
                print(f"Stats found for {player_name}: xG: {total_xG}, xA: {total_xA}, Expected Goals Conceded: {total_expected_goals_conceded}, Clean Sheet Probability: {last_season_clean_sheet_prob}")  # Debugging
                
                return total_xG, total_xA, total_expected_goals_conceded, last_season_clean_sheet_prob
            else:
                print(f"Missing required columns in {last_season_file}: {set(required_columns) - set(last_season_df.columns)}")  # Debugging
    else:
        print(f"File {last_season_file} not found.")  # Debugging
    
    return 0, 0, 0, 0

# Function to calculate clean sheet probability for current season
def calculate_clean_sheet_probability(df):
    clean_sheet_games = df[(df['minutes'] > 60) & (df['clean_sheets'] == True)]
    total_games = df[df['minutes'] > 60]
    if not total_games.empty:
        return len(clean_sheet_games) / len(total_games)
    return 0

# Loop through the DEF directories across all seasons
for season in ['2021-22', '2022-23', '2023-24']:
    position = 'DEF'
    position_dir = os.path.join(root_dir, season, position)
    last_season_dir = os.path.join(root_dir, f'{int(season[:4])-1}-{int(season[5:7])-1}')
    
    # Check if position directory exists
    if not os.path.exists(position_dir):
        print(f"Directory {position_dir} does not exist. Skipping.")
        continue

    # Loop through each CSV file in the DEF directory
    for player_file in os.listdir(position_dir):
        player_path = os.path.join(position_dir, player_file)
        
        # Read the CSV file and check for empty or corrupted files
        try:
            df = pd.read_csv(player_path)
        except pd.errors.EmptyDataError:
            print(f"File {player_path} is empty or corrupted. Skipping.")
            continue
        
        # Print missing columns for debugging
        required_columns = ['total_points', 'xG', 'assists', 'minutes', 'clean_sheets']
        missing_columns = [col for col in required_columns if col not in df.columns]
        if missing_columns:
            print(f"File {player_path} is missing columns: {missing_columns}. Skipping.")
            continue
        
        # 1. Create 'form' column if 'total_points' is available
        if 'total_points' in df.columns:
            df['form'] = calculate_form(df['total_points'])
        
        # 2. Create 'xG&A_form' column if 'xG' and 'assists' are available
        if 'xG' in df.columns and 'assists' in df.columns:
            df['xG&A_form'] = calculate_form(df[['xG', 'assists']].sum(axis=1))
        
        # 3. Create 'minutes per game' column if 'minutes' is available
        if 'minutes' in df.columns:
            df['minutes_per_game'] = df['minutes'].cumsum() / (df.index + 1)
        
        # 4. Calculate clean sheet probability if 'minutes' and 'clean_sheet' are available
        if 'minutes' in df.columns and 'clean_sheets' in df.columns:
            df['clean_sheet_probability'] = df['clean_sheets'].expanding().apply(lambda x: calculate_clean_sheet_probability(df[:x.index[-1]+1]), raw=False)
        
        # 5. Get last season stats (only for 2022-23 and 2023-24 seasons)
        if season in ['2022-23', '2023-24']:
            last_season_xG, last_season_xA, last_season_expected_goals_conceded, last_season_clean_sheet_prob = get_last_season_stats_defender(player_file, last_season_dir)
            df['last_season_xG'] = last_season_xG
            df['last_season_xA'] = last_season_xA
            df['last_season_expected_goals_conceded'] = last_season_expected_goals_conceded
            df['last_season_clean_sheet_probability'] = last_season_clean_sheet_prob
        
        # Round all numerical columns to two decimal places
        df = df.round(2)
        
        # Save the updated dataframe back to the CSV file
        df.to_csv(player_path, index=False)

print("All defender CSV files have been processed.")
# Out:
# File merged_data/2021-22/DEF/Samir_Caetano_de_Souza_Santos.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Zach_Awe.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Jarell_Quansah.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Emerson_Palmieri_dos_Santos.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Vontae_Daley-Campbell.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Jonathan_Tomkinson.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Reece_Welch.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Robert_Kenedy_Nunes_do_Nascimento.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Emerson_Aparecido_Leite_de_Souza_Junior.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Jonathan_Castro_Otto.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Francisco_Femenía_Far.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Ed_Turns.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Frederik_Alves.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Lyanco_Evangelista_Silveira_Neves_Vojnovic.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Toti_António_Gomes.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Josh_Feeney.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Dynel_Simeu.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Julian_Jeanvier.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Thierry_Small.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Ajibola_Alese.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Odeluga_Offiah.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Nuno_Varela_Tavares.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Luke_Mbete.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Rúben_Santos_Gato_Alves_Dias.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/José_Diogo_Dalot_Teixeira.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Bobby_Thomas.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Hugo_Bueno.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Alex_Nicolao_Telles.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Marc_Navarro.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Mazeed_Ogungbo.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Björn_Engels.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Tayo_Adaramola.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Thiago_Emiliano_da_Silva.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Lamare_Bogarde.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Yerson_Mosquera_Valdelamar.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Jarosław_Jach.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Frédéric_Guilbert.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Ricardo_Domingos_Barbosa_Pereira.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Kris_Moore.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2021-22/DEF/Joshua_Wilson-Esbrand.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Nathan_Aké.csv in merged_data/2021-22/DEF/Nathan_Aké.csv
# Missing required columns in merged_data/2021-22/DEF/Nathan_Aké.csv: {'expected_goals_conceded'}
# Looking for Tariq_Lamptey.csv in merged_data/2021-22/DEF/Tariq_Lamptey.csv
# Missing required columns in merged_data/2021-22/DEF/Tariq_Lamptey.csv: {'expected_goals_conceded'}
# Looking for Adam_Webster.csv in merged_data/2021-22/DEF/Adam_Webster.csv
# Missing required columns in merged_data/2021-22/DEF/Adam_Webster.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Mohamed_Dräger.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Kalidou_Koulibaly.csv in merged_data/2021-22/DEF/Kalidou_Koulibaly.csv
# File merged_data/2021-22/DEF/Kalidou_Koulibaly.csv not found.
# Looking for Moussa_Niakhaté.csv in merged_data/2021-22/DEF/Moussa_Niakhaté.csv
# File merged_data/2021-22/DEF/Moussa_Niakhaté.csv not found.
# Looking for Nathaniel_Phillips.csv in merged_data/2021-22/DEF/Nathaniel_Phillips.csv
# Missing required columns in merged_data/2021-22/DEF/Nathaniel_Phillips.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Jarrad_Branthwaite.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Joe_Rodon.csv in merged_data/2021-22/DEF/Joe_Rodon.csv
# Missing required columns in merged_data/2021-22/DEF/Joe_Rodon.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Harrison_Ashby.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Issa_Diop.csv in merged_data/2021-22/DEF/Issa_Diop.csv
# Missing required columns in merged_data/2021-22/DEF/Issa_Diop.csv: {'expected_goals_conceded'}
# Looking for Jakub_Kiwior.csv in merged_data/2021-22/DEF/Jakub_Kiwior.csv
# File merged_data/2021-22/DEF/Jakub_Kiwior.csv not found.
# Looking for Clément_Lenglet.csv in merged_data/2021-22/DEF/Clément_Lenglet.csv
# File merged_data/2021-22/DEF/Clément_Lenglet.csv not found.
# File merged_data/2022-23/DEF/Benjamin_White.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Tino_Livramento.csv in merged_data/2021-22/DEF/Tino_Livramento.csv
# Missing required columns in merged_data/2021-22/DEF/Tino_Livramento.csv: {'expected_goals_conceded'}
# Looking for Lisandro_Martínez.csv in merged_data/2021-22/DEF/Lisandro_Martínez.csv
# File merged_data/2021-22/DEF/Lisandro_Martínez.csv not found.
# Looking for Harry_Toffolo.csv in merged_data/2021-22/DEF/Harry_Toffolo.csv
# File merged_data/2021-22/DEF/Harry_Toffolo.csv not found.
# Looking for Michael_Keane.csv in merged_data/2021-22/DEF/Michael_Keane.csv
# Missing required columns in merged_data/2021-22/DEF/Michael_Keane.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Emerson_Palmieri_dos_Santos.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Timothy_Castagne.csv in merged_data/2021-22/DEF/Timothy_Castagne.csv
# Missing required columns in merged_data/2021-22/DEF/Timothy_Castagne.csv: {'expected_goals_conceded'}
# Looking for Joel_Ward.csv in merged_data/2021-22/DEF/Joel_Ward.csv
# Missing required columns in merged_data/2021-22/DEF/Joel_Ward.csv: {'expected_goals_conceded'}
# Looking for Wesley_Fofana.csv in merged_data/2021-22/DEF/Wesley_Fofana.csv
# Missing required columns in merged_data/2021-22/DEF/Wesley_Fofana.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Arthur_Masuaku.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Stuart_Dallas.csv in merged_data/2021-22/DEF/Stuart_Dallas.csv
# File merged_data/2021-22/DEF/Stuart_Dallas.csv not found.
# Looking for Matty_Cash.csv in merged_data/2021-22/DEF/Matty_Cash.csv
# File merged_data/2021-22/DEF/Matty_Cash.csv not found.
# Looking for Lucas_Digne.csv in merged_data/2021-22/DEF/Lucas_Digne.csv
# Missing required columns in merged_data/2021-22/DEF/Lucas_Digne.csv: {'expected_goals_conceded'}
# Looking for Dexter_Lembikisa.csv in merged_data/2021-22/DEF/Dexter_Lembikisa.csv
# File merged_data/2021-22/DEF/Dexter_Lembikisa.csv not found.
# File merged_data/2022-23/DEF/Max_Kinsey-Wellings.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Ibrahima_Konaté.csv in merged_data/2021-22/DEF/Ibrahima_Konaté.csv
# Missing required columns in merged_data/2021-22/DEF/Ibrahima_Konaté.csv: {'expected_goals_conceded'}
# Looking for Sergio_Gómez.csv in merged_data/2021-22/DEF/Sergio_Gómez.csv
# File merged_data/2021-22/DEF/Sergio_Gómez.csv not found.
# Looking for Kurt_Zouma.csv in merged_data/2021-22/DEF/Kurt_Zouma.csv
# Missing required columns in merged_data/2021-22/DEF/Kurt_Zouma.csv: {'expected_goals_conceded'}
# Looking for Matt_Targett.csv in merged_data/2021-22/DEF/Matt_Targett.csv
# Missing required columns in merged_data/2021-22/DEF/Matt_Targett.csv: {'expected_goals_conceded'}
# Looking for Cody_Drameh.csv in merged_data/2021-22/DEF/Cody_Drameh.csv
# Missing required columns in merged_data/2021-22/DEF/Cody_Drameh.csv: {'expected_goals_conceded'}
# Looking for Thilo_Kehrer.csv in merged_data/2021-22/DEF/Thilo_Kehrer.csv
# File merged_data/2021-22/DEF/Thilo_Kehrer.csv not found.
# Looking for Angelo_Ogbonna.csv in merged_data/2021-22/DEF/Angelo_Ogbonna.csv
# Missing required columns in merged_data/2021-22/DEF/Angelo_Ogbonna.csv: {'expected_goals_conceded'}
# Looking for Joel_Matip.csv in merged_data/2021-22/DEF/Joel_Matip.csv
# Missing required columns in merged_data/2021-22/DEF/Joel_Matip.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Sergio_Reguilón.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Sebastian_Revan.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Ethan_Ampadu.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Kofi_Balmer.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Nathan_Ferguson.csv in merged_data/2021-22/DEF/Nathan_Ferguson.csv
# Missing required columns in merged_data/2021-22/DEF/Nathan_Ferguson.csv: {'expected_goals_conceded'}
# Looking for Nayef_Aguerd.csv in merged_data/2021-22/DEF/Nayef_Aguerd.csv
# File merged_data/2021-22/DEF/Nayef_Aguerd.csv not found.
# Looking for Ben_Davies.csv in merged_data/2021-22/DEF/Ben_Davies.csv
# Missing required columns in merged_data/2021-22/DEF/Ben_Davies.csv: {'expected_goals_conceded'}
# Looking for Conor_Coady.csv in merged_data/2021-22/DEF/Conor_Coady.csv
# Missing required columns in merged_data/2021-22/DEF/Conor_Coady.csv: {'expected_goals_conceded'}
# Looking for Luke_Shaw.csv in merged_data/2021-22/DEF/Luke_Shaw.csv
# Missing required columns in merged_data/2021-22/DEF/Luke_Shaw.csv: {'expected_goals_conceded'}
# Looking for Mathias_Jorgensen.csv in merged_data/2021-22/DEF/Mathias_Jorgensen.csv
# Missing required columns in merged_data/2021-22/DEF/Mathias_Jorgensen.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Reece_Welch.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Diogo_Dalot_Teixeira.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Romain_Perraud.csv in merged_data/2021-22/DEF/Romain_Perraud.csv
# Missing required columns in merged_data/2021-22/DEF/Romain_Perraud.csv: {'expected_goals_conceded'}
# Looking for Tyrone_Mings.csv in merged_data/2021-22/DEF/Tyrone_Mings.csv
# Missing required columns in merged_data/2021-22/DEF/Tyrone_Mings.csv: {'expected_goals_conceded'}
# Looking for Duje_Caleta-Car.csv in merged_data/2021-22/DEF/Duje_Caleta-Car.csv
# File merged_data/2021-22/DEF/Duje_Caleta-Car.csv not found.
# Looking for Mason_Holgate.csv in merged_data/2021-22/DEF/Mason_Holgate.csv
# Missing required columns in merged_data/2021-22/DEF/Mason_Holgate.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Rúben_Gato_Alves_Dias.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Pervis_Estupiñán.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Felipe_Augusto_de_Almeida_Monteiro.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Alfie_Gilchrist.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Owen_Bevan.csv in merged_data/2021-22/DEF/Owen_Bevan.csv
# File merged_data/2021-22/DEF/Owen_Bevan.csv not found.
# Looking for Tyrick_Mitchell.csv in merged_data/2021-22/DEF/Tyrick_Mitchell.csv
# Missing required columns in merged_data/2021-22/DEF/Tyrick_Mitchell.csv: {'expected_goals_conceded'}
# Looking for Haydon_Roberts.csv in merged_data/2021-22/DEF/Haydon_Roberts.csv
# Missing required columns in merged_data/2021-22/DEF/Haydon_Roberts.csv: {'expected_goals_conceded'}
# Looking for Scott_McKenna.csv in merged_data/2021-22/DEF/Scott_McKenna.csv
# File merged_data/2021-22/DEF/Scott_McKenna.csv not found.
# Looking for Kieran_Trippier.csv in merged_data/2021-22/DEF/Kieran_Trippier.csv
# Looking for Jack_Stephens.csv in merged_data/2021-22/DEF/Jack_Stephens.csv
# Missing required columns in merged_data/2021-22/DEF/Jack_Stephens.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Gabriel_dos_Santos_Magalhães.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Richie_Laryea.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Josh_Wilson-Esbrand.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Liam_Cooper.csv in merged_data/2021-22/DEF/Liam_Cooper.csv
# Missing required columns in merged_data/2021-22/DEF/Liam_Cooper.csv: {'expected_goals_conceded'}
# Looking for Jan_Paul_van_Hecke.csv in merged_data/2021-22/DEF/Jan_Paul_van_Hecke.csv
# File merged_data/2021-22/DEF/Jan_Paul_van_Hecke.csv not found.
# Looking for Kyle_Walker.csv in merged_data/2021-22/DEF/Kyle_Walker.csv
# Missing required columns in merged_data/2021-22/DEF/Kyle_Walker.csv: {'expected_goals_conceded'}
# Looking for Marcos_Senesi.csv in merged_data/2021-22/DEF/Marcos_Senesi.csv
# File merged_data/2021-22/DEF/Marcos_Senesi.csv not found.
# Looking for Jonny_Evans.csv in merged_data/2021-22/DEF/Jonny_Evans.csv
# Missing required columns in merged_data/2021-22/DEF/Jonny_Evans.csv: {'expected_goals_conceded'}
# Looking for Matt_Ritchie.csv in merged_data/2021-22/DEF/Matt_Ritchie.csv
# Missing required columns in merged_data/2021-22/DEF/Matt_Ritchie.csv: {'expected_goals_conceded'}
# Looking for Ben_Chilwell.csv in merged_data/2021-22/DEF/Ben_Chilwell.csv
# File merged_data/2021-22/DEF/Ben_Chilwell.csv not found.
# Looking for Virgil_van_Dijk.csv in merged_data/2021-22/DEF/Virgil_van_Dijk.csv
# Missing required columns in merged_data/2021-22/DEF/Virgil_van_Dijk.csv: {'expected_goals_conceded'}
# Looking for Pascal_Struijk.csv in merged_data/2021-22/DEF/Pascal_Struijk.csv
# Missing required columns in merged_data/2021-22/DEF/Pascal_Struijk.csv: {'expected_goals_conceded'}
# Looking for Aaron_Wan-Bissaka.csv in merged_data/2021-22/DEF/Aaron_Wan-Bissaka.csv
# Missing required columns in merged_data/2021-22/DEF/Aaron_Wan-Bissaka.csv: {'expected_goals_conceded'}
# Looking for Nathan_Patterson.csv in merged_data/2021-22/DEF/Nathan_Patterson.csv
# Missing required columns in merged_data/2021-22/DEF/Nathan_Patterson.csv: {'expected_goals_conceded'}
# Looking for Fabian_Schär.csv in merged_data/2021-22/DEF/Fabian_Schär.csv
# Missing required columns in merged_data/2021-22/DEF/Fabian_Schär.csv: {'expected_goals_conceded'}
# Looking for Jack_Stacey.csv in merged_data/2021-22/DEF/Jack_Stacey.csv
# File merged_data/2021-22/DEF/Jack_Stacey.csv not found.
# Looking for Steve_Cook.csv in merged_data/2021-22/DEF/Steve_Cook.csv
# File merged_data/2021-22/DEF/Steve_Cook.csv not found.
# File merged_data/2022-23/DEF/Eric_Bailly.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Wout_Faes.csv in merged_data/2021-22/DEF/Wout_Faes.csv
# File merged_data/2021-22/DEF/Wout_Faes.csv not found.
# Looking for Lewis_Dunk.csv in merged_data/2021-22/DEF/Lewis_Dunk.csv
# Missing required columns in merged_data/2021-22/DEF/Lewis_Dunk.csv: {'expected_goals_conceded'}
# Looking for Kristoffer_Ajer.csv in merged_data/2021-22/DEF/Kristoffer_Ajer.csv
# Missing required columns in merged_data/2021-22/DEF/Kristoffer_Ajer.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Junior_Firpo_Adames.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Chris_Mepham.csv in merged_data/2021-22/DEF/Chris_Mepham.csv
# File merged_data/2021-22/DEF/Chris_Mepham.csv not found.
# File merged_data/2022-23/DEF/Ed_Turns.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Niels_Nkounkou.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Ryan_Sessegnon.csv in merged_data/2021-22/DEF/Ryan_Sessegnon.csv
# Missing required columns in merged_data/2021-22/DEF/Ryan_Sessegnon.csv: {'expected_goals_conceded'}
# Looking for Phil_Jones.csv in merged_data/2021-22/DEF/Phil_Jones.csv
# Missing required columns in merged_data/2021-22/DEF/Phil_Jones.csv: {'expected_goals_conceded'}
# Looking for Rasmus_Kristensen.csv in merged_data/2021-22/DEF/Rasmus_Kristensen.csv
# File merged_data/2021-22/DEF/Rasmus_Kristensen.csv not found.
# Looking for Levi_Colwill.csv in merged_data/2021-22/DEF/Levi_Colwill.csv
# File merged_data/2021-22/DEF/Levi_Colwill.csv not found.
# Looking for Rico_Lewis.csv in merged_data/2021-22/DEF/Rico_Lewis.csv
# File merged_data/2021-22/DEF/Rico_Lewis.csv not found.
# File merged_data/2022-23/DEF/Lyanco_Silveira_Neves_Vojnovic.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for João_Cancelo.csv in merged_data/2021-22/DEF/João_Cancelo.csv
# File merged_data/2021-22/DEF/João_Cancelo.csv not found.
# File merged_data/2022-23/DEF/Toti_António_Gomes.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Pedro_Porro.csv in merged_data/2021-22/DEF/Pedro_Porro.csv
# File merged_data/2021-22/DEF/Pedro_Porro.csv not found.
# Looking for Luke_Thomas.csv in merged_data/2021-22/DEF/Luke_Thomas.csv
# Missing required columns in merged_data/2021-22/DEF/Luke_Thomas.csv: {'expected_goals_conceded'}
# Looking for Lloyd_Kelly.csv in merged_data/2021-22/DEF/Lloyd_Kelly.csv
# File merged_data/2021-22/DEF/Lloyd_Kelly.csv not found.
# Looking for Ricardo_Barbosa_Pereira.csv in merged_data/2021-22/DEF/Ricardo_Barbosa_Pereira.csv
# File merged_data/2021-22/DEF/Ricardo_Barbosa_Pereira.csv not found.
# Looking for Harry_Souttar.csv in merged_data/2021-22/DEF/Harry_Souttar.csv
# File merged_data/2021-22/DEF/Harry_Souttar.csv not found.
# Looking for Tosin_Adarabioyo.csv in merged_data/2021-22/DEF/Tosin_Adarabioyo.csv
# File merged_data/2021-22/DEF/Tosin_Adarabioyo.csv not found.
# Looking for James_Tomkins.csv in merged_data/2021-22/DEF/James_Tomkins.csv
# Missing required columns in merged_data/2021-22/DEF/James_Tomkins.csv: {'expected_goals_conceded'}
# Looking for Sven_Botman.csv in merged_data/2021-22/DEF/Sven_Botman.csv
# File merged_data/2021-22/DEF/Sven_Botman.csv not found.
# File merged_data/2022-23/DEF/Luke_Mbete-Tabu.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Aaron_Cresswell.csv in merged_data/2021-22/DEF/Aaron_Cresswell.csv
# Missing required columns in merged_data/2021-22/DEF/Aaron_Cresswell.csv: {'expected_goals_conceded'}
# Looking for Mads_Roerslev_Rasmussen.csv in merged_data/2021-22/DEF/Mads_Roerslev_Rasmussen.csv
# Missing required columns in merged_data/2021-22/DEF/Mads_Roerslev_Rasmussen.csv: {'expected_goals_conceded'}
# Looking for Sergi_Canós_Tenés.csv in merged_data/2021-22/DEF/Sergi_Canós_Tenés.csv
# File merged_data/2021-22/DEF/Sergi_Canós_Tenés.csv not found.
# Looking for Layvin_Kurzawa.csv in merged_data/2021-22/DEF/Layvin_Kurzawa.csv
# File merged_data/2021-22/DEF/Layvin_Kurzawa.csv not found.
# Looking for Mohammed_Salisu.csv in merged_data/2021-22/DEF/Mohammed_Salisu.csv
# Missing required columns in merged_data/2021-22/DEF/Mohammed_Salisu.csv: {'expected_goals_conceded'}
# Looking for Robin_Koch.csv in merged_data/2021-22/DEF/Robin_Koch.csv
# Missing required columns in merged_data/2021-22/DEF/Robin_Koch.csv: {'expected_goals_conceded'}
# Looking for James_Bree.csv in merged_data/2021-22/DEF/James_Bree.csv
# File merged_data/2021-22/DEF/James_Bree.csv not found.
# Looking for Joseph_Gomez.csv in merged_data/2021-22/DEF/Joseph_Gomez.csv
# Missing required columns in merged_data/2021-22/DEF/Joseph_Gomez.csv: {'expected_goals_conceded'}
# Looking for Joachim_Andersen.csv in merged_data/2021-22/DEF/Joachim_Andersen.csv
# Missing required columns in merged_data/2021-22/DEF/Joachim_Andersen.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Pablo_Marí_Villar.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Kaelan_Casey.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Daniel_Amartey.csv in merged_data/2021-22/DEF/Daniel_Amartey.csv
# Missing required columns in merged_data/2021-22/DEF/Daniel_Amartey.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Loïc_Mbe_Soh.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Takehiro_Tomiyasu.csv in merged_data/2021-22/DEF/Takehiro_Tomiyasu.csv
# Missing required columns in merged_data/2021-22/DEF/Takehiro_Tomiyasu.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Reuell_Walters.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Dominic_Thompson.csv in merged_data/2021-22/DEF/Dominic_Thompson.csv
# Missing required columns in merged_data/2021-22/DEF/Dominic_Thompson.csv: {'expected_goals_conceded'}
# Looking for James_Tarkowski.csv in merged_data/2021-22/DEF/James_Tarkowski.csv
# Missing required columns in merged_data/2021-22/DEF/James_Tarkowski.csv: {'expected_goals_conceded'}
# Looking for Odeluga_Offiah.csv in merged_data/2021-22/DEF/Odeluga_Offiah.csv
# Missing required columns in merged_data/2021-22/DEF/Odeluga_Offiah.csv: {'xG', 'xA', 'expected_goals_conceded'}
# Looking for Matt_Clarke.csv in merged_data/2021-22/DEF/Matt_Clarke.csv
# File merged_data/2021-22/DEF/Matt_Clarke.csv not found.
# Looking for Reece_James.csv in merged_data/2021-22/DEF/Reece_James.csv
# Missing required columns in merged_data/2021-22/DEF/Reece_James.csv: {'expected_goals_conceded'}
# Looking for Pontus_Jansson.csv in merged_data/2021-22/DEF/Pontus_Jansson.csv
# Missing required columns in merged_data/2021-22/DEF/Pontus_Jansson.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Nuno_Varela_Tavares.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Yerry_Mina.csv in merged_data/2021-22/DEF/Yerry_Mina.csv
# Missing required columns in merged_data/2021-22/DEF/Yerry_Mina.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Marc_Jurado_Gomez.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Rhys_Bennett.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Sepp_van_den_Berg.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Chris_Richards.csv in merged_data/2021-22/DEF/Chris_Richards.csv
# File merged_data/2021-22/DEF/Chris_Richards.csv not found.
# Looking for Willy_Boly.csv in merged_data/2021-22/DEF/Willy_Boly.csv
# Missing required columns in merged_data/2021-22/DEF/Willy_Boly.csv: {'expected_goals_conceded'}
# Looking for Davinson_Sánchez.csv in merged_data/2021-22/DEF/Davinson_Sánchez.csv
# Missing required columns in merged_data/2021-22/DEF/Davinson_Sánchez.csv: {'expected_goals_conceded'}
# Looking for Seamus_Coleman.csv in merged_data/2021-22/DEF/Seamus_Coleman.csv
# Missing required columns in merged_data/2021-22/DEF/Seamus_Coleman.csv: {'expected_goals_conceded'}
# Looking for Ben_Greenwood.csv in merged_data/2021-22/DEF/Ben_Greenwood.csv
# File merged_data/2021-22/DEF/Ben_Greenwood.csv not found.
# Looking for Diego_Llorente.csv in merged_data/2021-22/DEF/Diego_Llorente.csv
# Missing required columns in merged_data/2021-22/DEF/Diego_Llorente.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Lino_Sousa.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Nathaniel_Clyne.csv in merged_data/2021-22/DEF/Nathaniel_Clyne.csv
# Missing required columns in merged_data/2021-22/DEF/Nathaniel_Clyne.csv: {'expected_goals_conceded'}
# Looking for Manuel_Akanji.csv in merged_data/2021-22/DEF/Manuel_Akanji.csv
# Missing required columns in merged_data/2021-22/DEF/Brandon_Williams.csv: {'expected_goals_conceded'}
# Looking for Japhet_Tanganga.csv in merged_data/2021-22/DEF/Japhet_Tanganga.csv
# Missing required columns in merged_data/2021-22/DEF/Japhet_Tanganga.csv: {'expected_goals_conceded'}
# Looking for Illia_Zabarnyi.csv in merged_data/2021-22/DEF/Illia_Zabarnyi.csv
# File merged_data/2021-22/DEF/Illia_Zabarnyi.csv not found.
# Looking for Shane_Duffy.csv in merged_data/2021-22/DEF/Shane_Duffy.csv
# Missing required columns in merged_data/2021-22/DEF/Shane_Duffy.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Renan_Augusto_Lodi_dos_Santos.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Tim_Ream.csv in merged_data/2021-22/DEF/Tim_Ream.csv
# File merged_data/2021-22/DEF/Tim_Ream.csv not found.
# Looking for Tyrell_Malacia.csv in merged_data/2021-22/DEF/Tyrell_Malacia.csv
# File merged_data/2021-22/DEF/Tyrell_Malacia.csv not found.
# Looking for Juan_Larios_López.csv in merged_data/2021-22/DEF/Juan_Larios_López.csv
# File merged_data/2021-22/DEF/Juan_Larios_López.csv not found.
# Looking for Maximilian_Wöber.csv in merged_data/2021-22/DEF/Maximilian_Wöber.csv
# File merged_data/2021-22/DEF/Maximilian_Wöber.csv not found.
# File merged_data/2022-23/DEF/Alex_Telles.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Vladimir_Coufal.csv in merged_data/2021-22/DEF/Vladimir_Coufal.csv
# Missing required columns in merged_data/2021-22/DEF/Vladimir_Coufal.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Alexandre_Moreno_Lopera.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Max_Kilman.csv in merged_data/2021-22/DEF/Max_Kilman.csv
# Missing required columns in merged_data/2021-22/DEF/Max_Kilman.csv: {'expected_goals_conceded'}
# Looking for Trevoh_Chalobah.csv in merged_data/2021-22/DEF/Trevoh_Chalobah.csv
# Missing required columns in merged_data/2021-22/DEF/Trevoh_Chalobah.csv: {'expected_goals_conceded'}
# Looking for Rico_Henry.csv in merged_data/2021-22/DEF/Rico_Henry.csv
# Missing required columns in merged_data/2021-22/DEF/Rico_Henry.csv: {'expected_goals_conceded'}
# Looking for Giulian_Biancone.csv in merged_data/2021-22/DEF/Giulian_Biancone.csv
# File merged_data/2021-22/DEF/Giulian_Biancone.csv not found.
# Looking for Rhys_Williams.csv in merged_data/2021-22/DEF/Rhys_Williams.csv
# Missing required columns in merged_data/2021-22/DEF/Rhys_Williams.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Jannik_Vestergaard.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Ben_Johnson.csv in merged_data/2021-22/DEF/Ben_Johnson.csv
# Missing required columns in merged_data/2021-22/DEF/Ben_Johnson.csv: {'expected_goals_conceded'}
# Looking for Matt_Doherty.csv in merged_data/2021-22/DEF/Matt_Doherty.csv
# Missing required columns in merged_data/2021-22/DEF/Matt_Doherty.csv: {'expected_goals_conceded'}
# Looking for Kenny_Tete.csv in merged_data/2021-22/DEF/Kenny_Tete.csv
# File merged_data/2021-22/DEF/Kenny_Tete.csv not found.
# File merged_data/2022-23/DEF/Emerson_Leite_de_Souza_Junior.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Kyle_John.csv in merged_data/2021-22/DEF/Kyle_John.csv
# File merged_data/2021-22/DEF/Kyle_John.csv not found.
# File merged_data/2022-23/DEF/James_Furlong.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Loïc_Badé.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Stefan_Parkes.csv in merged_data/2021-22/DEF/Stefan_Parkes.csv
# File merged_data/2021-22/DEF/Stefan_Parkes.csv not found.
# Looking for Neco_Williams.csv in merged_data/2021-22/DEF/Neco_Williams.csv
# Missing required columns in merged_data/2021-22/DEF/Neco_Williams.csv: {'expected_goals_conceded'}
# Looking for Ben_Mee.csv in merged_data/2021-22/DEF/Ben_Mee.csv
# Missing required columns in merged_data/2021-22/DEF/Ben_Mee.csv: {'expected_goals_conceded'}
# Looking for Çaglar_Söyüncü.csv in merged_data/2021-22/DEF/Çaglar_Söyüncü.csv
# Missing required columns in merged_data/2021-22/DEF/Çaglar_Söyüncü.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Jonathan_Panzo.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Fin_Stevens.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Aaron_Hickey.csv in merged_data/2021-22/DEF/Aaron_Hickey.csv
# File merged_data/2021-22/DEF/Aaron_Hickey.csv not found.
# Looking for Matías_Viña.csv in merged_data/2021-22/DEF/Matías_Viña.csv
# File merged_data/2021-22/DEF/Matías_Viña.csv not found.
# Looking for Federico_Fernández.csv in merged_data/2021-22/DEF/Federico_Fernández.csv
# Missing required columns in merged_data/2021-22/DEF/Federico_Fernández.csv: {'expected_goals_conceded'}
# Looking for Antonee_Robinson.csv in merged_data/2021-22/DEF/Antonee_Robinson.csv
# File merged_data/2021-22/DEF/Antonee_Robinson.csv not found.
# Looking for Javier_Manquillo_Gaitán.csv in merged_data/2021-22/DEF/Javier_Manquillo_Gaitán.csv
# File merged_data/2021-22/DEF/Javier_Manquillo_Gaitán.csv not found.
# File merged_data/2022-23/DEF/Diogo_Pinheiro_Monteiro.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Joe_Wormleighton.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Leo_Fuhr_Hjelde.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Calum_Chambers.csv in merged_data/2021-22/DEF/Calum_Chambers.csv
# Missing required columns in merged_data/2021-22/DEF/Calum_Chambers.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Sil_Swinkels.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Vitalii_Mykolenko.csv in merged_data/2021-22/DEF/Vitalii_Mykolenko.csv
# Missing required columns in merged_data/2021-22/DEF/Vitalii_Mykolenko.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Paul_Dummett.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Lewis_Brunt.csv in merged_data/2021-22/DEF/Lewis_Brunt.csv
# File merged_data/2021-22/DEF/Lewis_Brunt.csv not found.
# Looking for Tristan_Crama.csv in merged_data/2021-22/DEF/Tristan_Crama.csv
# File merged_data/2021-22/DEF/Tristan_Crama.csv not found.
# Looking for Jamal_Lewis.csv in merged_data/2021-22/DEF/Jamal_Lewis.csv
# Missing required columns in merged_data/2021-22/DEF/Jamal_Lewis.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Malang_Sarr.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Charlie_Robinson.csv in merged_data/2021-22/DEF/Charlie_Robinson.csv
# File merged_data/2021-22/DEF/Charlie_Robinson.csv not found.
# Looking for William_Saliba.csv in merged_data/2021-22/DEF/William_Saliba.csv
# Missing required columns in merged_data/2021-22/DEF/William_Saliba.csv: {'expected_goals_conceded'}
# Looking for Ezri_Konsa_Ngoyo.csv in merged_data/2021-22/DEF/Ezri_Konsa_Ngoyo.csv
# Missing required columns in merged_data/2021-22/DEF/Ezri_Konsa_Ngoyo.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Tayo_Adaramola.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Kyle_Walker-Peters.csv in merged_data/2021-22/DEF/Kyle_Walker-Peters.csv
# Missing required columns in merged_data/2021-22/DEF/Kyle_Walker-Peters.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Kaine_Kesler_Hayden.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Ivan_Perišić.csv in merged_data/2021-22/DEF/Ivan_Perišić.csv
# File merged_data/2021-22/DEF/Ivan_Perišić.csv not found.
# File merged_data/2022-23/DEF/Jeremiah_Chilokoa-Mullen.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Kevin_Mbabu.csv in merged_data/2021-22/DEF/Kevin_Mbabu.csv
# File merged_data/2021-22/DEF/Kevin_Mbabu.csv not found.
# Looking for Benoît_Badiashile.csv in merged_data/2021-22/DEF/Benoît_Badiashile.csv
# File merged_data/2021-22/DEF/Benoît_Badiashile.csv not found.
# File merged_data/2022-23/DEF/Thiago_Emiliano_da_Silva.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Nathan_Collins.csv in merged_data/2021-22/DEF/Nathan_Collins.csv
# Missing required columns in merged_data/2021-22/DEF/Nathan_Collins.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Terence_Kongolo.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Kieran_Tierney.csv in merged_data/2021-22/DEF/Kieran_Tierney.csv
# Missing required columns in merged_data/2021-22/DEF/Kieran_Tierney.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Calvin_Ramsay.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for César_Azpilicueta.csv in merged_data/2021-22/DEF/César_Azpilicueta.csv
# Missing required columns in merged_data/2021-22/DEF/César_Azpilicueta.csv: {'expected_goals_conceded'}
# Looking for Victor_Kristiansen.csv in merged_data/2021-22/DEF/Victor_Kristiansen.csv
# File merged_data/2021-22/DEF/Victor_Kristiansen.csv not found.
# Looking for Yan_Valery.csv in merged_data/2021-22/DEF/Yan_Valery.csv
# Missing required columns in merged_data/2021-22/DEF/Yan_Valery.csv: {'expected_goals_conceded'}
# Looking for Diego_Carlos_Santos_Silva.csv in merged_data/2021-22/DEF/Diego_Carlos_Santos_Silva.csv
# File merged_data/2021-22/DEF/Diego_Carlos_Santos_Silva.csv not found.
# File merged_data/2022-23/DEF/Lamare_Bogarde.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Victor_Lindelöf.csv in merged_data/2021-22/DEF/Victor_Lindelöf.csv
# Missing required columns in merged_data/2021-22/DEF/Victor_Lindelöf.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Yerson_Mosquera_Valdelamar.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Djed_Spence.csv in merged_data/2021-22/DEF/Djed_Spence.csv
# File merged_data/2021-22/DEF/Djed_Spence.csv not found.
# Looking for Joe_Worrall.csv in merged_data/2021-22/DEF/Joe_Worrall.csv
# File merged_data/2021-22/DEF/Joe_Worrall.csv not found.
# File merged_data/2022-23/DEF/Rúben_Nascimento_Vinagre.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Nélson_Cabral_Semedo.csv in merged_data/2021-22/DEF/Nélson_Cabral_Semedo.csv
# Missing required columns in merged_data/2021-22/DEF/Nélson_Cabral_Semedo.csv: {'expected_goals_conceded'}
# Looking for Marc_Guéhi.csv in merged_data/2021-22/DEF/Marc_Guéhi.csv
# Missing required columns in merged_data/2021-22/DEF/Marc_Guéhi.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Frédéric_Guilbert.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Eric_Dier.csv in merged_data/2021-22/DEF/Eric_Dier.csv
# Missing required columns in merged_data/2021-22/DEF/Eric_Dier.csv: {'expected_goals_conceded'}
# Looking for Raphaël_Varane.csv in merged_data/2021-22/DEF/Raphaël_Varane.csv
# Missing required columns in merged_data/2021-22/DEF/Raphaël_Varane.csv: {'expected_goals_conceded'}
# File merged_data/2022-23/DEF/Kortney_Hause.csv is missing columns: ['xG', 'assists']. Skipping.
# File merged_data/2022-23/DEF/Charlie_Goode.csv is missing columns: ['xG', 'assists']. Skipping.
# Looking for Harry_Maguire.csv in merged_data/2021-22/DEF/Harry_Maguire.csv
# Missing required columns in merged_data/2021-22/DEF/Harry_Maguire.csv: {'expected_goals_conceded'}
# Looking for James_Justin.csv in merged_data/2021-22/DEF/James_Justin.csv
# Missing required columns in merged_data/2021-22/DEF/James_Justin.csv: {'expected_goals_conceded'}
# Looking for Luke_Ayling.csv in merged_data/2021-22/DEF/Luke_Ayling.csv
# Stats found for Matty_Cash.csv: xG: 0.17, xA: 0.46, Expected Goals Conceded: 12.58, Clean Sheet Probability: 0.21052631578947367
# Looking for Lucas_Digne.csv in merged_data/2022-23/DEF/Lucas_Digne.csv
# Stats found for Lucas_Digne.csv: xG: 0.5, xA: 1.5600000000000003, Expected Goals Conceded: 14.120000000000001, Clean Sheet Probability: 0.15384615384615385
# Looking for Ibrahima_Konaté.csv in merged_data/2022-23/DEF/Ibrahima_Konaté.csv
# Stats found for Ibrahima_Konaté.csv: xG: 1.56, xA: 0.27, Expected Goals Conceded: 21.92, Clean Sheet Probability: 0.4117647058823529
# Looking for Sergio_Gómez.csv in merged_data/2022-23/DEF/Sergio_Gómez.csv
# Stats found for Sergio_Gómez.csv: xG: 0.32, xA: 0.44000000000000006, Expected Goals Conceded: 3.9200000000000004, Clean Sheet Probability: 0.5
# Looking for Kurt_Zouma.csv in merged_data/2022-23/DEF/Kurt_Zouma.csv
# Stats found for Kurt_Zouma.csv: xG: 2.13, xA: 0.06, Expected Goals Conceded: 14.41, Clean Sheet Probability: 0.3333333333333333
# Looking for Matt_Targett.csv in merged_data/2022-23/DEF/Matt_Targett.csv
# Stats found for Matt_Targett.csv: xG: 0.03, xA: 0.4099999999999999, Expected Goals Conceded: 2.42, Clean Sheet Probability: 0.5
# Looking for Thilo_Kehrer.csv in merged_data/2022-23/DEF/Thilo_Kehrer.csv
# Stats found for Thilo_Kehrer.csv: xG: 0.65, xA: 0.7000000000000001, Expected Goals Conceded: 21.18, Clean Sheet Probability: 0.20833333333333334
# Looking for Angelo_Ogbonna.csv in merged_data/2022-23/DEF/Angelo_Ogbonna.csv
# Stats found for Angelo_Ogbonna.csv: xG: 0.21000000000000002, xA: 0.49, Expected Goals Conceded: 20.08, Clean Sheet Probability: 0.2857142857142857
# Looking for Joel_Matip.csv in merged_data/2022-23/DEF/Joel_Matip.csv
# ...
# File merged_data/2022-23/DEF/Max_Lowe.csv not found.
# Looking for Trent_Alexander-Arnold.csv in merged_data/2022-23/DEF/Trent_Alexander-Arnold.csv
# Stats found for Trent_Alexander-Arnold.csv: xG: 1.8900000000000003, xA: 13.23, Expected Goals Conceded: 28.98, Clean Sheet Probability: 0.3125
# Looking for Craig_Dawson.csv in merged_data/2022-23/DEF/Craig_Dawson.csv
# Stats found for Craig_Dawson.csv: xG: 1.5100000000000002, xA: 0.11, Expected Goals Conceded: 32.129999999999995, Clean Sheet Probability: 0.30434782608695654
# Looking for James_Hill.csv in merged_data/2022-23/DEF/James_Hill.csv
# Stats found for James_Hill.csv: xG: 0.1, xA: 0.56, Expected Goals Conceded: 0.0, Clean Sheet Probability: 0
# Looking for Ashley_Young.csv in merged_data/2022-23/DEF/Ashley_Young.csv
# Stats found for Ashley_Young.csv: xG: 0.39, xA: 0.76, Expected Goals Conceded: 21.44, Clean Sheet Probability: 0.4090909090909091
# Looking for Emil_Krafth.csv in merged_data/2022-23/DEF/Emil_Krafth.csv
# Stats found for Emil_Krafth.csv: xG: 0.0, xA: 0.0, Expected Goals Conceded: 0.0, Clean Sheet Probability: 0
# Stats found for Victor_Lindelöf.csv: xG: 0.24, xA: 0.08, Expected Goals Conceded: 16.43, Clean Sheet Probability: 0.42857142857142855
# Looking for Sam_Curtis.csv in merged_data/2022-23/DEF/Sam_Curtis.csv
# File merged_data/2022-23/DEF/Sam_Curtis.csv not found.
# Looking for Pau_Torres.csv in merged_data/2022-23/DEF/Pau_Torres.csv
# File merged_data/2022-23/DEF/Pau_Torres.csv not found.
# Looking for Djed_Spence.csv in merged_data/2022-23/DEF/Djed_Spence.csv
# Stats found for Djed_Spence.csv: xG: 0.2, xA: 0.1, Expected Goals Conceded: 0.18, Clean Sheet Probability: 0
# Looking for Joe_Worrall.csv in merged_data/2022-23/DEF/Joe_Worrall.csv
# Stats found for Joe_Worrall.csv: xG: 0.92, xA: 0.56, Expected Goals Conceded: 30.880000000000003, Clean Sheet Probability: 0.21739130434782608
# Looking for Connor_Roberts.csv in merged_data/2022-23/DEF/Connor_Roberts.csv
# File merged_data/2022-23/DEF/Connor_Roberts.csv not found.
# Looking for Nélson_Cabral_Semedo.csv in merged_data/2022-23/DEF/Nélson_Cabral_Semedo.csv
# Stats found for Nélson_Cabral_Semedo.csv: xG: 0.78, xA: 0.6500000000000001, Expected Goals Conceded: 38.01, Clean Sheet Probability: 0.2962962962962963
# Looking for Marc_Guéhi.csv in merged_data/2022-23/DEF/Marc_Guéhi.csv
# Stats found for Marc_Guéhi.csv: xG: 1.6700000000000004, xA: 0.6499999999999999, Expected Goals Conceded: 28.760000000000005, Clean Sheet Probability: 0.24324324324324326
# Looking for Yasser_Larouci.csv in merged_data/2022-23/DEF/Yasser_Larouci.csv
# File merged_data/2022-23/DEF/Yasser_Larouci.csv not found.
# Looking for Eric_Dier.csv in merged_data/2022-23/DEF/Eric_Dier.csv
# Stats found for Eric_Dier.csv: xG: 1.47, xA: 1.6199999999999999, Expected Goals Conceded: 28.21, Clean Sheet Probability: 0.2903225806451613
# Looking for Raphaël_Varane.csv in merged_data/2022-23/DEF/Raphaël_Varane.csv
# Stats found for Raphaël_Varane.csv: xG: 0.91, xA: 0.14, Expected Goals Conceded: 18.29, Clean Sheet Probability: 0.5
# Looking for Charlie_Goode.csv in merged_data/2022-23/DEF/Charlie_Goode.csv
# Missing required columns in merged_data/2022-23/DEF/Charlie_Goode.csv: {'xG', 'xA'}
# Looking for Micky_van_de_Ven.csv in merged_data/2022-23/DEF/Micky_van_de_Ven.csv
# File merged_data/2022-23/DEF/Micky_van_de_Ven.csv not found.
# Looking for Harry_Maguire.csv in merged_data/2022-23/DEF/Harry_Maguire.csv
# Stats found for Harry_Maguire.csv: xG: 0.15000000000000002, xA: 0.38, Expected Goals Conceded: 6.41, Clean Sheet Probability: 0.625
# Looking for Konstantinos_Mavropanos.csv in merged_data/2022-23/DEF/Konstantinos_Mavropanos.csv
# File merged_data/2022-23/DEF/Konstantinos_Mavropanos.csv not found.
# Looking for Max_Aarons.csv in merged_data/2022-23/DEF/Max_Aarons.csv
# File merged_data/2022-23/DEF/Max_Aarons.csv not found.
# Looking for Christian_Chigozie.csv in merged_data/2022-23/DEF/Christian_Chigozie.csv
# File merged_data/2022-23/DEF/Christian_Chigozie.csv not found.
# Looking for Ryan_Fredericks.csv in merged_data/2022-23/DEF/Ryan_Fredericks.csv
# Stats found for Ryan_Fredericks.csv: xG: 0.0, xA: 0.1, Expected Goals Conceded: 1.48, Clean Sheet Probability: 0.0
# Looking for Andrew_Robertson.csv in merged_data/2022-23/DEF/Andrew_Robertson.csv
# Stats found for Andrew_Robertson.csv: xG: 1.0900000000000003, xA: 6.8100000000000005, Expected Goals Conceded: 24.939999999999998, Clean Sheet Probability: 0.3103448275862069
# Looking for Daiki_Hashioka.csv in merged_data/2022-23/DEF/Daiki_Hashioka.csv
# File merged_data/2022-23/DEF/Daiki_Hashioka.csv not found.
# Looking for Serge_Aurier.csv in merged_data/2022-23/DEF/Serge_Aurier.csv
# Stats found for Serge_Aurier.csv: xG: 0.66, xA: 0.8099999999999999, Expected Goals Conceded: 25.58, Clean Sheet Probability: 0.2857142857142857
# Looking for Ben_Jackson.csv in merged_data/2022-23/DEF/Ben_Jackson.csv
# File merged_data/2022-23/DEF/Ben_Jackson.csv not found.
# Looking for Josh_Acheampong.csv in merged_data/2022-23/DEF/Josh_Acheampong.csv
# File merged_data/2022-23/DEF/Josh_Acheampong.csv not found.
# Looking for Malo_Gusto.csv in merged_data/2022-23/DEF/Malo_Gusto.csv
# File merged_data/2022-23/DEF/Malo_Gusto.csv not found.
# All defender CSV files have been processed.

# %%
#CALCULATING THE FORM FOR THE GK FOLDER
import os
import pandas as pd

# Path to merged_data directory
root_dir = 'merged_data'

# Function to calculate form over last five games (or as many as available)
def calculate_form(series, num_games=5):
    form = []
    for i in range(len(series)):
        if i < num_games:
            form.append(series[:i].mean() if i > 0 else 0)  # Avoid empty slice error
        else:
            form.append(series[i-num_games:i].mean())
    return form

# Function to get last season stats for goalkeepers (including total saves)
def get_last_season_stats_goalkeeper(player_name, last_season_dir):
    last_season_file = os.path.join(last_season_dir, 'GK', player_name)
    
    print(f"Looking for {player_name} in {last_season_file}")  # Debugging
    
    if os.path.exists(last_season_file):
        last_season_df = pd.read_csv(last_season_file)
        if not last_season_df.empty:
            # Ensure the file has the necessary columns
            required_columns = ['penalties_saved', 'expected_goals_conceded', 'minutes', 'clean_sheets', 'saves']
            if all(col in last_season_df.columns for col in required_columns):
                total_penalties_saved = last_season_df['penalties_saved'].sum()
                total_expected_goals_conceded = last_season_df['expected_goals_conceded'].sum()
                total_saves = last_season_df['saves'].sum()
                
                # Calculate last season clean sheet probability
                clean_sheet_games = last_season_df[(last_season_df['minutes'] > 60) & (last_season_df['clean_sheets'] == True)]
                total_games = last_season_df[last_season_df['minutes'] > 60]
                if not total_games.empty:
                    last_season_clean_sheet_prob = len(clean_sheet_games) / len(total_games)
                else:
                    last_season_clean_sheet_prob = 0
                
                print(f"Stats found for {player_name}: Penalties Saved: {total_penalties_saved}, Expected Goals Conceded: {total_expected_goals_conceded}, Last Season Saves: {total_saves}, Last Season Clean Sheet Probability: {last_season_clean_sheet_prob}")  # Debugging
                
                return total_penalties_saved, total_expected_goals_conceded, last_season_clean_sheet_prob, total_saves
            else:
                print(f"Missing required columns in {last_season_file}: {set(required_columns) - set(last_season_df.columns)}")  # Debugging
    else:
        print(f"File {last_season_file} not found.")  # Debugging
    
    return 0, 0, 0, 0

# Function to calculate clean sheet probability for current season
def calculate_clean_sheet_probability(df):
    clean_sheet_games = df[(df['minutes'] > 60) & (df['clean_sheets'] == True)]
    total_games = df[df['minutes'] > 60]
    if not total_games.empty:
        return len(clean_sheet_games) / len(total_games)
    return 0

# Function to calculate saves per game
def calculate_saves_per_game(df):
    return df['saves'].cumsum() / (df.index + 1)

# Loop through the GK directories across all seasons
for season in ['2021-22', '2022-23', '2023-24']:
    position = 'GK'
    position_dir = os.path.join(root_dir, season, position)
    last_season_dir = os.path.join(root_dir, f'{int(season[:4])-1}-{int(season[5:7])-1}')
    
    # Check if position directory exists
    if not os.path.exists(position_dir):
        print(f"Directory {position_dir} does not exist. Skipping.")
        continue

    # Loop through each CSV file in the GK directory
    for player_file in os.listdir(position_dir):
        player_path = os.path.join(position_dir, player_file)
        
        # Read the CSV file and check for empty or corrupted files
        try:
            df = pd.read_csv(player_path)
        except pd.errors.EmptyDataError:
            print(f"File {player_path} is empty or corrupted. Skipping.")
            continue
        
        # Print missing columns for debugging
        required_columns = ['total_points', 'minutes', 'clean_sheets', 'saves']
        missing_columns = [col for col in required_columns if col not in df.columns]
        if missing_columns:
            print(f"File {player_path} is missing columns: {missing_columns}. Skipping.")
            continue
        
        # 1. Create 'form' column if 'total_points' is available
        if 'total_points' in df.columns:
            df['form'] = calculate_form(df['total_points'])
        
        # 2. Calculate clean sheet probability if 'minutes' and 'clean_sheets' are available
        if 'minutes' in df.columns and 'clean_sheets' in df.columns:
            df['clean_sheet_probability'] = df['clean_sheets'].expanding().apply(lambda x: calculate_clean_sheet_probability(df[:x.index[-1]+1]), raw=False)
        
        # 3. Calculate saves per game if 'saves' is available
        if 'saves' in df.columns:
            df['saves_per_game'] = calculate_saves_per_game(df)
        
        # 4. Get last season stats (only for 2022-23 and 2023-24 seasons)
        if season in ['2022-23', '2023-24']:
            last_season_penalties_saved, last_season_expected_goals_conceded, last_season_clean_sheet_prob, last_season_total_saves = get_last_season_stats_goalkeeper(player_file, last_season_dir)
            df['last_season_penalties_saved'] = last_season_penalties_saved
            df['last_season_expected_goals_conceded'] = last_season_expected_goals_conceded
            df['last_season_clean_sheet_probability'] = last_season_clean_sheet_prob
            df['last_season_total_saves'] = last_season_total_saves
        
        # Round all numerical columns to two decimal places
        df = df.round(2)
        
        # Save the updated dataframe back to the CSV file
        df.to_csv(player_path, index=False)

print("All goalkeeper CSV files have been processed.")
# Out:
# Looking for Martin_Dubravka.csv in merged_data/2021-22/GK/Martin_Dubravka.csv
# Missing required columns in merged_data/2021-22/GK/Martin_Dubravka.csv: {'expected_goals_conceded'}
# Looking for Matija_Šarkić.csv in merged_data/2021-22/GK/Matija_Šarkić.csv
# File merged_data/2021-22/GK/Matija_Šarkić.csv not found.
# Stats found for Joseph_Anang.csv: Penalties Saved: 0, Expected Goals Conceded: 0.0, Last Season Saves: 0, Last Season Clean Sheet Probability: 0
# Looking for Scott_Carson.csv in merged_data/2022-23/GK/Scott_Carson.csv
# Stats found for Scott_Carson.csv: Penalties Saved: 0, Expected Goals Conceded: 0.0, Last Season Saves: 0, Last Season Clean Sheet Probability: 0
# Looking for Guglielmo_Vicario.csv in merged_data/2022-23/GK/Guglielmo_Vicario.csv
# File merged_data/2022-23/GK/Guglielmo_Vicario.csv not found.
# Looking for Vicente_Guaita.csv in merged_data/2022-23/GK/Vicente_Guaita.csv
# Stats found for Vicente_Guaita.csv: Penalties Saved: 0, Expected Goals Conceded: 20.490000000000002, Last Season Saves: 85, Last Season Clean Sheet Probability: 0.2222222222222222
# Looking for Caoimhin_Kelleher.csv in merged_data/2022-23/GK/Caoimhin_Kelleher.csv
# Stats found for Caoimhin_Kelleher.csv: Penalties Saved: 0, Expected Goals Conceded: 1.77, Last Season Saves: 6, Last Season Clean Sheet Probability: 0.0
# Looking for Bernd_Leno.csv in merged_data/2022-23/GK/Bernd_Leno.csv
# Stats found for Bernd_Leno.csv: Penalties Saved: 1, Expected Goals Conceded: 38.87, Last Season Saves: 144, Last Season Clean Sheet Probability: 0.2222222222222222
# Looking for Jordan_Pickford.csv in merged_data/2022-23/GK/Jordan_Pickford.csv
# Stats found for Jordan_Pickford.csv: Penalties Saved: 1, Expected Goals Conceded: 44.01, Last Season Saves: 124, Last Season Clean Sheet Probability: 0.21621621621621623
# All goalkeeper CSV files have been processed.

# %%
pip install fuzzywuzzy
# Out:
# Collecting fuzzywuzzy
#   Obtaining dependency information for fuzzywuzzy from https://files.pythonhosted.org/packages/43/ff/74f23998ad2f93b945c0309f825be92e04e0348e062026998b5eefef4c33/fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata
#   Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl.metadata (4.9 kB)
# Downloading fuzzywuzzy-0.18.0-py2.py3-none-any.whl (18 kB)
# Installing collected packages: fuzzywuzzy
# Successfully installed fuzzywuzzy-0.18.0
#
# [notice] A new release of pip is available: 23.2.1 -> 24.2
# [notice] To update, run: python3 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
#ADD THE NEXT WEEK GAMEWEEK POINTS TO EACH ROW
import os
import pandas as pd

# Define the base directory
base_dir = 'merged_data'

# Define the season subdirectories
seasons = ['2022-23', '2023-24']

# Define the player position directories
positions = ['FWD', 'MID', 'GK', 'DEF']

# Loop through each season
for season_index, season in enumerate(seasons):
    for position in positions:
        # Get the path to the position folder in the current season
        position_dir = os.path.join(base_dir, season, position)

        # Ensure the position directory exists
        if not os.path.exists(position_dir):
            print(f"Position directory {position_dir} does not exist. Skipping.")
            continue

        # Loop through each player CSV file in the position directory
        for player_file in os.listdir(position_dir):
            # Load the CSV file for the player
            player_file_path = os.path.join(position_dir, player_file)
            try:
                df = pd.read_csv(player_file_path)
            except pd.errors.EmptyDataError:
                print(f"File {player_file_path} is empty or corrupted. Skipping.")
                continue

            # Check if the file has a 'total_points' column
            if 'total_points' not in df.columns:
                print(f"File {player_file_path} does not have 'total_points'. Skipping.")
                continue

            # Create a new column for next week's points
            df['next_week_points'] = None

            # Iterate through each row
            for i in range(len(df) - 1):
                df.at[i, 'next_week_points'] = df.at[i + 1, 'total_points']
                
            # Handle the case for the last row, only if it's not the last season
            if season_index < len(seasons) - 1 and len(df) > 0:
                # Look for the same player file in the next season, same position
                next_season = seasons[season_index + 1]
                next_season_dir = os.path.join(base_dir, next_season, position)
                next_season_player_file = os.path.join(next_season_dir, player_file)

                # Ensure the next season file exists and can be read
                if os.path.exists(next_season_player_file):
                    try:
                        next_season_df = pd.read_csv(next_season_player_file)
                        if len(next_season_df) > 0:
                            # Get the first row's total_points from the next season
                            df.at[len(df) - 1, 'next_week_points'] = next_season_df.at[0, 'total_points']
                    except pd.errors.EmptyDataError:
                        print(f"File {next_season_player_file} is empty or corrupted. Skipping last row addition.")
            
            # Save the updated CSV file back to the same location
            df.to_csv(player_file_path, index=False)

print("Processing completed.")
# Out:
# Processing completed.

# %%
#ADDING THE TEAM DIFFICULTIES
import os
import pandas as pd
from fuzzywuzzy import process

# Paths to directories
merged_data_dir = 'merged_data'
team_difficulty_ratings_dir = 'team_difficulty_ratings'

# Define seasons and positions
seasons = ['2022-23', '2023-24']  # Add additional seasons as necessary
positions = ['GK', 'DEF', 'MID', 'FWD']

# Team name mappings
team_name_mappings = {
    "Spurs": "Tottenham",
    "Man City": "Manchester City",
    "Man Utd": "Manchester United",
    "Nott'm Forest": "Nottingham Forest"
}

# Function to map team names
def map_team_name(team_name):
    return team_name_mappings.get(team_name, team_name)  # Map if in dict, else return original

# Function to find the closest match for a team name using fuzzywuzzy
def get_closest_match(team_name, options, threshold=75):
    closest_match, score = process.extractOne(team_name, options)
    if score >= threshold:
        return closest_match
    return None

# Function to find the next week's fixture difficulty
def get_next_fixture_difficulty(player_team, was_home, opponent_team):
    # Map the player team name to a canonical version before matching
    mapped_team = map_team_name(player_team)

    # Find the closest team name match in the team_difficulty_ratings directory
    team_files = os.listdir(team_difficulty_ratings_dir)
    closest_team_file = get_closest_match(mapped_team, team_files)
    
    # Load the team's difficulty rating CSV
    if closest_team_file:
        team_difficulty_file_path = os.path.join(team_difficulty_ratings_dir, closest_team_file)
        team_df = pd.read_csv(team_difficulty_file_path)
    
        # Find the closest match for the opponent team in the difficulty ratings
        opponent = get_closest_match(opponent_team, team_df['Opponent'].tolist())
    
        # Get the fixture difficulty based on 'Home Difficulty' or 'Away Difficulty'
        if opponent is not None:
            if was_home:
                difficulty = team_df.loc[team_df['Opponent'] == opponent, 'Home Difficulty'].values
            else:
                difficulty = team_df.loc[team_df['Opponent'] == opponent, 'Away Difficulty'].values
            if len(difficulty) > 0:
                return round(difficulty[0], 2)  # Round difficulty to two decimal places
    return None

# Function to handle moving to the next season for the last row
def get_next_season_fixture(player_file, current_season_index, position):
    if current_season_index < len(seasons) - 1:  # Check if we're not in the last season
        next_season = seasons[current_season_index + 1]
        next_season_dir = os.path.join(merged_data_dir, next_season, position)
        if os.path.exists(next_season_dir):
            # List all player files in the next season position directory
            next_season_files = os.listdir(next_season_dir)
            closest_player_file = get_closest_match(player_file, next_season_files, threshold=75)
            if closest_player_file:
                # Load the first row of the closest player's CSV in the next season
                next_player_path = os.path.join(next_season_dir, closest_player_file)
                next_df = pd.read_csv(next_player_path)
                if len(next_df) > 0:
                    # Return the first row's team, was_home, and opponent_team
                    return next_df.iloc[0]['team'], next_df.iloc[0]['was_home'], next_df.iloc[0]['opponent_team']
    return None, None, None  # Return None if no valid next season match is found

# Traverse the merged_data directory
for season_index, season in enumerate(seasons):
    for position in positions:
        position_dir = os.path.join(merged_data_dir, season, position)
        
        # Check if the position directory exists
        if os.path.exists(position_dir):
            for player_file in os.listdir(position_dir):
                player_file_path = os.path.join(position_dir, player_file)
                
                # Load the player CSV
                try:
                    df = pd.read_csv(player_file_path)
                except pd.errors.EmptyDataError:
                    print(f"File {player_file_path} is empty or corrupted. Skipping.")
                    continue
                
                # Check if the dataframe is empty
                if df.empty:
                    print(f"{player_file_path} is empty. Skipping.")
                    continue
                
                # Ensure the necessary columns exist
                if {'team', 'was_home', 'opponent_team'}.issubset(df.columns):
                    
                    # Shift the columns to get next week's fixture details
                    df['next_team'] = df['team'].shift(-1)
                    df['next_was_home'] = df['was_home'].shift(-1)
                    df['next_opponent_team'] = df['opponent_team'].shift(-1)

                    # Handle the last row separately
                    last_row_index = df.index[-1]
                    last_team, last_was_home, last_opponent_team = df.iloc[last_row_index]['team'], df.iloc[last_row_index]['was_home'], df.iloc[last_row_index]['opponent_team']
                    
                    # For the last row of the season, check the next season's first row for the same player
                    if season_index < len(seasons) - 1:  # Only for seasons other than the last one
                        next_season_team, next_season_was_home, next_season_opponent_team = get_next_season_fixture(player_file, season_index, position)
                        
                        if next_season_team:
                            df.loc[last_row_index, 'next_team'] = next_season_team
                            df.loc[last_row_index, 'next_was_home'] = next_season_was_home
                            df.loc[last_row_index, 'next_opponent_team'] = next_season_opponent_team
                    
                    # Create a new column for next week's fixture difficulty
                    df['next_week_fixture_difficulty'] = df.apply(
                        lambda row: get_next_fixture_difficulty(
                            row['next_team'], row['next_was_home'], row['next_opponent_team']
                        ) if pd.notnull(row['next_team']) and pd.notnull(row['next_opponent_team']) else None, axis=1
                    )
                    
                    # Save the updated CSV back to file
                    df.to_csv(player_file_path, index=False)
                    print(f"Updated {player_file_path} with next_week_fixture_difficulty.")
        else:
            print(f"Position directory {position_dir} does not exist for season {season}.")
# Out:
# Updated merged_data/2022-23/GK/Martin_Dubravka.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Matija_Šarkić.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Hugo_Lloris.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Stefan_Ortega_Moreno.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Viljami_Sinisalo.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Brandon_Austin.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Illan_Meslier.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Lukasz_Fabianski.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Willy_Caballero.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Daniel_Iversen.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Gavin_Bazunu.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Karl_Hein.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Asmir_Begović.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/David_De_Gea_Quintana.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/Norberto_Murara_Neto.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23/GK/José_Malheiro_de_Sá.csv with next_week_fixture_difficulty.
# Updated merged_data/2022-23
csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Cody_Gakpo.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Christopher_Nkunku.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Deivid_Washington_de_Souza_Eugênio.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Timo_Werner.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/William_Osula.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Alejo_Véliz.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Deniz_Undav.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Daniel_Jebbison.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Jean-Philippe_Mateta.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Gianluca_Scamacca.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Chiedozie_Ogbene.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Jay_Stansfield.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/David_Datro_Fofana.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Aleksandar_Mitrović.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Erling_Haaland.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Wout_Weghorst.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Youssef_Ramalho_Chermiti.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Mason_Burstow.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Ben_Parkinson.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Enes_Ünal.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Jacob_Brown.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Joe_Hugill.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Mark_O’Mahony.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Danny_Welbeck.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Leon_Chiwome.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Emmanuel_Dennis.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Ethan_Wheatley.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Rasmus_Højlund.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Taiwo_Awoniyi.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Ivan_Toney.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Lyle_Foster.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Antwoine_Hackford.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Sasa_Kalajdzic.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Jhon_Durán.csv with next_week_fixture_difficulty.
# Updated merged_data/2023-24/FWD/Evan_Ferguson.csv with next_week_fixture_difficulty.

# %%
## CREATING THE TEST DATA 
import os
import pandas as pd

# Define the base directories
base_dir = 'merged_data'
train_data_dir = 'train_data'

# Create the train_data directory if it doesn't exist
if not os.path.exists(train_data_dir):
    os.makedirs(train_data_dir)

# Define the positions and corresponding output files
positions_mapping = {
    'FWD': 'forward.csv',
    'MID': 'midfielder.csv',
    'GK': 'goalkeeper.csv',
    'DEF': 'defender.csv'
}

# Initialize empty dataframes for each position
position_dfs = {
    'FWD': pd.DataFrame(),
    'MID': pd.DataFrame(),
    'GK': pd.DataFrame(),
    'DEF': pd.DataFrame()
}

# Loop through the seasons
for season in ['2022-23', '2023-24']:
    # Loop through each position (FWD, MID, GK, DEF)
    for position, output_file in positions_mapping.items():
        position_dir = os.path.join(base_dir, season, position)

        # Ensure the position directory exists
        if not os.path.exists(position_dir):
            print(f"Position directory {position_dir} does not exist. Skipping.")
            continue

        # Loop through each player CSV file in the position directory
        for player_file in os.listdir(position_dir):
            player_file_path = os.path.join(position_dir, player_file)

            try:
                df = pd.read_csv(player_file_path)
            except pd.errors.EmptyDataError:
                print(f"File {player_file_path} is empty or corrupted. Skipping.")
                continue

            # Filter rows where 'next_week_points' is defined (non-null or non-NaN)
            df_filtered = df[df['next_week_points'].notnull()]

            # Append filtered data to the corresponding dataframe for this position
            position_dfs[position] = pd.concat([position_dfs[position], df_filtered])

# Save each position's dataframe into the corresponding CSV in train_data
for position, output_file in positions_mapping.items():
    output_path = os.path.join(train_data_dir, output_file)
    position_dfs[position].to_csv(output_path, index=False)
    print(f"{output_file} saved with {len(position_dfs[position])} rows.")

print("Processing completed.")
# Out:
# forward.csv saved with 6037 rows.
# midfielder.csv saved with 21402 rows.
# goalkeeper.csv saved with 4755 rows.
# defender.csv saved with 16472 rows.
# Processing completed.
